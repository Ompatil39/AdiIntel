# %%
# Step 1: Load CSV and inspect
import pandas as pd

# Load CSV
df = pd.read_csv("mock_ads_deep_training_data.csv")  # replace with your actual CSV file path

# Show first few rows
print(df.head())

# Info about columns and types
print(df.info())

# Check for missing values
print(df.isnull().sum())

# Basic statistics
print(df.describe())
# Out:
#        platform  campaign_id campaign_name  impressions  clicks    spend  \
# 0  LinkedIn Ads       300001  Campaign_A_0        29230     326  2454.81
# 1  Facebook Ads       100002  Campaign_B_1        41677    6729  2930.53
# 2  Facebook Ads       100003  Campaign_C_2        11087    1358   327.95
# 3  Facebook Ads       100004  Campaign_D_3        23231    1183  2864.28
# 4  Facebook Ads       100005  Campaign_E_4        15192     771  1625.96
#
#    conversions    CTR   ROAS  campaign_score  performance_alerts  \
# 0           61   1.12   0.59              21                   1
# 1         1311  16.15  14.58             176                   0
# 2          581  12.25  48.30             155                   0
# 3          245   5.09   1.77              63                   0
# 4            4   5.08   0.07              41                   0
#
#                           budget_recommendation  \
# 0  Decrease budget or pause underperforming ads
# 1                       Maintain current budget
# 2                       Maintain current budget
# 3                               Increase budget
# 4                               Increase budget
#
#   recommended_budget_distribution  avg_performance_score  \
# 0  22% Alpha, 38% Beta, 40% Gamma                     21
# 1  22% Alpha, 24% Beta, 54% Gamma                    180
# 2  21% Alpha, 50% Beta, 29% Gamma                    155
# 3  44% Alpha, 37% Beta, 19% Gamma                     58
# 4  27% Alpha, 39% Beta, 34% Gamma                     40
#
#   budget_reallocation_opportunity audience_expansion_opportunity  \
# 0     Shift 10% between campaigns                            Yes
# 1     Shift 14% between campaigns                             No
# 2      Shift 8% between campaigns                             No
# 3     Shift 10% between campaigns                            Yes
# 4      Shift 5% between campaigns                            Yes
#
#            bid_strategy_optimization
# 0               Maximize conversions
# 1                    Maximize clicks
# 2      Optimize bids for target ROAS
# 3                    Maximize clicks
# 4  Manual bid adjustment recommended
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   platform                         100000 non-null  object
#  1   campaign_id                      100000 non-null  int64
#  2   campaign_name                    100000 non-null  object
#  3   impressions                      100000 non-null  int64
#  4   clicks                           100000 non-null  int64
#  5   spend                            100000 non-null  float64
#  6   conversions                      100000 non-null  int64
#  7   CTR                              100000 non-null  float64
#  8   ROAS                             100000 non-null  float64
#  9   campaign_score                   100000 non-null  int64
#  10  performance_alerts               100000 non-null  int64
#  11  budget_recommendation            100000 non-null  object
#  12  recommended_budget_distribution  100000 non-null  object
#  13  avg_performance_score            100000 non-null  int64
#  14  budget_reallocation_opportunity  100000 non-null  object
#  15  audience_expansion_opportunity   100000 non-null  object
#  16  bid_strategy_optimization        100000 non-null  object
# dtypes: float64(3), int64(7), object(7)
# memory usage: 13.0+ MB
# None
# platform                           0
# campaign_id                        0
# campaign_name                      0
# impressions                        0
# clicks                             0
# spend                              0
# conversions                        0
# CTR                                0
# ROAS                               0
# campaign_score                     0
# performance_alerts                 0
# budget_recommendation              0
# recommended_budget_distribution    0
# avg_performance_score              0
# budget_reallocation_opportunity    0
# audience_expansion_opportunity     0
# bid_strategy_optimization          0
# dtype: int64
#          campaign_id    impressions         clicks          spend  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean   199648.500000   27505.533350    2792.526340    2549.209348
# std    115075.036328   12968.873503    2183.103803    1416.727930
# min         9.000000    5000.000000      50.000000     100.030000
# 25%     99859.250000   16294.750000    1014.000000    1322.992500
# 50%    199634.500000   27522.500000    2221.000000    2550.925000
# 75%    299100.250000   38727.250000    4133.000000    3781.882500
# max    399997.000000   50000.000000    9944.000000    5000.000000
#
#          conversions            CTR           ROAS  campaign_score  \
# count  100000.000000  100000.000000  100000.000000   100000.000000
# mean      694.729880      10.181445      15.280206      117.650220
# std       745.214556       5.706959      42.108237       54.929383
# min         0.000000       0.110000       0.000000        1.000000
# 25%       152.000000       5.260000       1.410000       74.000000
# 50%       428.000000      10.190000       4.610000      121.000000
# 75%       985.000000      15.140000      13.150000      163.000000
# max      4852.000000      20.000000    1783.430000      219.000000
#
#        performance_alerts  avg_performance_score
# count       100000.000000          100000.000000
# mean             0.088640             117.654390
# std              0.284225              55.015682
# min              0.000000              -4.000000
# 25%              0.000000              74.000000
# 50%              0.000000             121.000000
# 75%              0.000000             163.000000
# max              1.000000             224.000000

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
import re  # for extracting percentages safely

# Copy your dataframe
df_model = df.copy()

# -------------------------------
# 1. Encode platform (categorical input)
# -------------------------------
platform_encoder = LabelEncoder()
df_model['platform_encoded'] = platform_encoder.fit_transform(df_model['platform'])

# -------------------------------
# 2. Encode categorical outputs
# -------------------------------
# Budget Recommendation
budget_rec_encoder = LabelEncoder()
df_model['budget_rec_encoded'] = budget_rec_encoder.fit_transform(df_model['budget_recommendation'])

# Audience Expansion Opportunity (Yes/No)
audience_exp_encoder = LabelEncoder()
df_model['audience_exp_encoded'] = audience_exp_encoder.fit_transform(df_model['audience_expansion_opportunity'])

# Bid Strategy Optimization
bid_strategy_encoder = LabelEncoder()
df_model['bid_strategy_encoded'] = bid_strategy_encoder.fit_transform(df_model['bid_strategy_optimization'])

# -------------------------------
# 3. Process recommended_budget_distribution
# Example: "22% Alpha, 38% Beta, 40% Gamma" -> [22,38,40]
# -------------------------------
def parse_budget_distribution(text):
    parts = text.split(',')
    percentages = []
    for part in parts:
        percent = float(part.strip().split('%')[0])
        percentages.append(percent)
    return percentages

budget_dist = df_model['recommended_budget_distribution'].apply(parse_budget_distribution)
budget_dist_df = pd.DataFrame(budget_dist.tolist(), columns=['budget_alpha', 'budget_beta', 'budget_gamma'])
df_model = pd.concat([df_model, budget_dist_df], axis=1)

# -------------------------------
# 4. Features (inputs) for model
# -------------------------------
X = df_model[['platform_encoded', 'impressions', 'clicks', 'spend', 'conversions', 'CTR', 'ROAS',
              'budget_alpha', 'budget_beta', 'budget_gamma']].values

# -------------------------------
# 5. Targets (outputs)
# -------------------------------

# Safe extraction of numeric percentage from budget_reallocation_opportunity
def extract_percentage(text):
    if isinstance(text, str):
        match = re.search(r'(\d+)%', text)
        if match:
            return float(match.group(1))
    return 0.0

y_campaign_score = df_model['campaign_score'].values
y_performance_alerts = df_model['performance_alerts'].values
y_budget_rec = df_model['budget_rec_encoded'].values
y_roi_forecast = df_model['ROAS'].values  # can be replaced with advanced ROI formula
y_budget_dist_total = df_model[['budget_alpha','budget_beta','budget_gamma']].values
y_avg_perf_score = df_model['avg_performance_score'].values
y_budget_realloc = df_model['budget_reallocation_opportunity'].apply(extract_percentage).values
y_audience_exp = df_model['audience_exp_encoded'].values
y_bid_strategy = df_model['bid_strategy_encoded'].values

# -------------------------------
# 6. Standardize features
# -------------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Feature shape:", X_scaled.shape)
print("Targets ready for modeling.")
# Out:
# Feature shape: (100000, 10)
# Targets ready for modeling.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout

# -------------------------------
# Assume df_model and processed features/targets exist
# X_scaled, y_campaign_score, y_performance_alerts, y_budget_rec, y_roi_forecast,
# y_budget_dist_total, y_avg_perf_score, y_budget_realloc, y_audience_exp, y_bid_strategy
# -------------------------------

# -------------------------------
# 1. Train-test split for features
# -------------------------------
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# -------------------------------
# 2. Train-test split for targets individually
# -------------------------------
y_campaign_score_train, y_campaign_score_test = train_test_split(y_campaign_score, test_size=0.2, random_state=42)
y_performance_alerts_train, y_performance_alerts_test = train_test_split(y_performance_alerts, test_size=0.2, random_state=42)
y_budget_rec_train, y_budget_rec_test = train_test_split(y_budget_rec, test_size=0.2, random_state=42)
y_roi_forecast_train, y_roi_forecast_test = train_test_split(y_roi_forecast, test_size=0.2, random_state=42)
y_budget_dist_train, y_budget_dist_test = train_test_split(y_budget_dist_total, test_size=0.2, random_state=42)
y_avg_perf_score_train, y_avg_perf_score_test = train_test_split(y_avg_perf_score, test_size=0.2, random_state=42)
y_budget_realloc_train, y_budget_realloc_test = train_test_split(y_budget_realloc, test_size=0.2, random_state=42)
y_audience_exp_train, y_audience_exp_test = train_test_split(y_audience_exp, test_size=0.2, random_state=42)
y_bid_strategy_train, y_bid_strategy_test = train_test_split(y_bid_strategy, test_size=0.2, random_state=42)

# -------------------------------
# 3. Combine targets into dicts
# -------------------------------
y_train_prepared = {
    'campaign_score': y_campaign_score_train,
    'roi_forecast': y_roi_forecast_train,
    'avg_perf_score': y_avg_perf_score_train,
    'budget_dist': y_budget_dist_train,
    'budget_realloc': y_budget_realloc_train,
    'performance_alerts': y_performance_alerts_train,
    'budget_rec': y_budget_rec_train,
    'audience_exp': y_audience_exp_train,
    'bid_strategy': y_bid_strategy_train
}

y_test_prepared = {
    'campaign_score': y_campaign_score_test,
    'roi_forecast': y_roi_forecast_test,
    'avg_perf_score': y_avg_perf_score_test,
    'budget_dist': y_budget_dist_test,
    'budget_realloc': y_budget_realloc_test,
    'performance_alerts': y_performance_alerts_test,
    'budget_rec': y_budget_rec_test,
    'audience_exp': y_audience_exp_test,
    'bid_strategy': y_bid_strategy_test
}

# -------------------------------
# 4. Build multi-task neural network
# -------------------------------
input_layer = Input(shape=(X_train.shape[1],), name='input_features')

# Shared hidden layers
x = Dense(256, activation='relu')(input_layer)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)

# Output layers
campaign_score_out = Dense(1, name='campaign_score')(x)
roi_forecast_out = Dense(1, name='roi_forecast')(x)
avg_perf_score_out = Dense(1, name='avg_perf_score')(x)
budget_dist_out = Dense(3, name='budget_dist')(x)
budget_realloc_out = Dense(1, name='budget_realloc')(x)

performance_alerts_out = Dense(1, activation='sigmoid', name='performance_alerts')(x)
budget_rec_out = Dense(len(np.unique(y_budget_rec)), activation='softmax', name='budget_rec')(x)
audience_exp_out = Dense(1, activation='sigmoid', name='audience_exp')(x)
bid_strategy_out = Dense(len(np.unique(y_bid_strategy)), activation='softmax', name='bid_strategy')(x)

# Build model
model = Model(inputs=input_layer, outputs=[
    campaign_score_out, roi_forecast_out, avg_perf_score_out, budget_dist_out, budget_realloc_out,
    performance_alerts_out, budget_rec_out, audience_exp_out, bid_strategy_out
])

# -------------------------------
# 5. Compile model
# -------------------------------
model.compile(
    optimizer='adam',
    loss={
        'campaign_score': 'mse',
        'roi_forecast': 'mse',
        'avg_perf_score': 'mse',
        'budget_dist': 'mse',
        'budget_realloc': 'mse',
        'performance_alerts': 'binary_crossentropy',
        'budget_rec': 'sparse_categorical_crossentropy',
        'audience_exp': 'binary_crossentropy',
        'bid_strategy': 'sparse_categorical_crossentropy'
    },
    metrics={
        'campaign_score': 'mae',
        'roi_forecast': 'mae',
        'avg_perf_score': 'mae',
        'budget_dist': 'mae',
        'budget_realloc': 'mae',
        'performance_alerts': 'accuracy',
        'budget_rec': 'accuracy',
        'audience_exp': 'accuracy',
        'bid_strategy': 'accuracy'
    }
)

# -------------------------------
# 6. Train model
# -------------------------------
history = model.fit(
    X_train, y_train_prepared,
    validation_data=(X_test, y_test_prepared),
    epochs=50,
    batch_size=512
)

print("Model training completed successfully!")
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - audience_exp_accuracy: 0.4969 - audience_exp_loss: 0.8865 - avg_perf_score_loss: 4635.2383 - avg_perf_score_mae: 47.6814 - bid_strategy_accuracy: 0.2518 - bid_strategy_loss: 1.9424 - budget_dist_loss: 516.4344 - budget_dist_mae: 18.7843 - budget_realloc_loss: 120.4466 - budget_realloc_mae: 7.4658 - budget_rec_accuracy: 0.4094 - budget_rec_loss: 1.2652 - campaign_score_loss: 4539.7031 - campaign_score_mae: 47.0475 - loss: 11383.0439 - performance_alerts_accuracy: 0.7683 - performance_alerts_loss: 0.4392 - roi_forecast_loss: 1547.6107 - roi_forecast_mae: 16.8306 - val_audience_exp_accuracy: 0.5020 - val_audience_exp_loss: 0.7013 - val_avg_perf_score_loss: 533.5765 - val_avg_perf_score_mae: 18.3595 - val_bid_strategy_accuracy: 0.2520 - val_bid_strategy_loss: 1.8839 - val_budget_dist_loss: 266.8152 - val_budget_dist_mae: 13.4957 - val_budget_realloc_loss: 25.6778 - val_budget_realloc_mae: 4.1473 - val_budget_rec_accuracy: 0.4557 - val_budget_rec_loss: 0.9143 - val_campaign_score_loss: 540.7192 - val_campaign_score_mae: 18.2834 - val_loss: 2475.1201 - val_performance_alerts_accuracy: 0.9104 - val_performance_alerts_loss: 0.2772 - val_roi_forecast_loss: 1077.6172 - val_roi_forecast_mae: 10.7174
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5018 - audience_exp_loss: 0.9539 - avg_perf_score_loss: 557.6160 - avg_perf_score_mae: 18.7684 - bid_strategy_accuracy: 0.2510 - bid_strategy_loss: 2.1555 - budget_dist_loss: 220.0801 - budget_dist_mae: 12.1380 - budget_realloc_loss: 23.4012 - budget_realloc_mae: 3.9395 - budget_rec_accuracy: 0.4615 - budget_rec_loss: 1.1987 - campaign_score_loss: 570.1857 - campaign_score_mae: 18.6864 - loss: 1813.9902 - performance_alerts_accuracy: 0.8972 - performance_alerts_loss: 0.3521 - roi_forecast_loss: 434.7362 - roi_forecast_mae: 8.8791 - val_audience_exp_accuracy: 0.4994 - val_audience_exp_loss: 0.7776 - val_avg_perf_score_loss: 359.4821 - val_avg_perf_score_mae: 15.0881 - val_bid_strategy_accuracy: 0.2473 - val_bid_strategy_loss: 1.5206 - val_budget_dist_loss: 112.1325 - val_budget_dist_mae: 8.6528 - val_budget_realloc_loss: 13.9809 - val_budget_realloc_mae: 3.1103 - val_budget_rec_accuracy: 0.5028 - val_budget_rec_loss: 0.8950 - val_campaign_score_loss: 347.1462 - val_campaign_score_mae: 14.8021 - val_loss: 889.4388 - val_performance_alerts_accuracy: 0.9104 - val_performance_alerts_loss: 0.2691 - val_roi_forecast_loss: 44.6871 - val_roi_forecast_mae: 3.1545
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - audience_exp_accuracy: 0.5031 - audience_exp_loss: 0.9312 - avg_perf_score_loss: 371.2350 - avg_perf_score_mae: 15.3401 - bid_strategy_accuracy: 0.2505 - bid_strategy_loss: 1.8823 - budget_dist_loss: 87.5119 - budget_dist_mae: 7.4558 - budget_realloc_loss: 15.6148 - budget_realloc_mae: 3.2447 - budget_rec_accuracy: 0.4900 - budget_rec_loss: 1.0609 - campaign_score_loss: 358.2953 - campaign_score_mae: 15.0737 - loss: 940.1982 - performance_alerts_accuracy: 0.9114 - performance_alerts_loss: 0.2212 - roi_forecast_loss: 103.0191 - roi_forecast_mae: 6.2538 - val_audience_exp_accuracy: 0.4944 - val_audience_exp_loss: 0.7288 - val_avg_perf_score_loss: 180.8942 - val_avg_perf_score_mae: 10.7287 - val_bid_strategy_accuracy: 0.2505 - val_bid_strategy_loss: 1.4689 - val_budget_dist_loss: 37.5861 - val_budget_dist_mae: 5.0572 - val_budget_realloc_loss: 11.5491 - val_budget_realloc_mae: 2.8895 - val_budget_rec_accuracy: 0.5224 - val_budget_rec_loss: 0.7661 - val_campaign_score_loss: 169.2644 - val_campaign_score_mae: 10.3821 - val_loss: 426.8866 - val_performance_alerts_accuracy: 0.9465 - val_performance_alerts_loss: 0.1356 - val_roi_forecast_loss: 20.6710 - val_roi_forecast_mae: 3.2638
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - audience_exp_accuracy: 0.4995 - audience_exp_loss: 0.8968 - avg_perf_score_loss: 254.6093 - avg_perf_score_mae: 12.6613 - bid_strategy_accuracy: 0.2512 - bid_strategy_loss: 1.7746 - budget_dist_loss: 60.7336 - budget_dist_mae: 6.1703 - budget_realloc_loss: 14.0258 - budget_realloc_mae: 3.1078 - budget_rec_accuracy: 0.4972 - budget_rec_loss: 0.9558 - campaign_score_loss: 242.7682 - campaign_score_mae: 12.3716 - loss: 659.3679 - performance_alerts_accuracy: 0.9314 - performance_alerts_loss: 0.1686 - roi_forecast_loss: 83.1696 - roi_forecast_mae: 5.1967 - val_audience_exp_accuracy: 0.5035 - val_audience_exp_loss: 0.7148 - val_avg_perf_score_loss: 109.5301 - val_avg_perf_score_mae: 8.3923 - val_bid_strategy_accuracy: 0.2517 - val_bid_strategy_loss: 1.4369 - val_budget_dist_loss: 25.7718 - val_budget_dist_mae: 4.1567 - val_budget_realloc_loss: 10.6541 - val_budget_realloc_mae: 2.8064 - val_budget_rec_accuracy: 0.5247 - val_budget_rec_loss: 0.7315 - val_campaign_score_loss: 98.5701 - val_campaign_score_mae: 7.9386 - val_loss: 263.3843 - val_performance_alerts_accuracy: 0.9530 - val_performance_alerts_loss: 0.1092 - val_roi_forecast_loss: 13.9879 - val_roi_forecast_mae: 2.7469
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.8587 - avg_perf_score_loss: 200.9443 - avg_perf_score_mae: 11.2572 - bid_strategy_accuracy: 0.2532 - bid_strategy_loss: 1.6721 - budget_dist_loss: 50.4158 - budget_dist_mae: 5.5806 - budget_realloc_loss: 13.1868 - budget_realloc_mae: 3.0341 - budget_rec_accuracy: 0.5040 - budget_rec_loss: 0.8919 - campaign_score_loss: 189.9922 - campaign_score_mae: 10.9430 - loss: 520.9955 - performance_alerts_accuracy: 0.9403 - performance_alerts_loss: 0.1364 - roi_forecast_loss: 62.3422 - roi_forecast_mae: 4.4934 - val_audience_exp_accuracy: 0.5020 - val_audience_exp_loss: 0.7027 - val_avg_perf_score_loss: 80.6629 - val_avg_perf_score_mae: 7.0662 - val_bid_strategy_accuracy: 0.2558 - val_bid_strategy_loss: 1.4079 - val_budget_dist_loss: 15.4653 - val_budget_dist_mae: 3.1541 - val_budget_realloc_loss: 10.5250 - val_budget_realloc_mae: 2.7930 - val_budget_rec_accuracy: 0.5254 - val_budget_rec_loss: 0.7263 - val_campaign_score_loss: 70.3977 - val_campaign_score_mae: 6.5536 - val_loss: 193.3153 - val_performance_alerts_accuracy: 0.9673 - val_performance_alerts_loss: 0.0934 - val_roi_forecast_loss: 12.5754 - val_roi_forecast_mae: 2.5477
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5012 - audience_exp_loss: 0.8241 - avg_perf_score_loss: 174.8462 - avg_perf_score_mae: 10.4292 - bid_strategy_accuracy: 0.2517 - bid_strategy_loss: 1.6176 - budget_dist_loss: 44.6119 - budget_dist_mae: 5.2139 - budget_realloc_loss: 12.8284 - budget_realloc_mae: 3.0005 - budget_rec_accuracy: 0.5046 - budget_rec_loss: 0.8521 - campaign_score_loss: 164.3799 - campaign_score_mae: 10.0973 - loss: 461.5649 - performance_alerts_accuracy: 0.9468 - performance_alerts_loss: 0.1199 - roi_forecast_loss: 61.3402 - roi_forecast_mae: 3.9742 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.7024 - val_avg_perf_score_loss: 67.9723 - val_avg_perf_score_mae: 6.3490 - val_bid_strategy_accuracy: 0.2520 - val_bid_strategy_loss: 1.4108 - val_budget_dist_loss: 12.0444 - val_budget_dist_mae: 2.7713 - val_budget_realloc_loss: 10.3337 - val_budget_realloc_mae: 2.7756 - val_budget_rec_accuracy: 0.5314 - val_budget_rec_loss: 0.7149 - val_campaign_score_loss: 57.8513 - val_campaign_score_mae: 5.7510 - val_loss: 161.6012 - val_performance_alerts_accuracy: 0.9740 - val_performance_alerts_loss: 0.0827 - val_roi_forecast_loss: 10.2818 - val_roi_forecast_mae: 2.3496
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5015 - audience_exp_loss: 0.8042 - avg_perf_score_loss: 159.0599 - avg_perf_score_mae: 9.9097 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.5773 - budget_dist_loss: 42.0459 - budget_dist_mae: 5.0579 - budget_realloc_loss: 12.5606 - budget_realloc_mae: 2.9785 - budget_rec_accuracy: 0.5092 - budget_rec_loss: 0.8204 - campaign_score_loss: 148.7355 - campaign_score_mae: 9.5928 - loss: 418.0712 - performance_alerts_accuracy: 0.9511 - performance_alerts_loss: 0.1101 - roi_forecast_loss: 51.8615 - roi_forecast_mae: 3.7549 - val_audience_exp_accuracy: 0.5013 - val_audience_exp_loss: 0.7008 - val_avg_perf_score_loss: 59.6665 - val_avg_perf_score_mae: 5.9641 - val_bid_strategy_accuracy: 0.2551 - val_bid_strategy_loss: 1.4031 - val_budget_dist_loss: 9.8041 - val_budget_dist_mae: 2.5284 - val_budget_realloc_loss: 10.2709 - val_budget_realloc_mae: 2.7701 - val_budget_rec_accuracy: 0.5234 - val_budget_rec_loss: 0.7390 - val_campaign_score_loss: 49.4429 - val_campaign_score_mae: 5.3003 - val_loss: 145.1908 - val_performance_alerts_accuracy: 0.9645 - val_performance_alerts_loss: 0.0894 - val_roi_forecast_loss: 12.8431 - val_roi_forecast_mae: 2.4459
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5015 - audience_exp_loss: 0.7897 - avg_perf_score_loss: 145.9909 - avg_perf_score_mae: 9.5326 - bid_strategy_accuracy: 0.2482 - bid_strategy_loss: 1.5499 - budget_dist_loss: 39.7505 - budget_dist_mae: 4.9137 - budget_realloc_loss: 12.3995 - budget_realloc_mae: 2.9640 - budget_rec_accuracy: 0.5089 - budget_rec_loss: 0.7952 - campaign_score_loss: 135.6037 - campaign_score_mae: 9.1628 - loss: 385.3677 - performance_alerts_accuracy: 0.9558 - performance_alerts_loss: 0.1038 - roi_forecast_loss: 47.9571 - roi_forecast_mae: 3.5603 - val_audience_exp_accuracy: 0.5026 - val_audience_exp_loss: 0.7176 - val_avg_perf_score_loss: 52.3385 - val_avg_perf_score_mae: 5.6242 - val_bid_strategy_accuracy: 0.2533 - val_bid_strategy_loss: 1.3994 - val_budget_dist_loss: 8.5481 - val_budget_dist_mae: 2.3137 - val_budget_realloc_loss: 10.2081 - val_budget_realloc_mae: 2.7647 - val_budget_rec_accuracy: 0.5236 - val_budget_rec_loss: 0.7182 - val_campaign_score_loss: 42.5418 - val_campaign_score_mae: 4.8988 - val_loss: 125.8930 - val_performance_alerts_accuracy: 0.9712 - val_performance_alerts_loss: 0.0787 - val_roi_forecast_loss: 9.1727 - val_roi_forecast_mae: 2.2528
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.7809 - avg_perf_score_loss: 137.1698 - avg_perf_score_mae: 9.1822 - bid_strategy_accuracy: 0.2533 - bid_strategy_loss: 1.5186 - budget_dist_loss: 37.7630 - budget_dist_mae: 4.7902 - budget_realloc_loss: 12.1627 - budget_realloc_mae: 2.9417 - budget_rec_accuracy: 0.5106 - budget_rec_loss: 0.7866 - campaign_score_loss: 126.8297 - campaign_score_mae: 8.8027 - loss: 361.6104 - performance_alerts_accuracy: 0.9556 - performance_alerts_loss: 0.1024 - roi_forecast_loss: 44.2487 - roi_forecast_mae: 3.3941 - val_audience_exp_accuracy: 0.5008 - val_audience_exp_loss: 0.6968 - val_avg_perf_score_loss: 46.5532 - val_avg_perf_score_mae: 5.3305 - val_bid_strategy_accuracy: 0.2543 - val_bid_strategy_loss: 1.4299 - val_budget_dist_loss: 8.1163 - val_budget_dist_mae: 2.2522 - val_budget_realloc_loss: 10.2038 - val_budget_realloc_mae: 2.7647 - val_budget_rec_accuracy: 0.5254 - val_budget_rec_loss: 0.7188 - val_campaign_score_loss: 36.7087 - val_campaign_score_mae: 4.6250 - val_loss: 113.2835 - val_performance_alerts_accuracy: 0.9708 - val_performance_alerts_loss: 0.0807 - val_roi_forecast_loss: 8.4984 - val_roi_forecast_mae: 2.0941
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.7647 - avg_perf_score_loss: 131.4308 - avg_perf_score_mae: 8.9592 - bid_strategy_accuracy: 0.2491 - bid_strategy_loss: 1.5020 - budget_dist_loss: 36.7982 - budget_dist_mae: 4.7161 - budget_realloc_loss: 11.9543 - budget_realloc_mae: 2.9202 - budget_rec_accuracy: 0.5118 - budget_rec_loss: 0.7732 - campaign_score_loss: 121.0077 - campaign_score_mae: 8.5714 - loss: 341.7871 - performance_alerts_accuracy: 0.9566 - performance_alerts_loss: 0.1008 - roi_forecast_loss: 37.6554 - roi_forecast_mae: 3.1718 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.6992 - val_avg_perf_score_loss: 41.9620 - val_avg_perf_score_mae: 5.0062 - val_bid_strategy_accuracy: 0.2549 - val_bid_strategy_loss: 1.4076 - val_budget_dist_loss: 7.0772 - val_budget_dist_mae: 2.0751 - val_budget_realloc_loss: 10.1471 - val_budget_realloc_mae: 2.7586 - val_budget_rec_accuracy: 0.5199 - val_budget_rec_loss: 0.7165 - val_campaign_score_loss: 31.9725 - val_campaign_score_mae: 4.1421 - val_loss: 99.8835 - val_performance_alerts_accuracy: 0.9696 - val_performance_alerts_loss: 0.0802 - val_roi_forecast_loss: 5.6966 - val_roi_forecast_mae: 1.6861
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4984 - audience_exp_loss: 0.7606 - avg_perf_score_loss: 123.2658 - avg_perf_score_mae: 8.6930 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.4863 - budget_dist_loss: 34.8572 - budget_dist_mae: 4.5943 - budget_realloc_loss: 11.9048 - budget_realloc_mae: 2.9201 - budget_rec_accuracy: 0.5151 - budget_rec_loss: 0.7626 - campaign_score_loss: 113.0194 - campaign_score_mae: 8.2725 - loss: 322.4760 - performance_alerts_accuracy: 0.9573 - performance_alerts_loss: 0.0987 - roi_forecast_loss: 36.3790 - roi_forecast_mae: 2.9981 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.6955 - val_avg_perf_score_loss: 39.1277 - val_avg_perf_score_mae: 4.8651 - val_bid_strategy_accuracy: 0.2514 - val_bid_strategy_loss: 1.3948 - val_budget_dist_loss: 6.5666 - val_budget_dist_mae: 1.9585 - val_budget_realloc_loss: 10.1636 - val_budget_realloc_mae: 2.7591 - val_budget_rec_accuracy: 0.5248 - val_budget_rec_loss: 0.7141 - val_campaign_score_loss: 28.8603 - val_campaign_score_mae: 3.9609 - val_loss: 91.1229 - val_performance_alerts_accuracy: 0.9682 - val_performance_alerts_loss: 0.0834 - val_roi_forecast_loss: 3.4097 - val_roi_forecast_mae: 1.3745
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4953 - audience_exp_loss: 0.7519 - avg_perf_score_loss: 115.8961 - avg_perf_score_mae: 8.3600 - bid_strategy_accuracy: 0.2506 - bid_strategy_loss: 1.4752 - budget_dist_loss: 34.2490 - budget_dist_mae: 4.5536 - budget_realloc_loss: 11.7278 - budget_realloc_mae: 2.9026 - budget_rec_accuracy: 0.5147 - budget_rec_loss: 0.7569 - campaign_score_loss: 104.9635 - campaign_score_mae: 7.9183 - loss: 309.8983 - performance_alerts_accuracy: 0.9591 - performance_alerts_loss: 0.0965 - roi_forecast_loss: 39.8178 - roi_forecast_mae: 2.8822 - val_audience_exp_accuracy: 0.4952 - val_audience_exp_loss: 0.6985 - val_avg_perf_score_loss: 31.2788 - val_avg_perf_score_mae: 4.4423 - val_bid_strategy_accuracy: 0.2539 - val_bid_strategy_loss: 1.4193 - val_budget_dist_loss: 7.2023 - val_budget_dist_mae: 2.1474 - val_budget_realloc_loss: 10.1349 - val_budget_realloc_mae: 2.7584 - val_budget_rec_accuracy: 0.5253 - val_budget_rec_loss: 0.7176 - val_campaign_score_loss: 20.7313 - val_campaign_score_mae: 3.4396 - val_loss: 75.4823 - val_performance_alerts_accuracy: 0.9697 - val_performance_alerts_loss: 0.0830 - val_roi_forecast_loss: 2.8953 - val_roi_forecast_mae: 1.1668
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4998 - audience_exp_loss: 0.7434 - avg_perf_score_loss: 109.4354 - avg_perf_score_mae: 8.1165 - bid_strategy_accuracy: 0.2468 - bid_strategy_loss: 1.4666 - budget_dist_loss: 33.1931 - budget_dist_mae: 4.4889 - budget_realloc_loss: 11.6998 - budget_realloc_mae: 2.9031 - budget_rec_accuracy: 0.5144 - budget_rec_loss: 0.7501 - campaign_score_loss: 98.7883 - campaign_score_mae: 7.6632 - loss: 288.6606 - performance_alerts_accuracy: 0.9588 - performance_alerts_loss: 0.0966 - roi_forecast_loss: 32.5022 - roi_forecast_mae: 2.7456 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.7067 - val_avg_perf_score_loss: 28.9573 - val_avg_perf_score_mae: 4.2734 - val_bid_strategy_accuracy: 0.2502 - val_bid_strategy_loss: 1.4003 - val_budget_dist_loss: 7.2129 - val_budget_dist_mae: 2.1488 - val_budget_realloc_loss: 10.1898 - val_budget_realloc_mae: 2.7647 - val_budget_rec_accuracy: 0.5247 - val_budget_rec_loss: 0.7190 - val_campaign_score_loss: 19.2178 - val_campaign_score_mae: 3.2752 - val_loss: 71.9592 - val_performance_alerts_accuracy: 0.9708 - val_performance_alerts_loss: 0.0806 - val_roi_forecast_loss: 3.2962 - val_roi_forecast_mae: 1.4341
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4996 - audience_exp_loss: 0.7369 - avg_perf_score_loss: 102.7250 - avg_perf_score_mae: 7.8542 - bid_strategy_accuracy: 0.2505 - bid_strategy_loss: 1.4573 - budget_dist_loss: 31.7094 - budget_dist_mae: 4.3934 - budget_realloc_loss: 11.5167 - budget_realloc_mae: 2.8843 - budget_rec_accuracy: 0.5170 - budget_rec_loss: 0.7456 - campaign_score_loss: 92.5170 - campaign_score_mae: 7.4078 - loss: 273.6894 - performance_alerts_accuracy: 0.9607 - performance_alerts_loss: 0.0950 - roi_forecast_loss: 31.8836 - roi_forecast_mae: 2.6147 - val_audience_exp_accuracy: 0.4976 - val_audience_exp_loss: 0.7018 - val_avg_perf_score_loss: 24.3975 - val_avg_perf_score_mae: 3.9603 - val_bid_strategy_accuracy: 0.2501 - val_bid_strategy_loss: 1.4083 - val_budget_dist_loss: 5.6746 - val_budget_dist_mae: 1.8631 - val_budget_realloc_loss: 10.1002 - val_budget_realloc_mae: 2.7568 - val_budget_rec_accuracy: 0.5258 - val_budget_rec_loss: 0.8237 - val_campaign_score_loss: 14.4124 - val_campaign_score_mae: 2.8915 - val_loss: 59.7522 - val_performance_alerts_accuracy: 0.9718 - val_performance_alerts_loss: 0.0765 - val_roi_forecast_loss: 1.8788 - val_roi_forecast_mae: 1.0236
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4999 - audience_exp_loss: 0.7336 - avg_perf_score_loss: 100.3683 - avg_perf_score_mae: 7.7393 - bid_strategy_accuracy: 0.2497 - bid_strategy_loss: 1.4540 - budget_dist_loss: 30.9794 - budget_dist_mae: 4.3425 - budget_realloc_loss: 11.4683 - budget_realloc_mae: 2.8755 - budget_rec_accuracy: 0.5188 - budget_rec_loss: 0.7451 - campaign_score_loss: 90.0605 - campaign_score_mae: 7.2666 - loss: 267.0475 - performance_alerts_accuracy: 0.9615 - performance_alerts_loss: 0.0927 - roi_forecast_loss: 31.3186 - roi_forecast_mae: 2.4994 - val_audience_exp_accuracy: 0.5002 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 22.1925 - val_avg_perf_score_mae: 3.7930 - val_bid_strategy_accuracy: 0.2501 - val_bid_strategy_loss: 1.4213 - val_budget_dist_loss: 5.9811 - val_budget_dist_mae: 1.9249 - val_budget_realloc_loss: 10.1386 - val_budget_realloc_mae: 2.7604 - val_budget_rec_accuracy: 0.5249 - val_budget_rec_loss: 0.7431 - val_campaign_score_loss: 12.0228 - val_campaign_score_mae: 2.6533 - val_loss: 55.7209 - val_performance_alerts_accuracy: 0.9714 - val_performance_alerts_loss: 0.0774 - val_roi_forecast_loss: 2.0575 - val_roi_forecast_mae: 0.9263
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5025 - audience_exp_loss: 0.7282 - avg_perf_score_loss: 95.3919 - avg_perf_score_mae: 7.5404 - bid_strategy_accuracy: 0.2485 - bid_strategy_loss: 1.4471 - budget_dist_loss: 29.5094 - budget_dist_mae: 4.2376 - budget_realloc_loss: 11.3420 - budget_realloc_mae: 2.8685 - budget_rec_accuracy: 0.5168 - budget_rec_loss: 0.7413 - campaign_score_loss: 85.0549 - campaign_score_mae: 7.0411 - loss: 252.7013 - performance_alerts_accuracy: 0.9615 - performance_alerts_loss: 0.0922 - roi_forecast_loss: 28.2357 - roi_forecast_mae: 2.4273 - val_audience_exp_accuracy: 0.5002 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 20.8692 - val_avg_perf_score_mae: 3.6960 - val_bid_strategy_accuracy: 0.2494 - val_bid_strategy_loss: 1.3970 - val_budget_dist_loss: 4.9125 - val_budget_dist_mae: 1.7320 - val_budget_realloc_loss: 10.0893 - val_budget_realloc_mae: 2.7552 - val_budget_rec_accuracy: 0.5254 - val_budget_rec_loss: 0.7263 - val_campaign_score_loss: 10.8344 - val_campaign_score_mae: 2.5613 - val_loss: 51.8528 - val_performance_alerts_accuracy: 0.9746 - val_performance_alerts_loss: 0.0716 - val_roi_forecast_loss: 2.0117 - val_roi_forecast_mae: 0.9509
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5011 - audience_exp_loss: 0.7231 - avg_perf_score_loss: 96.0446 - avg_perf_score_mae: 7.5357 - bid_strategy_accuracy: 0.2487 - bid_strategy_loss: 1.4415 - budget_dist_loss: 28.0823 - budget_dist_mae: 4.1299 - budget_realloc_loss: 11.2615 - budget_realloc_mae: 2.8604 - budget_rec_accuracy: 0.5198 - budget_rec_loss: 0.7355 - campaign_score_loss: 85.8413 - campaign_score_mae: 7.0276 - loss: 254.9114 - performance_alerts_accuracy: 0.9633 - performance_alerts_loss: 0.0885 - roi_forecast_loss: 30.4924 - roi_forecast_mae: 2.4143 - val_audience_exp_accuracy: 0.4994 - val_audience_exp_loss: 0.7098 - val_avg_perf_score_loss: 19.3994 - val_avg_perf_score_mae: 3.5629 - val_bid_strategy_accuracy: 0.2481 - val_bid_strategy_loss: 1.4277 - val_budget_dist_loss: 5.4440 - val_budget_dist_mae: 1.8265 - val_budget_realloc_loss: 10.1926 - val_budget_realloc_mae: 2.7609 - val_budget_rec_accuracy: 0.5242 - val_budget_rec_loss: 0.7042 - val_campaign_score_loss: 9.5508 - val_campaign_score_mae: 2.4196 - val_loss: 48.8582 - val_performance_alerts_accuracy: 0.9721 - val_performance_alerts_loss: 0.0749 - val_roi_forecast_loss: 1.2245 - val_roi_forecast_mae: 0.7819
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.4998 - audience_exp_loss: 0.7217 - avg_perf_score_loss: 92.6280 - avg_perf_score_mae: 7.4081 - bid_strategy_accuracy: 0.2498 - bid_strategy_loss: 1.4372 - budget_dist_loss: 26.2379 - budget_dist_mae: 3.9792 - budget_realloc_loss: 11.1614 - budget_realloc_mae: 2.8506 - budget_rec_accuracy: 0.5196 - budget_rec_loss: 0.7312 - campaign_score_loss: 82.7571 - campaign_score_mae: 6.8999 - loss: 244.5755 - performance_alerts_accuracy: 0.9646 - performance_alerts_loss: 0.0874 - roi_forecast_loss: 28.6422 - roi_forecast_mae: 2.3757 - val_audience_exp_accuracy: 0.4984 - val_audience_exp_loss: 0.6964 - val_avg_perf_score_loss: 18.7169 - val_avg_perf_score_mae: 3.4944 - val_bid_strategy_accuracy: 0.2482 - val_bid_strategy_loss: 1.3933 - val_budget_dist_loss: 7.4283 - val_budget_dist_mae: 2.2722 - val_budget_realloc_loss: 10.1076 - val_budget_realloc_mae: 2.7561 - val_budget_rec_accuracy: 0.5232 - val_budget_rec_loss: 0.7078 - val_campaign_score_loss: 8.2998 - val_campaign_score_mae: 2.1738 - val_loss: 49.0828 - val_performance_alerts_accuracy: 0.9722 - val_performance_alerts_loss: 0.0744 - val_roi_forecast_loss: 1.5065 - val_roi_forecast_mae: 0.8610
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4987 - audience_exp_loss: 0.7194 - avg_perf_score_loss: 88.5695 - avg_perf_score_mae: 7.2429 - bid_strategy_accuracy: 0.2510 - bid_strategy_loss: 1.4364 - budget_dist_loss: 24.7630 - budget_dist_mae: 3.8543 - budget_realloc_loss: 11.0851 - budget_realloc_mae: 2.8454 - budget_rec_accuracy: 0.5212 - budget_rec_loss: 0.7249 - campaign_score_loss: 78.3921 - campaign_score_mae: 6.7202 - loss: 232.6113 - performance_alerts_accuracy: 0.9662 - performance_alerts_loss: 0.0844 - roi_forecast_loss: 26.8029 - roi_forecast_mae: 2.2910 - val_audience_exp_accuracy: 0.4985 - val_audience_exp_loss: 0.6954 - val_avg_perf_score_loss: 19.9394 - val_avg_perf_score_mae: 3.6077 - val_bid_strategy_accuracy: 0.2471 - val_bid_strategy_loss: 1.3922 - val_budget_dist_loss: 10.8019 - val_budget_dist_mae: 2.8210 - val_budget_realloc_loss: 10.4564 - val_budget_realloc_mae: 2.7865 - val_budget_rec_accuracy: 0.5307 - val_budget_rec_loss: 0.7026 - val_campaign_score_loss: 9.0838 - val_campaign_score_mae: 2.2706 - val_loss: 54.9630 - val_performance_alerts_accuracy: 0.9743 - val_performance_alerts_loss: 0.0692 - val_roi_forecast_loss: 1.5044 - val_roi_forecast_mae: 0.9692
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5020 - audience_exp_loss: 0.7152 - avg_perf_score_loss: 86.9902 - avg_perf_score_mae: 7.1612 - bid_strategy_accuracy: 0.2494 - bid_strategy_loss: 1.4288 - budget_dist_loss: 23.4423 - budget_dist_mae: 3.7403 - budget_realloc_loss: 10.9355 - budget_realloc_mae: 2.8307 - budget_rec_accuracy: 0.5221 - budget_rec_loss: 0.7285 - campaign_score_loss: 76.2832 - campaign_score_mae: 6.6188 - loss: 226.9810 - performance_alerts_accuracy: 0.9673 - performance_alerts_loss: 0.0826 - roi_forecast_loss: 26.4432 - roi_forecast_mae: 2.2252 - val_audience_exp_accuracy: 0.4946 - val_audience_exp_loss: 0.6949 - val_avg_perf_score_loss: 18.8872 - val_avg_perf_score_mae: 3.5203 - val_bid_strategy_accuracy: 0.2462 - val_bid_strategy_loss: 1.4009 - val_budget_dist_loss: 13.5700 - val_budget_dist_mae: 3.1803 - val_budget_realloc_loss: 10.4613 - val_budget_realloc_mae: 2.7883 - val_budget_rec_accuracy: 0.5293 - val_budget_rec_loss: 0.7068 - val_campaign_score_loss: 8.7452 - val_campaign_score_mae: 2.2814 - val_loss: 56.7524 - val_performance_alerts_accuracy: 0.9732 - val_performance_alerts_loss: 0.0730 - val_roi_forecast_loss: 1.9058 - val_roi_forecast_mae: 0.9072
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5004 - audience_exp_loss: 0.7136 - avg_perf_score_loss: 83.4217 - avg_perf_score_mae: 6.9901 - bid_strategy_accuracy: 0.2496 - bid_strategy_loss: 1.4248 - budget_dist_loss: 22.5364 - budget_dist_mae: 3.6537 - budget_realloc_loss: 10.9116 - budget_realloc_mae: 2.8281 - budget_rec_accuracy: 0.5220 - budget_rec_loss: 0.7227 - campaign_score_loss: 72.9229 - campaign_score_mae: 6.4379 - loss: 220.7493 - performance_alerts_accuracy: 0.9671 - performance_alerts_loss: 0.0825 - roi_forecast_loss: 27.9091 - roi_forecast_mae: 2.2155 - val_audience_exp_accuracy: 0.4989 - val_audience_exp_loss: 0.6946 - val_avg_perf_score_loss: 33.2505 - val_avg_perf_score_mae: 4.7478 - val_bid_strategy_accuracy: 0.2471 - val_bid_strategy_loss: 1.4024 - val_budget_dist_loss: 21.4711 - val_budget_dist_mae: 4.1435 - val_budget_realloc_loss: 11.4640 - val_budget_realloc_mae: 2.8829 - val_budget_rec_accuracy: 0.5274 - val_budget_rec_loss: 0.7225 - val_campaign_score_loss: 25.5270 - val_campaign_score_mae: 4.5037 - val_loss: 100.5189 - val_performance_alerts_accuracy: 0.9758 - val_performance_alerts_loss: 0.0685 - val_roi_forecast_loss: 5.4032 - val_roi_forecast_mae: 2.2063
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4972 - audience_exp_loss: 0.7129 - avg_perf_score_loss: 77.9090 - avg_perf_score_mae: 6.7931 - bid_strategy_accuracy: 0.2539 - bid_strategy_loss: 1.4243 - budget_dist_loss: 20.9274 - budget_dist_mae: 3.5312 - budget_realloc_loss: 10.7882 - budget_realloc_mae: 2.8167 - budget_rec_accuracy: 0.5218 - budget_rec_loss: 0.7271 - campaign_score_loss: 67.4971 - campaign_score_mae: 6.2324 - loss: 207.5072 - performance_alerts_accuracy: 0.9677 - performance_alerts_loss: 0.0823 - roi_forecast_loss: 27.0920 - roi_forecast_mae: 2.2196 - val_audience_exp_accuracy: 0.4979 - val_audience_exp_loss: 0.6951 - val_avg_perf_score_loss: 34.4052 - val_avg_perf_score_mae: 4.8163 - val_bid_strategy_accuracy: 0.2491 - val_bid_strategy_loss: 1.4271 - val_budget_dist_loss: 28.2017 - val_budget_dist_mae: 4.7638 - val_budget_realloc_loss: 12.2376 - val_budget_realloc_mae: 2.9527 - val_budget_rec_accuracy: 0.5271 - val_budget_rec_loss: 0.7098 - val_campaign_score_loss: 23.8442 - val_campaign_score_mae: 4.2287 - val_loss: 107.1406 - val_performance_alerts_accuracy: 0.9732 - val_performance_alerts_loss: 0.0750 - val_roi_forecast_loss: 4.9593 - val_roi_forecast_mae: 1.2987
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5005 - audience_exp_loss: 0.7116 - avg_perf_score_loss: 72.6470 - avg_perf_score_mae: 6.5714 - bid_strategy_accuracy: 0.2456 - bid_strategy_loss: 1.4230 - budget_dist_loss: 20.2198 - budget_dist_mae: 3.4755 - budget_realloc_loss: 10.7940 - budget_realloc_mae: 2.8186 - budget_rec_accuracy: 0.5214 - budget_rec_loss: 0.7229 - campaign_score_loss: 62.3130 - campaign_score_mae: 5.9834 - loss: 194.3619 - performance_alerts_accuracy: 0.9670 - performance_alerts_loss: 0.0832 - roi_forecast_loss: 25.4984 - roi_forecast_mae: 2.1631 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.6943 - val_avg_perf_score_loss: 57.5321 - val_avg_perf_score_mae: 6.6162 - val_bid_strategy_accuracy: 0.2498 - val_bid_strategy_loss: 1.3973 - val_budget_dist_loss: 40.9572 - val_budget_dist_mae: 5.8475 - val_budget_realloc_loss: 13.7928 - val_budget_realloc_mae: 3.0912 - val_budget_rec_accuracy: 0.5303 - val_budget_rec_loss: 0.7186 - val_campaign_score_loss: 49.6111 - val_campaign_score_mae: 6.6475 - val_loss: 168.6404 - val_performance_alerts_accuracy: 0.9753 - val_performance_alerts_loss: 0.0691 - val_roi_forecast_loss: 3.0424 - val_roi_forecast_mae: 1.3326
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5014 - audience_exp_loss: 0.7102 - avg_perf_score_loss: 68.7792 - avg_perf_score_mae: 6.3785 - bid_strategy_accuracy: 0.2528 - bid_strategy_loss: 1.4158 - budget_dist_loss: 19.8837 - budget_dist_mae: 3.4435 - budget_realloc_loss: 10.7545 - budget_realloc_mae: 2.8162 - budget_rec_accuracy: 0.5232 - budget_rec_loss: 0.7246 - campaign_score_loss: 58.3212 - campaign_score_mae: 5.7761 - loss: 186.3496 - performance_alerts_accuracy: 0.9678 - performance_alerts_loss: 0.0820 - roi_forecast_loss: 25.3966 - roi_forecast_mae: 2.1080 - val_audience_exp_accuracy: 0.4956 - val_audience_exp_loss: 0.6946 - val_avg_perf_score_loss: 92.1982 - val_avg_perf_score_mae: 8.5571 - val_bid_strategy_accuracy: 0.2482 - val_bid_strategy_loss: 1.4175 - val_budget_dist_loss: 54.4347 - val_budget_dist_mae: 6.8442 - val_budget_realloc_loss: 15.3718 - val_budget_realloc_mae: 3.2380 - val_budget_rec_accuracy: 0.5290 - val_budget_rec_loss: 0.7044 - val_campaign_score_loss: 88.0945 - val_campaign_score_mae: 8.7883 - val_loss: 262.6412 - val_performance_alerts_accuracy: 0.9746 - val_performance_alerts_loss: 0.0706 - val_roi_forecast_loss: 8.3689 - val_roi_forecast_mae: 2.5508
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4997 - audience_exp_loss: 0.7073 - avg_perf_score_loss: 64.4405 - avg_perf_score_mae: 6.1956 - bid_strategy_accuracy: 0.2500 - bid_strategy_loss: 1.4154 - budget_dist_loss: 19.7362 - budget_dist_mae: 3.4284 - budget_realloc_loss: 10.7902 - budget_realloc_mae: 2.8188 - budget_rec_accuracy: 0.5221 - budget_rec_loss: 0.7232 - campaign_score_loss: 54.0811 - campaign_score_mae: 5.5656 - loss: 176.7963 - performance_alerts_accuracy: 0.9673 - performance_alerts_loss: 0.0830 - roi_forecast_loss: 24.6952 - roi_forecast_mae: 2.1637 - val_audience_exp_accuracy: 0.4952 - val_audience_exp_loss: 0.6944 - val_avg_perf_score_loss: 105.1590 - val_avg_perf_score_mae: 9.3043 - val_bid_strategy_accuracy: 0.2524 - val_bid_strategy_loss: 1.3923 - val_budget_dist_loss: 49.5741 - val_budget_dist_mae: 6.4861 - val_budget_realloc_loss: 13.8292 - val_budget_realloc_mae: 3.0943 - val_budget_rec_accuracy: 0.5259 - val_budget_rec_loss: 0.7075 - val_campaign_score_loss: 93.5524 - val_campaign_score_mae: 9.1583 - val_loss: 271.2352 - val_performance_alerts_accuracy: 0.9743 - val_performance_alerts_loss: 0.0717 - val_roi_forecast_loss: 5.2390 - val_roi_forecast_mae: 1.7001
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4998 - audience_exp_loss: 0.7079 - avg_perf_score_loss: 60.4020 - avg_perf_score_mae: 6.0095 - bid_strategy_accuracy: 0.2527 - bid_strategy_loss: 1.4139 - budget_dist_loss: 19.5088 - budget_dist_mae: 3.4046 - budget_realloc_loss: 10.8237 - budget_realloc_mae: 2.8204 - budget_rec_accuracy: 0.5230 - budget_rec_loss: 0.7240 - campaign_score_loss: 49.9073 - campaign_score_mae: 5.3624 - loss: 168.9741 - performance_alerts_accuracy: 0.9669 - performance_alerts_loss: 0.0835 - roi_forecast_loss: 25.1964 - roi_forecast_mae: 2.1820 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.7213 - val_avg_perf_score_loss: 150.5749 - val_avg_perf_score_mae: 11.3863 - val_bid_strategy_accuracy: 0.2504 - val_bid_strategy_loss: 1.3935 - val_budget_dist_loss: 65.1050 - val_budget_dist_mae: 7.5049 - val_budget_realloc_loss: 16.4567 - val_budget_realloc_mae: 3.3353 - val_budget_rec_accuracy: 0.5258 - val_budget_rec_loss: 0.7426 - val_campaign_score_loss: 135.5328 - val_campaign_score_mae: 11.1426 - val_loss: 373.0100 - val_performance_alerts_accuracy: 0.9735 - val_performance_alerts_loss: 0.0729 - val_roi_forecast_loss: 1.5077 - val_roi_forecast_mae: 0.9051
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5019 - audience_exp_loss: 0.7059 - avg_perf_score_loss: 57.5058 - avg_perf_score_mae: 5.8792 - bid_strategy_accuracy: 0.2524 - bid_strategy_loss: 1.4188 - budget_dist_loss: 18.9704 - budget_dist_mae: 3.3657 - budget_realloc_loss: 10.8197 - budget_realloc_mae: 2.8223 - budget_rec_accuracy: 0.5238 - budget_rec_loss: 0.7249 - campaign_score_loss: 46.9717 - campaign_score_mae: 5.2007 - loss: 161.3765 - performance_alerts_accuracy: 0.9677 - performance_alerts_loss: 0.0836 - roi_forecast_loss: 24.0070 - roi_forecast_mae: 2.1314 - val_audience_exp_accuracy: 0.4935 - val_audience_exp_loss: 0.6954 - val_avg_perf_score_loss: 147.7536 - val_avg_perf_score_mae: 11.1504 - val_bid_strategy_accuracy: 0.2567 - val_bid_strategy_loss: 1.4076 - val_budget_dist_loss: 65.4907 - val_budget_dist_mae: 7.5170 - val_budget_realloc_loss: 17.3905 - val_budget_realloc_mae: 3.4217 - val_budget_rec_accuracy: 0.5293 - val_budget_rec_loss: 0.7163 - val_campaign_score_loss: 140.2070 - val_campaign_score_mae: 11.2027 - val_loss: 379.5383 - val_performance_alerts_accuracy: 0.9745 - val_performance_alerts_loss: 0.0729 - val_roi_forecast_loss: 4.6055 - val_roi_forecast_mae: 1.4711
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4978 - audience_exp_loss: 0.7063 - avg_perf_score_loss: 55.7210 - avg_perf_score_mae: 5.7746 - bid_strategy_accuracy: 0.2505 - bid_strategy_loss: 1.4125 - budget_dist_loss: 19.1176 - budget_dist_mae: 3.3760 - budget_realloc_loss: 10.8374 - budget_realloc_mae: 2.8238 - budget_rec_accuracy: 0.5241 - budget_rec_loss: 0.7205 - campaign_score_loss: 45.5706 - campaign_score_mae: 5.1100 - loss: 157.3249 - performance_alerts_accuracy: 0.9673 - performance_alerts_loss: 0.0831 - roi_forecast_loss: 23.2049 - roi_forecast_mae: 2.0337 - val_audience_exp_accuracy: 0.4972 - val_audience_exp_loss: 0.6985 - val_avg_perf_score_loss: 179.5219 - val_avg_perf_score_mae: 12.5494 - val_bid_strategy_accuracy: 0.2563 - val_bid_strategy_loss: 1.4037 - val_budget_dist_loss: 69.7436 - val_budget_dist_mae: 7.8811 - val_budget_realloc_loss: 15.8708 - val_budget_realloc_mae: 3.2819 - val_budget_rec_accuracy: 0.5260 - val_budget_rec_loss: 0.7106 - val_campaign_score_loss: 169.9778 - val_campaign_score_mae: 12.5434 - val_loss: 447.1061 - val_performance_alerts_accuracy: 0.9723 - val_performance_alerts_loss: 0.0762 - val_roi_forecast_loss: 8.1553 - val_roi_forecast_mae: 2.4695
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4980 - audience_exp_loss: 0.7055 - avg_perf_score_loss: 54.6819 - avg_perf_score_mae: 5.6963 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.4159 - budget_dist_loss: 18.6884 - budget_dist_mae: 3.3391 - budget_realloc_loss: 10.8174 - budget_realloc_mae: 2.8233 - budget_rec_accuracy: 0.5238 - budget_rec_loss: 0.7210 - campaign_score_loss: 44.1523 - campaign_score_mae: 4.9978 - loss: 151.7931 - performance_alerts_accuracy: 0.9667 - performance_alerts_loss: 0.0841 - roi_forecast_loss: 20.6085 - roi_forecast_mae: 1.9615 - val_audience_exp_accuracy: 0.5000 - val_audience_exp_loss: 0.7021 - val_avg_perf_score_loss: 204.1370 - val_avg_perf_score_mae: 13.1372 - val_bid_strategy_accuracy: 0.2499 - val_bid_strategy_loss: 1.4015 - val_budget_dist_loss: 72.0076 - val_budget_dist_mae: 8.0210 - val_budget_realloc_loss: 16.5639 - val_budget_realloc_mae: 3.3454 - val_budget_rec_accuracy: 0.5280 - val_budget_rec_loss: 0.7087 - val_campaign_score_loss: 192.5743 - val_campaign_score_mae: 13.0393 - val_loss: 497.5067 - val_performance_alerts_accuracy: 0.9722 - val_performance_alerts_loss: 0.0771 - val_roi_forecast_loss: 8.2763 - val_roi_forecast_mae: 2.3801
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4999 - audience_exp_loss: 0.7049 - avg_perf_score_loss: 53.9957 - avg_perf_score_mae: 5.6591 - bid_strategy_accuracy: 0.2507 - bid_strategy_loss: 1.4117 - budget_dist_loss: 18.6261 - budget_dist_mae: 3.3440 - budget_realloc_loss: 10.8014 - budget_realloc_mae: 2.8214 - budget_rec_accuracy: 0.5229 - budget_rec_loss: 0.7253 - campaign_score_loss: 43.4827 - campaign_score_mae: 4.9663 - loss: 154.0461 - performance_alerts_accuracy: 0.9663 - performance_alerts_loss: 0.0850 - roi_forecast_loss: 24.1045 - roi_forecast_mae: 2.0954 - val_audience_exp_accuracy: 0.4906 - val_audience_exp_loss: 0.6944 - val_avg_perf_score_loss: 186.8133 - val_avg_perf_score_mae: 12.5719 - val_bid_strategy_accuracy: 0.2508 - val_bid_strategy_loss: 1.4270 - val_budget_dist_loss: 68.5443 - val_budget_dist_mae: 7.7416 - val_budget_realloc_loss: 16.8058 - val_budget_realloc_mae: 3.3677 - val_budget_rec_accuracy: 0.5276 - val_budget_rec_loss: 0.7138 - val_campaign_score_loss: 174.0754 - val_campaign_score_mae: 12.3857 - val_loss: 456.8413 - val_performance_alerts_accuracy: 0.9720 - val_performance_alerts_loss: 0.0764 - val_roi_forecast_loss: 6.7107 - val_roi_forecast_mae: 1.2854
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.7038 - avg_perf_score_loss: 50.8562 - avg_perf_score_mae: 5.5323 - bid_strategy_accuracy: 0.2525 - bid_strategy_loss: 1.4135 - budget_dist_loss: 18.4142 - budget_dist_mae: 3.3148 - budget_realloc_loss: 10.8000 - budget_realloc_mae: 2.8188 - budget_rec_accuracy: 0.5248 - budget_rec_loss: 0.7247 - campaign_score_loss: 40.3547 - campaign_score_mae: 4.8213 - loss: 144.0735 - performance_alerts_accuracy: 0.9664 - performance_alerts_loss: 0.0843 - roi_forecast_loss: 20.9275 - roi_forecast_mae: 1.9577 - val_audience_exp_accuracy: 0.4941 - val_audience_exp_loss: 0.6944 - val_avg_perf_score_loss: 243.6859 - val_avg_perf_score_mae: 14.5361 - val_bid_strategy_accuracy: 0.2504 - val_bid_strategy_loss: 1.3929 - val_budget_dist_loss: 71.0798 - val_budget_dist_mae: 7.9163 - val_budget_realloc_loss: 16.0544 - val_budget_realloc_mae: 3.3004 - val_budget_rec_accuracy: 0.5271 - val_budget_rec_loss: 0.7196 - val_campaign_score_loss: 234.5231 - val_campaign_score_mae: 14.5180 - val_loss: 582.0309 - val_performance_alerts_accuracy: 0.9707 - val_performance_alerts_loss: 0.0807 - val_roi_forecast_loss: 12.0765 - val_roi_forecast_mae: 2.3590
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5015 - audience_exp_loss: 0.7020 - avg_perf_score_loss: 50.0303 - avg_perf_score_mae: 5.4661 - bid_strategy_accuracy: 0.2515 - bid_strategy_loss: 1.4080 - budget_dist_loss: 18.2819 - budget_dist_mae: 3.3034 - budget_realloc_loss: 10.8464 - budget_realloc_mae: 2.8252 - budget_rec_accuracy: 0.5226 - budget_rec_loss: 0.7234 - campaign_score_loss: 39.6524 - campaign_score_mae: 4.7627 - loss: 141.6292 - performance_alerts_accuracy: 0.9661 - performance_alerts_loss: 0.0848 - roi_forecast_loss: 19.8179 - roi_forecast_mae: 1.9350 - val_audience_exp_accuracy: 0.4920 - val_audience_exp_loss: 0.6946 - val_avg_perf_score_loss: 245.4350 - val_avg_perf_score_mae: 14.4474 - val_bid_strategy_accuracy: 0.2507 - val_bid_strategy_loss: 1.4071 - val_budget_dist_loss: 73.8009 - val_budget_dist_mae: 8.0956 - val_budget_realloc_loss: 15.7275 - val_budget_realloc_mae: 3.2706 - val_budget_rec_accuracy: 0.5258 - val_budget_rec_loss: 0.7128 - val_campaign_score_loss: 237.5564 - val_campaign_score_mae: 14.4479 - val_loss: 586.4368 - val_performance_alerts_accuracy: 0.9714 - val_performance_alerts_loss: 0.0791 - val_roi_forecast_loss: 9.6593 - val_roi_forecast_mae: 2.0438
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5015 - audience_exp_loss: 0.7025 - avg_perf_score_loss: 48.8010 - avg_perf_score_mae: 5.3853 - bid_strategy_accuracy: 0.2495 - bid_strategy_loss: 1.4079 - budget_dist_loss: 18.0288 - budget_dist_mae: 3.2773 - budget_realloc_loss: 10.8188 - budget_realloc_mae: 2.8244 - budget_rec_accuracy: 0.5237 - budget_rec_loss: 0.7240 - campaign_score_loss: 38.5999 - campaign_score_mae: 4.6759 - loss: 139.8522 - performance_alerts_accuracy: 0.9664 - performance_alerts_loss: 0.0853 - roi_forecast_loss: 20.6041 - roi_forecast_mae: 1.8843 - val_audience_exp_accuracy: 0.4958 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 241.8820 - val_avg_perf_score_mae: 14.2559 - val_bid_strategy_accuracy: 0.2510 - val_bid_strategy_loss: 1.3902 - val_budget_dist_loss: 69.7692 - val_budget_dist_mae: 7.8071 - val_budget_realloc_loss: 16.6175 - val_budget_realloc_mae: 3.3506 - val_budget_rec_accuracy: 0.5301 - val_budget_rec_loss: 0.7083 - val_campaign_score_loss: 235.5157 - val_campaign_score_mae: 14.3351 - val_loss: 576.7169 - val_performance_alerts_accuracy: 0.9730 - val_performance_alerts_loss: 0.0774 - val_roi_forecast_loss: 8.6749 - val_roi_forecast_mae: 2.6321
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4990 - audience_exp_loss: 0.7051 - avg_perf_score_loss: 48.2621 - avg_perf_score_mae: 5.3794 - bid_strategy_accuracy: 0.2485 - bid_strategy_loss: 1.4101 - budget_dist_loss: 17.8532 - budget_dist_mae: 3.2599 - budget_realloc_loss: 10.8141 - budget_realloc_mae: 2.8201 - budget_rec_accuracy: 0.5219 - budget_rec_loss: 0.7230 - campaign_score_loss: 38.0155 - campaign_score_mae: 4.6533 - loss: 136.8229 - performance_alerts_accuracy: 0.9672 - performance_alerts_loss: 0.0846 - roi_forecast_loss: 18.8706 - roi_forecast_mae: 1.8724 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.6951 - val_avg_perf_score_loss: 301.4192 - val_avg_perf_score_mae: 16.3580 - val_bid_strategy_accuracy: 0.2544 - val_bid_strategy_loss: 1.3988 - val_budget_dist_loss: 67.6685 - val_budget_dist_mae: 7.6879 - val_budget_realloc_loss: 15.5606 - val_budget_realloc_mae: 3.2566 - val_budget_rec_accuracy: 0.5242 - val_budget_rec_loss: 0.7228 - val_campaign_score_loss: 285.5711 - val_campaign_score_mae: 16.1587 - val_loss: 677.5251 - val_performance_alerts_accuracy: 0.9712 - val_performance_alerts_loss: 0.0814 - val_roi_forecast_loss: 3.0515 - val_roi_forecast_mae: 1.5662
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4984 - audience_exp_loss: 0.7028 - avg_perf_score_loss: 46.3434 - avg_perf_score_mae: 5.2755 - bid_strategy_accuracy: 0.2536 - bid_strategy_loss: 1.4080 - budget_dist_loss: 17.5283 - budget_dist_mae: 3.2347 - budget_realloc_loss: 10.7808 - budget_realloc_mae: 2.8186 - budget_rec_accuracy: 0.5222 - budget_rec_loss: 0.7226 - campaign_score_loss: 36.1521 - campaign_score_mae: 4.5516 - loss: 134.9485 - performance_alerts_accuracy: 0.9669 - performance_alerts_loss: 0.0845 - roi_forecast_loss: 21.2711 - roi_forecast_mae: 1.8929 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.6989 - val_avg_perf_score_loss: 251.2515 - val_avg_perf_score_mae: 14.2808 - val_bid_strategy_accuracy: 0.2471 - val_bid_strategy_loss: 1.4098 - val_budget_dist_loss: 64.2912 - val_budget_dist_mae: 7.4150 - val_budget_realloc_loss: 16.5275 - val_budget_realloc_mae: 3.3430 - val_budget_rec_accuracy: 0.5265 - val_budget_rec_loss: 0.7103 - val_campaign_score_loss: 251.2310 - val_campaign_score_mae: 14.5626 - val_loss: 589.2938 - val_performance_alerts_accuracy: 0.9729 - val_performance_alerts_loss: 0.0761 - val_roi_forecast_loss: 1.7442 - val_roi_forecast_mae: 0.9777
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4997 - audience_exp_loss: 0.7021 - avg_perf_score_loss: 46.4186 - avg_perf_score_mae: 5.2702 - bid_strategy_accuracy: 0.2510 - bid_strategy_loss: 1.4061 - budget_dist_loss: 17.2427 - budget_dist_mae: 3.2043 - budget_realloc_loss: 10.7678 - budget_realloc_mae: 2.8164 - budget_rec_accuracy: 0.5222 - budget_rec_loss: 0.7240 - campaign_score_loss: 36.1631 - campaign_score_mae: 4.5324 - loss: 134.1589 - performance_alerts_accuracy: 0.9672 - performance_alerts_loss: 0.0846 - roi_forecast_loss: 20.5520 - roi_forecast_mae: 1.8872 - val_audience_exp_accuracy: 0.4978 - val_audience_exp_loss: 0.6948 - val_avg_perf_score_loss: 302.9209 - val_avg_perf_score_mae: 15.9869 - val_bid_strategy_accuracy: 0.2508 - val_bid_strategy_loss: 1.3966 - val_budget_dist_loss: 66.1585 - val_budget_dist_mae: 7.5935 - val_budget_realloc_loss: 15.7624 - val_budget_realloc_mae: 3.2736 - val_budget_rec_accuracy: 0.5236 - val_budget_rec_loss: 0.7125 - val_campaign_score_loss: 293.0825 - val_campaign_score_mae: 15.9424 - val_loss: 689.5815 - val_performance_alerts_accuracy: 0.9727 - val_performance_alerts_loss: 0.0780 - val_roi_forecast_loss: 7.4121 - val_roi_forecast_mae: 1.9534
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5023 - audience_exp_loss: 0.7008 - avg_perf_score_loss: 44.6239 - avg_perf_score_mae: 5.1859 - bid_strategy_accuracy: 0.2500 - bid_strategy_loss: 1.4079 - budget_dist_loss: 16.9717 - budget_dist_mae: 3.1825 - budget_realloc_loss: 10.7128 - budget_realloc_mae: 2.8107 - budget_rec_accuracy: 0.5217 - budget_rec_loss: 0.7232 - campaign_score_loss: 34.3856 - campaign_score_mae: 4.4388 - loss: 128.6490 - performance_alerts_accuracy: 0.9668 - performance_alerts_loss: 0.0838 - roi_forecast_loss: 19.1278 - roi_forecast_mae: 1.8417 - val_audience_exp_accuracy: 0.5020 - val_audience_exp_loss: 0.6938 - val_avg_perf_score_loss: 316.8452 - val_avg_perf_score_mae: 16.4700 - val_bid_strategy_accuracy: 0.2512 - val_bid_strategy_loss: 1.3906 - val_budget_dist_loss: 58.8658 - val_budget_dist_mae: 7.1813 - val_budget_realloc_loss: 13.8201 - val_budget_realloc_mae: 3.0960 - val_budget_rec_accuracy: 0.5246 - val_budget_rec_loss: 0.7178 - val_campaign_score_loss: 323.8463 - val_campaign_score_mae: 16.8841 - val_loss: 724.9340 - val_performance_alerts_accuracy: 0.9715 - val_performance_alerts_loss: 0.0809 - val_roi_forecast_loss: 7.3466 - val_roi_forecast_mae: 1.6494
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5017 - audience_exp_loss: 0.7012 - avg_perf_score_loss: 44.0755 - avg_perf_score_mae: 5.1554 - bid_strategy_accuracy: 0.2508 - bid_strategy_loss: 1.4065 - budget_dist_loss: 16.7639 - budget_dist_mae: 3.1670 - budget_realloc_loss: 10.6592 - budget_realloc_mae: 2.8068 - budget_rec_accuracy: 0.5245 - budget_rec_loss: 0.7213 - campaign_score_loss: 33.6435 - campaign_score_mae: 4.3927 - loss: 124.6162 - performance_alerts_accuracy: 0.9670 - performance_alerts_loss: 0.0839 - roi_forecast_loss: 16.5701 - roi_forecast_mae: 1.7544 - val_audience_exp_accuracy: 0.4978 - val_audience_exp_loss: 0.6952 - val_avg_perf_score_loss: 339.6476 - val_avg_perf_score_mae: 17.1776 - val_bid_strategy_accuracy: 0.2510 - val_bid_strategy_loss: 1.3937 - val_budget_dist_loss: 58.6037 - val_budget_dist_mae: 7.1022 - val_budget_realloc_loss: 14.8011 - val_budget_realloc_mae: 3.1871 - val_budget_rec_accuracy: 0.5210 - val_budget_rec_loss: 0.7256 - val_campaign_score_loss: 335.4982 - val_campaign_score_mae: 17.2989 - val_loss: 761.6450 - val_performance_alerts_accuracy: 0.9670 - val_performance_alerts_loss: 0.0872 - val_roi_forecast_loss: 9.0800 - val_roi_forecast_mae: 2.4330
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5001 - audience_exp_loss: 0.7017 - avg_perf_score_loss: 44.2340 - avg_perf_score_mae: 5.1498 - bid_strategy_accuracy: 0.2498 - bid_strategy_loss: 1.4034 - budget_dist_loss: 16.4401 - budget_dist_mae: 3.1307 - budget_realloc_loss: 10.6839 - budget_realloc_mae: 2.8089 - budget_rec_accuracy: 0.5204 - budget_rec_loss: 0.7240 - campaign_score_loss: 34.1074 - campaign_score_mae: 4.4026 - loss: 128.2607 - performance_alerts_accuracy: 0.9670 - performance_alerts_loss: 0.0839 - roi_forecast_loss: 19.7927 - roi_forecast_mae: 1.8222 - val_audience_exp_accuracy: 0.4951 - val_audience_exp_loss: 0.6960 - val_avg_perf_score_loss: 303.8535 - val_avg_perf_score_mae: 16.1600 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.4037 - val_budget_dist_loss: 61.6133 - val_budget_dist_mae: 7.3573 - val_budget_realloc_loss: 14.3411 - val_budget_realloc_mae: 3.1457 - val_budget_rec_accuracy: 0.5207 - val_budget_rec_loss: 0.7195 - val_campaign_score_loss: 299.3313 - val_campaign_score_mae: 16.2839 - val_loss: 688.3120 - val_performance_alerts_accuracy: 0.9657 - val_performance_alerts_loss: 0.0888 - val_roi_forecast_loss: 5.4184 - val_roi_forecast_mae: 2.0579
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5023 - audience_exp_loss: 0.6999 - avg_perf_score_loss: 42.8843 - avg_perf_score_mae: 5.0944 - bid_strategy_accuracy: 0.2524 - bid_strategy_loss: 1.4035 - budget_dist_loss: 16.0310 - budget_dist_mae: 3.1050 - budget_realloc_loss: 10.6597 - budget_realloc_mae: 2.8084 - budget_rec_accuracy: 0.5226 - budget_rec_loss: 0.7200 - campaign_score_loss: 32.6951 - campaign_score_mae: 4.3259 - loss: 122.2543 - performance_alerts_accuracy: 0.9683 - performance_alerts_loss: 0.0831 - roi_forecast_loss: 16.9752 - roi_forecast_mae: 1.7100 - val_audience_exp_accuracy: 0.4985 - val_audience_exp_loss: 0.6940 - val_avg_perf_score_loss: 283.7053 - val_avg_perf_score_mae: 15.6037 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.4117 - val_budget_dist_loss: 49.6342 - val_budget_dist_mae: 6.6185 - val_budget_realloc_loss: 13.9208 - val_budget_realloc_mae: 3.1064 - val_budget_rec_accuracy: 0.5250 - val_budget_rec_loss: 0.7129 - val_campaign_score_loss: 261.0589 - val_campaign_score_mae: 15.1945 - val_loss: 625.1580 - val_performance_alerts_accuracy: 0.9714 - val_performance_alerts_loss: 0.0798 - val_roi_forecast_loss: 12.6129 - val_roi_forecast_mae: 1.5621
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.7004 - avg_perf_score_loss: 42.9205 - avg_perf_score_mae: 5.0803 - bid_strategy_accuracy: 0.2493 - bid_strategy_loss: 1.4043 - budget_dist_loss: 15.7942 - budget_dist_mae: 3.0702 - budget_realloc_loss: 10.6721 - budget_realloc_mae: 2.8073 - budget_rec_accuracy: 0.5236 - budget_rec_loss: 0.7207 - campaign_score_loss: 32.8649 - campaign_score_mae: 4.3223 - loss: 123.5432 - performance_alerts_accuracy: 0.9676 - performance_alerts_loss: 0.0832 - roi_forecast_loss: 18.2700 - roi_forecast_mae: 1.7167 - val_audience_exp_accuracy: 0.4994 - val_audience_exp_loss: 0.7026 - val_avg_perf_score_loss: 249.4897 - val_avg_perf_score_mae: 14.6677 - val_bid_strategy_accuracy: 0.2498 - val_bid_strategy_loss: 1.3959 - val_budget_dist_loss: 44.4606 - val_budget_dist_mae: 6.2314 - val_budget_realloc_loss: 13.3486 - val_budget_realloc_mae: 3.0510 - val_budget_rec_accuracy: 0.5232 - val_budget_rec_loss: 0.7272 - val_campaign_score_loss: 244.8397 - val_campaign_score_mae: 14.7755 - val_loss: 571.3099 - val_performance_alerts_accuracy: 0.9679 - val_performance_alerts_loss: 0.0852 - val_roi_forecast_loss: 15.3950 - val_roi_forecast_mae: 2.8222
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5024 - audience_exp_loss: 0.6990 - avg_perf_score_loss: 42.6630 - avg_perf_score_mae: 5.0586 - bid_strategy_accuracy: 0.2524 - bid_strategy_loss: 1.4054 - budget_dist_loss: 15.5875 - budget_dist_mae: 3.0325 - budget_realloc_loss: 10.6332 - budget_realloc_mae: 2.8045 - budget_rec_accuracy: 0.5222 - budget_rec_loss: 0.7185 - campaign_score_loss: 32.4911 - campaign_score_mae: 4.2929 - loss: 120.2775 - performance_alerts_accuracy: 0.9682 - performance_alerts_loss: 0.0829 - roi_forecast_loss: 16.0050 - roi_forecast_mae: 1.6758 - val_audience_exp_accuracy: 0.4992 - val_audience_exp_loss: 0.6951 - val_avg_perf_score_loss: 298.2016 - val_avg_perf_score_mae: 15.9539 - val_bid_strategy_accuracy: 0.2521 - val_bid_strategy_loss: 1.3946 - val_budget_dist_loss: 45.7379 - val_budget_dist_mae: 6.3306 - val_budget_realloc_loss: 13.4474 - val_budget_realloc_mae: 3.0613 - val_budget_rec_accuracy: 0.5262 - val_budget_rec_loss: 0.7126 - val_campaign_score_loss: 293.3723 - val_campaign_score_mae: 16.0870 - val_loss: 665.1247 - val_performance_alerts_accuracy: 0.9701 - val_performance_alerts_loss: 0.0807 - val_roi_forecast_loss: 10.6969 - val_roi_forecast_mae: 2.6859
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - audience_exp_accuracy: 0.4999 - audience_exp_loss: 0.6996 - avg_perf_score_loss: 41.2948 - avg_perf_score_mae: 4.9789 - bid_strategy_accuracy: 0.2503 - bid_strategy_loss: 1.4025 - budget_dist_loss: 14.8760 - budget_dist_mae: 2.9870 - budget_realloc_loss: 10.5754 - budget_realloc_mae: 2.7994 - budget_rec_accuracy: 0.5242 - budget_rec_loss: 0.7209 - campaign_score_loss: 30.9479 - campaign_score_mae: 4.1907 - loss: 117.4525 - performance_alerts_accuracy: 0.9672 - performance_alerts_loss: 0.0828 - roi_forecast_loss: 16.7639 - roi_forecast_mae: 1.7015 - val_audience_exp_accuracy: 0.4979 - val_audience_exp_loss: 0.6966 - val_avg_perf_score_loss: 336.7252 - val_avg_perf_score_mae: 16.8033 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.3975 - val_budget_dist_loss: 46.4460 - val_budget_dist_mae: 6.3670 - val_budget_realloc_loss: 13.5214 - val_budget_realloc_mae: 3.0688 - val_budget_rec_accuracy: 0.5252 - val_budget_rec_loss: 0.7142 - val_campaign_score_loss: 321.5616 - val_campaign_score_mae: 16.6168 - val_loss: 730.0289 - val_performance_alerts_accuracy: 0.9679 - val_performance_alerts_loss: 0.0851 - val_roi_forecast_loss: 7.3040 - val_roi_forecast_mae: 1.6615
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5013 - audience_exp_loss: 0.6986 - avg_perf_score_loss: 41.6270 - avg_perf_score_mae: 4.9928 - bid_strategy_accuracy: 0.2502 - bid_strategy_loss: 1.4085 - budget_dist_loss: 14.6502 - budget_dist_mae: 2.9549 - budget_realloc_loss: 10.5777 - budget_realloc_mae: 2.7992 - budget_rec_accuracy: 0.5222 - budget_rec_loss: 0.7216 - campaign_score_loss: 31.5124 - campaign_score_mae: 4.2138 - loss: 117.5753 - performance_alerts_accuracy: 0.9679 - performance_alerts_loss: 0.0832 - roi_forecast_loss: 16.2171 - roi_forecast_mae: 1.6412 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.6991 - val_avg_perf_score_loss: 259.0933 - val_avg_perf_score_mae: 14.9081 - val_bid_strategy_accuracy: 0.2513 - val_bid_strategy_loss: 1.4004 - val_budget_dist_loss: 38.6071 - val_budget_dist_mae: 5.7665 - val_budget_realloc_loss: 12.6955 - val_budget_realloc_mae: 2.9901 - val_budget_rec_accuracy: 0.5221 - val_budget_rec_loss: 0.7274 - val_campaign_score_loss: 245.2639 - val_campaign_score_mae: 14.7323 - val_loss: 578.3708 - val_performance_alerts_accuracy: 0.9671 - val_performance_alerts_loss: 0.0861 - val_roi_forecast_loss: 18.9878 - val_roi_forecast_mae: 1.4474
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4977 - audience_exp_loss: 0.6993 - avg_perf_score_loss: 40.0357 - avg_perf_score_mae: 4.9228 - bid_strategy_accuracy: 0.2498 - bid_strategy_loss: 1.4006 - budget_dist_loss: 14.3020 - budget_dist_mae: 2.9187 - budget_realloc_loss: 10.5677 - budget_realloc_mae: 2.7991 - budget_rec_accuracy: 0.5226 - budget_rec_loss: 0.7182 - campaign_score_loss: 29.8790 - campaign_score_mae: 4.1243 - loss: 114.6198 - performance_alerts_accuracy: 0.9676 - performance_alerts_loss: 0.0816 - roi_forecast_loss: 16.8355 - roi_forecast_mae: 1.6436 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.7008 - val_avg_perf_score_loss: 292.5359 - val_avg_perf_score_mae: 15.6693 - val_bid_strategy_accuracy: 0.2512 - val_bid_strategy_loss: 1.4174 - val_budget_dist_loss: 39.8948 - val_budget_dist_mae: 5.8929 - val_budget_realloc_loss: 12.5815 - val_budget_realloc_mae: 2.9803 - val_budget_rec_accuracy: 0.5214 - val_budget_rec_loss: 0.7200 - val_campaign_score_loss: 282.9153 - val_campaign_score_mae: 15.6472 - val_loss: 646.9434 - val_performance_alerts_accuracy: 0.9639 - val_performance_alerts_loss: 0.0900 - val_roi_forecast_loss: 14.7141 - val_roi_forecast_mae: 1.6208
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4987 - audience_exp_loss: 0.6994 - avg_perf_score_loss: 40.7003 - avg_perf_score_mae: 4.9533 - bid_strategy_accuracy: 0.2510 - bid_strategy_loss: 1.4045 - budget_dist_loss: 13.9381 - budget_dist_mae: 2.8840 - budget_realloc_loss: 10.5122 - budget_realloc_mae: 2.7949 - budget_rec_accuracy: 0.5225 - budget_rec_loss: 0.7198 - campaign_score_loss: 30.4686 - campaign_score_mae: 4.1610 - loss: 116.8241 - performance_alerts_accuracy: 0.9692 - performance_alerts_loss: 0.0817 - roi_forecast_loss: 18.2527 - roi_forecast_mae: 1.7044 - val_audience_exp_accuracy: 0.5009 - val_audience_exp_loss: 0.7119 - val_avg_perf_score_loss: 243.6337 - val_avg_perf_score_mae: 14.4317 - val_bid_strategy_accuracy: 0.2515 - val_bid_strategy_loss: 1.3940 - val_budget_dist_loss: 31.9006 - val_budget_dist_mae: 5.2488 - val_budget_realloc_loss: 12.4999 - val_budget_realloc_mae: 2.9728 - val_budget_rec_accuracy: 0.5255 - val_budget_rec_loss: 0.7302 - val_campaign_score_loss: 232.6378 - val_campaign_score_mae: 14.3596 - val_loss: 545.8578 - val_performance_alerts_accuracy: 0.9708 - val_performance_alerts_loss: 0.0798 - val_roi_forecast_loss: 21.1693 - val_roi_forecast_mae: 2.5091
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4982 - audience_exp_loss: 0.6992 - avg_perf_score_loss: 39.7676 - avg_perf_score_mae: 4.8879 - bid_strategy_accuracy: 0.2496 - bid_strategy_loss: 1.4028 - budget_dist_loss: 13.6332 - budget_dist_mae: 2.8552 - budget_realloc_loss: 10.5207 - budget_realloc_mae: 2.7953 - budget_rec_accuracy: 0.5224 - budget_rec_loss: 0.7195 - campaign_score_loss: 29.8078 - campaign_score_mae: 4.0839 - loss: 113.6002 - performance_alerts_accuracy: 0.9680 - performance_alerts_loss: 0.0817 - roi_forecast_loss: 16.9042 - roi_forecast_mae: 1.7160 - val_audience_exp_accuracy: 0.4991 - val_audience_exp_loss: 0.6971 - val_avg_perf_score_loss: 343.0803 - val_avg_perf_score_mae: 17.1750 - val_bid_strategy_accuracy: 0.2474 - val_bid_strategy_loss: 1.3920 - val_budget_dist_loss: 34.9110 - val_budget_dist_mae: 5.4348 - val_budget_realloc_loss: 12.4523 - val_budget_realloc_mae: 2.9677 - val_budget_rec_accuracy: 0.5181 - val_budget_rec_loss: 0.7265 - val_campaign_score_loss: 326.7289 - val_campaign_score_mae: 16.9894 - val_loss: 738.2020 - val_performance_alerts_accuracy: 0.9609 - val_performance_alerts_loss: 0.0934 - val_roi_forecast_loss: 16.7723 - val_roi_forecast_mae: 1.7384
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5019 - audience_exp_loss: 0.6984 - avg_perf_score_loss: 38.9482 - avg_perf_score_mae: 4.8257 - bid_strategy_accuracy: 0.2501 - bid_strategy_loss: 1.4030 - budget_dist_loss: 13.2111 - budget_dist_mae: 2.8081 - budget_realloc_loss: 10.4931 - budget_realloc_mae: 2.7914 - budget_rec_accuracy: 0.5257 - budget_rec_loss: 0.7183 - campaign_score_loss: 28.8303 - campaign_score_mae: 4.0237 - loss: 109.5957 - performance_alerts_accuracy: 0.9678 - performance_alerts_loss: 0.0817 - roi_forecast_loss: 15.4316 - roi_forecast_mae: 1.5986 - val_audience_exp_accuracy: 0.4995 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 337.4197 - val_avg_perf_score_mae: 16.6125 - val_bid_strategy_accuracy: 0.2497 - val_bid_strategy_loss: 1.4025 - val_budget_dist_loss: 41.1850 - val_budget_dist_mae: 5.9477 - val_budget_realloc_loss: 12.4801 - val_budget_realloc_mae: 2.9711 - val_budget_rec_accuracy: 0.5247 - val_budget_rec_loss: 0.7287 - val_campaign_score_loss: 323.2451 - val_campaign_score_mae: 16.4309 - val_loss: 745.5284 - val_performance_alerts_accuracy: 0.9690 - val_performance_alerts_loss: 0.0812 - val_roi_forecast_loss: 26.2144 - val_roi_forecast_mae: 2.4564
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - audience_exp_accuracy: 0.4990 - audience_exp_loss: 0.6986 - avg_perf_score_loss: 42.2597 - avg_perf_score_mae: 4.9585 - bid_strategy_accuracy: 0.2520 - bid_strategy_loss: 1.4008 - budget_dist_loss: 13.3890 - budget_dist_mae: 2.8266 - budget_realloc_loss: 10.5391 - budget_realloc_mae: 2.7965 - budget_rec_accuracy: 0.5239 - budget_rec_loss: 0.7219 - campaign_score_loss: 32.3146 - campaign_score_mae: 4.1839 - loss: 118.8752 - performance_alerts_accuracy: 0.9676 - performance_alerts_loss: 0.0820 - roi_forecast_loss: 17.3596 - roi_forecast_mae: 1.6778 - val_audience_exp_accuracy: 0.4985 - val_audience_exp_loss: 0.6968 - val_avg_perf_score_loss: 277.0057 - val_avg_perf_score_mae: 15.1450 - val_bid_strategy_accuracy: 0.2500 - val_bid_strategy_loss: 1.3952 - val_budget_dist_loss: 27.9004 - val_budget_dist_mae: 4.8535 - val_budget_realloc_loss: 11.3967 - val_budget_realloc_mae: 2.8774 - val_budget_rec_accuracy: 0.5232 - val_budget_rec_loss: 0.7135 - val_campaign_score_loss: 268.8041 - val_campaign_score_mae: 15.1410 - val_loss: 599.9391 - val_performance_alerts_accuracy: 0.9685 - val_performance_alerts_loss: 0.0806 - val_roi_forecast_loss: 11.3473 - val_roi_forecast_mae: 1.8917
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4988 - audience_exp_loss: 0.6984 - avg_perf_score_loss: 38.5816 - avg_perf_score_mae: 4.8143 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.3989 - budget_dist_loss: 12.8860 - budget_dist_mae: 2.7714 - budget_realloc_loss: 10.4824 - budget_realloc_mae: 2.7910 - budget_rec_accuracy: 0.5234 - budget_rec_loss: 0.7206 - campaign_score_loss: 28.2899 - campaign_score_mae: 3.9835 - loss: 108.2102 - performance_alerts_accuracy: 0.9685 - performance_alerts_loss: 0.0818 - roi_forecast_loss: 14.9435 - roi_forecast_mae: 1.5467 - val_audience_exp_accuracy: 0.4995 - val_audience_exp_loss: 0.6945 - val_avg_perf_score_loss: 309.3875 - val_avg_perf_score_mae: 15.8485 - val_bid_strategy_accuracy: 0.2474 - val_bid_strategy_loss: 1.4262 - val_budget_dist_loss: 26.9613 - val_budget_dist_mae: 4.7524 - val_budget_realloc_loss: 11.3140 - val_budget_realloc_mae: 2.8695 - val_budget_rec_accuracy: 0.5224 - val_budget_rec_loss: 0.7317 - val_campaign_score_loss: 298.7714 - val_campaign_score_mae: 15.7928 - val_loss: 670.1534 - val_performance_alerts_accuracy: 0.9660 - val_performance_alerts_loss: 0.0854 - val_roi_forecast_loss: 19.1304 - val_roi_forecast_mae: 2.2534
# Model training completed successfully!

# %%
# -------------------------------
# Multi-Task Neural Network Training Code
# -------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------------
# Assume df_model and processed features/targets exist:
# X_scaled (features), and targets:
# y_campaign_score, y_performance_alerts, y_budget_rec, y_roi_forecast,
# y_budget_dist_total (shape: n_samples x 3), y_avg_perf_score, 
# y_budget_realloc, y_audience_exp, y_bid_strategy
# -------------------------------

# 1. Train-test split for features
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# 2. Train-test split for each target
def split_target(y):
    return train_test_split(y, test_size=0.2, random_state=42)

y_campaign_score_train, y_campaign_score_test = split_target(y_campaign_score)
y_roi_forecast_train, y_roi_forecast_test = split_target(y_roi_forecast)
y_avg_perf_score_train, y_avg_perf_score_test = split_target(y_avg_perf_score)
y_budget_realloc_train, y_budget_realloc_test = split_target(y_budget_realloc)
y_budget_dist_train, y_budget_dist_test = split_target(y_budget_dist_total)  # shape: (n_samples,3)

y_performance_alerts_train, y_performance_alerts_test = split_target(y_performance_alerts)
y_budget_rec_train, y_budget_rec_test = split_target(y_budget_rec)
y_audience_exp_train, y_audience_exp_test = split_target(y_audience_exp)
y_bid_strategy_train, y_bid_strategy_test = split_target(y_bid_strategy)

# 3. Scale regression targets
scalers = {}

for name, y_train, y_test in [
    ('campaign_score', y_campaign_score_train, y_campaign_score_test),
    ('roi_forecast', y_roi_forecast_train, y_roi_forecast_test),
    ('avg_perf_score', y_avg_perf_score_train, y_avg_perf_score_test),
    ('budget_realloc', y_budget_realloc_train, y_budget_realloc_test)
]:
    scaler = StandardScaler()
    y_campaign_score_train_scaled = scaler.fit_transform(np.array(y_train).reshape(-1,1))
    y_campaign_score_test_scaled = scaler.transform(np.array(y_test).reshape(-1,1))
    if name == 'campaign_score':
        y_campaign_score_train, y_campaign_score_test = y_campaign_score_train_scaled, y_campaign_score_test_scaled
    elif name == 'roi_forecast':
        y_roi_forecast_train, y_roi_forecast_test = y_campaign_score_train_scaled, y_campaign_score_test_scaled
    elif name == 'avg_perf_score':
        y_avg_perf_score_train, y_avg_perf_score_test = y_campaign_score_train_scaled, y_campaign_score_test_scaled
    elif name == 'budget_realloc':
        y_budget_realloc_train, y_budget_realloc_test = y_campaign_score_train_scaled, y_campaign_score_test_scaled
    scalers[name] = scaler

# Scale multi-output regression: budget_dist (n_samples,3)
scaler_budget_dist = StandardScaler()
y_budget_dist_train = scaler_budget_dist.fit_transform(y_budget_dist_train)
y_budget_dist_test = scaler_budget_dist.transform(y_budget_dist_test)
scalers['budget_dist'] = scaler_budget_dist

# 4. Combine targets into dicts
y_train_prepared = {
    'campaign_score': y_campaign_score_train,
    'roi_forecast': y_roi_forecast_train,
    'avg_perf_score': y_avg_perf_score_train,
    'budget_dist': y_budget_dist_train,
    'budget_realloc': y_budget_realloc_train,
    'performance_alerts': y_performance_alerts_train,
    'budget_rec': y_budget_rec_train,
    'audience_exp': y_audience_exp_train,
    'bid_strategy': y_bid_strategy_train
}

y_test_prepared = {
    'campaign_score': y_campaign_score_test,
    'roi_forecast': y_roi_forecast_test,
    'avg_perf_score': y_avg_perf_score_test,
    'budget_dist': y_budget_dist_test,
    'budget_realloc': y_budget_realloc_test,
    'performance_alerts': y_performance_alerts_test,
    'budget_rec': y_budget_rec_test,
    'audience_exp': y_audience_exp_test,
    'bid_strategy': y_bid_strategy_test
}

# 5. Compute class weights for imbalanced classification targets
audience_exp_weights = compute_class_weight('balanced', classes=np.unique(y_audience_exp_train), y=y_audience_exp_train)
bid_strategy_weights = compute_class_weight('balanced', classes=np.unique(y_bid_strategy_train), y=y_bid_strategy_train)
class_weights = {
    'audience_exp': dict(enumerate(audience_exp_weights)),
    'bid_strategy': dict(enumerate(bid_strategy_weights))
}

# 6. Build multi-task neural network
input_layer = Input(shape=(X_train.shape[1],), name='input_features')

# Shared layers
x = Dense(256, activation='relu')(input_layer)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)

# Regression outputs
campaign_score_out = Dense(32, activation='relu')(x)
campaign_score_out = Dense(1, name='campaign_score')(campaign_score_out)

roi_forecast_out = Dense(16, activation='relu')(x)
roi_forecast_out = Dense(1, name='roi_forecast')(roi_forecast_out)

avg_perf_score_out = Dense(16, activation='relu')(x)
avg_perf_score_out = Dense(1, name='avg_perf_score')(avg_perf_score_out)

budget_realloc_out = Dense(16, activation='relu')(x)
budget_realloc_out = Dense(1, name='budget_realloc')(budget_realloc_out)

budget_dist_out = Dense(16, activation='relu')(x)
budget_dist_out = Dense(3, name='budget_dist')(budget_dist_out)  # matches y shape (n_samples,3)

# Classification outputs
performance_alerts_out = Dense(16, activation='relu')(x)
performance_alerts_out = Dense(1, activation='sigmoid', name='performance_alerts')(performance_alerts_out)

budget_rec_out = Dense(32, activation='relu')(x)
budget_rec_out = Dense(len(np.unique(y_budget_rec_train)), activation='softmax', name='budget_rec')(budget_rec_out)

audience_exp_out = Dense(16, activation='relu')(x)
audience_exp_out = Dense(1, activation='sigmoid', name='audience_exp')(audience_exp_out)

bid_strategy_out = Dense(32, activation='relu')(x)
bid_strategy_out = Dense(len(np.unique(y_bid_strategy_train)), activation='softmax', name='bid_strategy')(bid_strategy_out)

# Build model
model = Model(inputs=input_layer, outputs=[
    campaign_score_out, roi_forecast_out, avg_perf_score_out, budget_dist_out, budget_realloc_out,
    performance_alerts_out, budget_rec_out, audience_exp_out, bid_strategy_out
])

# 7. Compile model
model.compile(
    optimizer='adam',
    loss={
        'campaign_score': 'mse',
        'roi_forecast': 'mse',
        'avg_perf_score': 'mse',
        'budget_dist': 'mse',
        'budget_realloc': 'mse',
        'performance_alerts': 'binary_crossentropy',
        'budget_rec': 'sparse_categorical_crossentropy',
        'audience_exp': 'binary_crossentropy',
        'bid_strategy': 'sparse_categorical_crossentropy'
    },
    metrics={
        'campaign_score': 'mae',
        'roi_forecast': 'mae',
        'avg_perf_score': 'mae',
        'budget_dist': 'mae',
        'budget_realloc': 'mae',
        'performance_alerts': 'accuracy',
        'budget_rec': 'accuracy',
        'audience_exp': 'accuracy',
        'bid_strategy': 'accuracy'
    },
    loss_weights={k:1.0 for k in y_train_prepared.keys()}
)

# 8. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
]

# -------------------------------
# 9. Train model (without class_weight)
# -------------------------------
history = model.fit(
    X_train, y_train_prepared,
    validation_data=(X_test, y_test_prepared),
    epochs=50,
    batch_size=512,
    callbacks=callbacks,
    verbose=1
)


print("Multi-task model training completed successfully!")
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - audience_exp_accuracy: 0.4972 - audience_exp_loss: 0.6973 - avg_perf_score_loss: 0.1380 - avg_perf_score_mae: 0.2689 - bid_strategy_accuracy: 0.2495 - bid_strategy_loss: 1.3935 - budget_dist_loss: 0.2286 - budget_dist_mae: 0.3293 - budget_realloc_loss: 1.0171 - budget_realloc_mae: 0.8722 - budget_rec_accuracy: 0.4915 - budget_rec_loss: 0.8083 - campaign_score_loss: 0.1403 - campaign_score_mae: 0.2683 - loss: 4.7888 - performance_alerts_accuracy: 0.9017 - performance_alerts_loss: 0.2571 - roi_forecast_loss: 0.1058 - roi_forecast_mae: 0.1696 - val_audience_exp_accuracy: 0.4949 - val_audience_exp_loss: 0.6946 - val_avg_perf_score_loss: 0.0299 - val_avg_perf_score_mae: 0.1384 - val_bid_strategy_accuracy: 0.2472 - val_bid_strategy_loss: 1.3881 - val_budget_dist_loss: 0.0114 - val_budget_dist_mae: 0.0796 - val_budget_realloc_loss: 0.9932 - val_budget_realloc_mae: 0.8645 - val_budget_rec_accuracy: 0.5214 - val_budget_rec_loss: 0.7292 - val_campaign_score_loss: 0.0269 - val_campaign_score_mae: 0.1297 - val_loss: 4.0011 - val_performance_alerts_accuracy: 0.9575 - val_performance_alerts_loss: 0.1119 - val_roi_forecast_loss: 0.0098 - val_roi_forecast_mae: 0.0703 - learning_rate: 0.0010
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5013 - audience_exp_loss: 0.6948 - avg_perf_score_loss: 0.0515 - avg_perf_score_mae: 0.1776 - bid_strategy_accuracy: 0.2494 - bid_strategy_loss: 1.3896 - budget_dist_loss: 0.0544 - budget_dist_mae: 0.1775 - budget_realloc_loss: 1.0065 - budget_realloc_mae: 0.8686 - budget_rec_accuracy: 0.5193 - budget_rec_loss: 0.7238 - campaign_score_loss: 0.0476 - campaign_score_mae: 0.1706 - loss: 4.0941 - performance_alerts_accuracy: 0.9603 - performance_alerts_loss: 0.0966 - roi_forecast_loss: 0.0291 - roi_forecast_mae: 0.1024 - val_audience_exp_accuracy: 0.4945 - val_audience_exp_loss: 0.6951 - val_avg_perf_score_loss: 0.0259 - val_avg_perf_score_mae: 0.1286 - val_bid_strategy_accuracy: 0.2483 - val_bid_strategy_loss: 1.3869 - val_budget_dist_loss: 0.0074 - val_budget_dist_mae: 0.0658 - val_budget_realloc_loss: 0.9894 - val_budget_realloc_mae: 0.8632 - val_budget_rec_accuracy: 0.5368 - val_budget_rec_loss: 0.6894 - val_campaign_score_loss: 0.0212 - val_campaign_score_mae: 0.1160 - val_loss: 3.8896 - val_performance_alerts_accuracy: 0.9779 - val_performance_alerts_loss: 0.0624 - val_roi_forecast_loss: 0.0057 - val_roi_forecast_mae: 0.0530 - learning_rate: 0.0010
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5014 - audience_exp_loss: 0.6942 - avg_perf_score_loss: 0.0419 - avg_perf_score_mae: 0.1604 - bid_strategy_accuracy: 0.2509 - bid_strategy_loss: 1.3881 - budget_dist_loss: 0.0453 - budget_dist_mae: 0.1615 - budget_realloc_loss: 1.0037 - budget_realloc_mae: 0.8672 - budget_rec_accuracy: 0.5289 - budget_rec_loss: 0.6921 - campaign_score_loss: 0.0380 - campaign_score_mae: 0.1528 - loss: 3.9889 - performance_alerts_accuracy: 0.9762 - performance_alerts_loss: 0.0612 - roi_forecast_loss: 0.0238 - roi_forecast_mae: 0.0893 - val_audience_exp_accuracy: 0.4980 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 0.0210 - val_avg_perf_score_mae: 0.1148 - val_bid_strategy_accuracy: 0.2558 - val_bid_strategy_loss: 1.3868 - val_budget_dist_loss: 0.0071 - val_budget_dist_mae: 0.0614 - val_budget_realloc_loss: 0.9882 - val_budget_realloc_mae: 0.8618 - val_budget_rec_accuracy: 0.5387 - val_budget_rec_loss: 0.6680 - val_campaign_score_loss: 0.0182 - val_campaign_score_mae: 0.1035 - val_loss: 3.8477 - val_performance_alerts_accuracy: 0.9890 - val_performance_alerts_loss: 0.0379 - val_roi_forecast_loss: 0.0205 - val_roi_forecast_mae: 0.0782 - learning_rate: 0.0010
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5011 - audience_exp_loss: 0.6941 - avg_perf_score_loss: 0.0363 - avg_perf_score_mae: 0.1490 - bid_strategy_accuracy: 0.2520 - bid_strategy_loss: 1.3871 - budget_dist_loss: 0.0412 - budget_dist_mae: 0.1539 - budget_realloc_loss: 1.0040 - budget_realloc_mae: 0.8667 - budget_rec_accuracy: 0.5354 - budget_rec_loss: 0.6755 - campaign_score_loss: 0.0328 - campaign_score_mae: 0.1412 - loss: 3.9412 - performance_alerts_accuracy: 0.9849 - performance_alerts_loss: 0.0437 - roi_forecast_loss: 0.0276 - roi_forecast_mae: 0.0894 - val_audience_exp_accuracy: 0.4949 - val_audience_exp_loss: 0.6940 - val_avg_perf_score_loss: 0.0174 - val_avg_perf_score_mae: 0.1060 - val_bid_strategy_accuracy: 0.2546 - val_bid_strategy_loss: 1.3873 - val_budget_dist_loss: 0.0050 - val_budget_dist_mae: 0.0537 - val_budget_realloc_loss: 0.9867 - val_budget_realloc_mae: 0.8613 - val_budget_rec_accuracy: 0.5470 - val_budget_rec_loss: 0.6595 - val_campaign_score_loss: 0.0131 - val_campaign_score_mae: 0.0901 - val_loss: 3.8018 - val_performance_alerts_accuracy: 0.9923 - val_performance_alerts_loss: 0.0290 - val_roi_forecast_loss: 0.0045 - val_roi_forecast_mae: 0.0429 - learning_rate: 0.0010
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5017 - audience_exp_loss: 0.6936 - avg_perf_score_loss: 0.0315 - avg_perf_score_mae: 0.1387 - bid_strategy_accuracy: 0.2540 - bid_strategy_loss: 1.3869 - budget_dist_loss: 0.0378 - budget_dist_mae: 0.1475 - budget_realloc_loss: 1.0012 - budget_realloc_mae: 0.8660 - budget_rec_accuracy: 0.5374 - budget_rec_loss: 0.6671 - campaign_score_loss: 0.0279 - campaign_score_mae: 0.1298 - loss: 3.9031 - performance_alerts_accuracy: 0.9875 - performance_alerts_loss: 0.0351 - roi_forecast_loss: 0.0210 - roi_forecast_mae: 0.0789 - val_audience_exp_accuracy: 0.5008 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0170 - val_avg_perf_score_mae: 0.1050 - val_bid_strategy_accuracy: 0.2497 - val_bid_strategy_loss: 1.3867 - val_budget_dist_loss: 0.0051 - val_budget_dist_mae: 0.0535 - val_budget_realloc_loss: 0.9872 - val_budget_realloc_mae: 0.8610 - val_budget_rec_accuracy: 0.5431 - val_budget_rec_loss: 0.6553 - val_campaign_score_loss: 0.0145 - val_campaign_score_mae: 0.0947 - val_loss: 3.7930 - val_performance_alerts_accuracy: 0.9932 - val_performance_alerts_loss: 0.0245 - val_roi_forecast_loss: 0.0045 - val_roi_forecast_mae: 0.0446 - learning_rate: 0.0010
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5025 - audience_exp_loss: 0.6936 - avg_perf_score_loss: 0.0275 - avg_perf_score_mae: 0.1298 - bid_strategy_accuracy: 0.2517 - bid_strategy_loss: 1.3870 - budget_dist_loss: 0.0352 - budget_dist_mae: 0.1418 - budget_realloc_loss: 1.0005 - budget_realloc_mae: 0.8655 - budget_rec_accuracy: 0.5389 - budget_rec_loss: 0.6612 - campaign_score_loss: 0.0239 - campaign_score_mae: 0.1201 - loss: 3.8768 - performance_alerts_accuracy: 0.9903 - performance_alerts_loss: 0.0290 - roi_forecast_loss: 0.0185 - roi_forecast_mae: 0.0723 - val_audience_exp_accuracy: 0.5026 - val_audience_exp_loss: 0.6939 - val_avg_perf_score_loss: 0.0117 - val_avg_perf_score_mae: 0.0860 - val_bid_strategy_accuracy: 0.2526 - val_bid_strategy_loss: 1.3868 - val_budget_dist_loss: 0.0044 - val_budget_dist_mae: 0.0498 - val_budget_realloc_loss: 0.9876 - val_budget_realloc_mae: 0.8614 - val_budget_rec_accuracy: 0.5375 - val_budget_rec_loss: 0.6608 - val_campaign_score_loss: 0.0080 - val_campaign_score_mae: 0.0682 - val_loss: 3.7917 - val_performance_alerts_accuracy: 0.9887 - val_performance_alerts_loss: 0.0296 - val_roi_forecast_loss: 0.0030 - val_roi_forecast_mae: 0.0337 - learning_rate: 0.0010
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5033 - audience_exp_loss: 0.6936 - avg_perf_score_loss: 0.0244 - avg_perf_score_mae: 0.1219 - bid_strategy_accuracy: 0.2541 - bid_strategy_loss: 1.3867 - budget_dist_loss: 0.0327 - budget_dist_mae: 0.1368 - budget_realloc_loss: 1.0006 - budget_realloc_mae: 0.8654 - budget_rec_accuracy: 0.5404 - budget_rec_loss: 0.6595 - campaign_score_loss: 0.0207 - campaign_score_mae: 0.1116 - loss: 3.8668 - performance_alerts_accuracy: 0.9909 - performance_alerts_loss: 0.0270 - roi_forecast_loss: 0.0215 - roi_forecast_mae: 0.0732 - val_audience_exp_accuracy: 0.5000 - val_audience_exp_loss: 0.6939 - val_avg_perf_score_loss: 0.0092 - val_avg_perf_score_mae: 0.0763 - val_bid_strategy_accuracy: 0.2532 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0044 - val_budget_dist_mae: 0.0509 - val_budget_realloc_loss: 0.9864 - val_budget_realloc_mae: 0.8603 - val_budget_rec_accuracy: 0.5397 - val_budget_rec_loss: 0.6513 - val_campaign_score_loss: 0.0061 - val_campaign_score_mae: 0.0608 - val_loss: 3.7640 - val_performance_alerts_accuracy: 0.9940 - val_performance_alerts_loss: 0.0195 - val_roi_forecast_loss: 0.0017 - val_roi_forecast_mae: 0.0294 - learning_rate: 0.0010
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5021 - audience_exp_loss: 0.6936 - avg_perf_score_loss: 0.0222 - avg_perf_score_mae: 0.1161 - bid_strategy_accuracy: 0.2544 - bid_strategy_loss: 1.3866 - budget_dist_loss: 0.0312 - budget_dist_mae: 0.1333 - budget_realloc_loss: 1.0011 - budget_realloc_mae: 0.8651 - budget_rec_accuracy: 0.5399 - budget_rec_loss: 0.6580 - campaign_score_loss: 0.0186 - campaign_score_mae: 0.1051 - loss: 3.8507 - performance_alerts_accuracy: 0.9918 - performance_alerts_loss: 0.0254 - roi_forecast_loss: 0.0148 - roi_forecast_mae: 0.0654 - val_audience_exp_accuracy: 0.4957 - val_audience_exp_loss: 0.6936 - val_avg_perf_score_loss: 0.0098 - val_avg_perf_score_mae: 0.0791 - val_bid_strategy_accuracy: 0.2526 - val_bid_strategy_loss: 1.3867 - val_budget_dist_loss: 0.0054 - val_budget_dist_mae: 0.0552 - val_budget_realloc_loss: 0.9863 - val_budget_realloc_mae: 0.8602 - val_budget_rec_accuracy: 0.5411 - val_budget_rec_loss: 0.6539 - val_campaign_score_loss: 0.0063 - val_campaign_score_mae: 0.0618 - val_loss: 3.7764 - val_performance_alerts_accuracy: 0.9922 - val_performance_alerts_loss: 0.0228 - val_roi_forecast_loss: 0.0062 - val_roi_forecast_mae: 0.0402 - learning_rate: 0.0010
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5051 - audience_exp_loss: 0.6934 - avg_perf_score_loss: 0.0201 - avg_perf_score_mae: 0.1106 - bid_strategy_accuracy: 0.2530 - bid_strategy_loss: 1.3867 - budget_dist_loss: 0.0299 - budget_dist_mae: 0.1303 - budget_realloc_loss: 1.0003 - budget_realloc_mae: 0.8651 - budget_rec_accuracy: 0.5418 - budget_rec_loss: 0.6554 - campaign_score_loss: 0.0167 - campaign_score_mae: 0.0993 - loss: 3.8412 - performance_alerts_accuracy: 0.9923 - performance_alerts_loss: 0.0234 - roi_forecast_loss: 0.0148 - roi_forecast_mae: 0.0639 - val_audience_exp_accuracy: 0.4950 - val_audience_exp_loss: 0.6936 - val_avg_perf_score_loss: 0.0084 - val_avg_perf_score_mae: 0.0732 - val_bid_strategy_accuracy: 0.2578 - val_bid_strategy_loss: 1.3865 - val_budget_dist_loss: 0.0060 - val_budget_dist_mae: 0.0568 - val_budget_realloc_loss: 0.9866 - val_budget_realloc_mae: 0.8607 - val_budget_rec_accuracy: 0.5415 - val_budget_rec_loss: 0.6516 - val_campaign_score_loss: 0.0050 - val_campaign_score_mae: 0.0543 - val_loss: 3.7647 - val_performance_alerts_accuracy: 0.9934 - val_performance_alerts_loss: 0.0192 - val_roi_forecast_loss: 0.0022 - val_roi_forecast_mae: 0.0319 - learning_rate: 0.0010
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5019 - audience_exp_loss: 0.6933 - avg_perf_score_loss: 0.0193 - avg_perf_score_mae: 0.1082 - bid_strategy_accuracy: 0.2554 - bid_strategy_loss: 1.3865 - budget_dist_loss: 0.0281 - budget_dist_mae: 0.1271 - budget_realloc_loss: 1.0006 - budget_realloc_mae: 0.8649 - budget_rec_accuracy: 0.5405 - budget_rec_loss: 0.6552 - campaign_score_loss: 0.0157 - campaign_score_mae: 0.0965 - loss: 3.8373 - performance_alerts_accuracy: 0.9923 - performance_alerts_loss: 0.0230 - roi_forecast_loss: 0.0156 - roi_forecast_mae: 0.0632 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.6940 - val_avg_perf_score_loss: 0.0097 - val_avg_perf_score_mae: 0.0787 - val_bid_strategy_accuracy: 0.2578 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0042 - val_budget_dist_mae: 0.0490 - val_budget_realloc_loss: 0.9871 - val_budget_realloc_mae: 0.8609 - val_budget_rec_accuracy: 0.5418 - val_budget_rec_loss: 0.6481 - val_campaign_score_loss: 0.0068 - val_campaign_score_mae: 0.0649 - val_loss: 3.7602 - val_performance_alerts_accuracy: 0.9953 - val_performance_alerts_loss: 0.0170 - val_roi_forecast_loss: 0.0015 - val_roi_forecast_mae: 0.0290 - learning_rate: 0.0010
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5028 - audience_exp_loss: 0.6933 - avg_perf_score_loss: 0.0183 - avg_perf_score_mae: 0.1052 - bid_strategy_accuracy: 0.2551 - bid_strategy_loss: 1.3864 - budget_dist_loss: 0.0268 - budget_dist_mae: 0.1242 - budget_realloc_loss: 1.0002 - budget_realloc_mae: 0.8650 - budget_rec_accuracy: 0.5443 - budget_rec_loss: 0.6535 - campaign_score_loss: 0.0148 - campaign_score_mae: 0.0932 - loss: 3.8303 - performance_alerts_accuracy: 0.9932 - performance_alerts_loss: 0.0213 - roi_forecast_loss: 0.0151 - roi_forecast_mae: 0.0618 - val_audience_exp_accuracy: 0.4895 - val_audience_exp_loss: 0.6936 - val_avg_perf_score_loss: 0.0084 - val_avg_perf_score_mae: 0.0723 - val_bid_strategy_accuracy: 0.2548 - val_bid_strategy_loss: 1.3866 - val_budget_dist_loss: 0.0045 - val_budget_dist_mae: 0.0473 - val_budget_realloc_loss: 0.9865 - val_budget_realloc_mae: 0.8615 - val_budget_rec_accuracy: 0.5434 - val_budget_rec_loss: 0.6496 - val_campaign_score_loss: 0.0061 - val_campaign_score_mae: 0.0602 - val_loss: 3.7623 - val_performance_alerts_accuracy: 0.9941 - val_performance_alerts_loss: 0.0183 - val_roi_forecast_loss: 0.0032 - val_roi_forecast_mae: 0.0291 - learning_rate: 0.0010
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5030 - audience_exp_loss: 0.6932 - avg_perf_score_loss: 0.0178 - avg_perf_score_mae: 0.1037 - bid_strategy_accuracy: 0.2538 - bid_strategy_loss: 1.3865 - budget_dist_loss: 0.0256 - budget_dist_mae: 0.1217 - budget_realloc_loss: 1.0004 - budget_realloc_mae: 0.8648 - budget_rec_accuracy: 0.5433 - budget_rec_loss: 0.6535 - campaign_score_loss: 0.0145 - campaign_score_mae: 0.0922 - loss: 3.8287 - performance_alerts_accuracy: 0.9930 - performance_alerts_loss: 0.0210 - roi_forecast_loss: 0.0160 - roi_forecast_mae: 0.0620 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.6942 - val_avg_perf_score_loss: 0.0098 - val_avg_perf_score_mae: 0.0790 - val_bid_strategy_accuracy: 0.2571 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0043 - val_budget_dist_mae: 0.0497 - val_budget_realloc_loss: 0.9864 - val_budget_realloc_mae: 0.8606 - val_budget_rec_accuracy: 0.5441 - val_budget_rec_loss: 0.6490 - val_campaign_score_loss: 0.0064 - val_campaign_score_mae: 0.0631 - val_loss: 3.7652 - val_performance_alerts_accuracy: 0.9940 - val_performance_alerts_loss: 0.0178 - val_roi_forecast_loss: 0.0058 - val_roi_forecast_mae: 0.0473 - learning_rate: 0.0010
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5049 - audience_exp_loss: 0.6933 - avg_perf_score_loss: 0.0168 - avg_perf_score_mae: 0.1008 - bid_strategy_accuracy: 0.2553 - bid_strategy_loss: 1.3863 - budget_dist_loss: 0.0249 - budget_dist_mae: 0.1196 - budget_realloc_loss: 1.0004 - budget_realloc_mae: 0.8646 - budget_rec_accuracy: 0.5395 - budget_rec_loss: 0.6529 - campaign_score_loss: 0.0133 - campaign_score_mae: 0.0884 - loss: 3.8250 - performance_alerts_accuracy: 0.9934 - performance_alerts_loss: 0.0203 - roi_forecast_loss: 0.0175 - roi_forecast_mae: 0.0630 - val_audience_exp_accuracy: 0.4974 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0092 - val_avg_perf_score_mae: 0.0765 - val_bid_strategy_accuracy: 0.2526 - val_bid_strategy_loss: 1.3866 - val_budget_dist_loss: 0.0039 - val_budget_dist_mae: 0.0469 - val_budget_realloc_loss: 0.9871 - val_budget_realloc_mae: 0.8608 - val_budget_rec_accuracy: 0.5472 - val_budget_rec_loss: 0.6497 - val_campaign_score_loss: 0.0063 - val_campaign_score_mae: 0.0642 - val_loss: 3.7654 - val_performance_alerts_accuracy: 0.9939 - val_performance_alerts_loss: 0.0186 - val_roi_forecast_loss: 0.0053 - val_roi_forecast_mae: 0.0421 - learning_rate: 0.0010
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5035 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0156 - avg_perf_score_mae: 0.0973 - bid_strategy_accuracy: 0.2562 - bid_strategy_loss: 1.3862 - budget_dist_loss: 0.0233 - budget_dist_mae: 0.1161 - budget_realloc_loss: 1.0008 - budget_realloc_mae: 0.8646 - budget_rec_accuracy: 0.5444 - budget_rec_loss: 0.6494 - campaign_score_loss: 0.0122 - campaign_score_mae: 0.0843 - loss: 3.8112 - performance_alerts_accuracy: 0.9946 - performance_alerts_loss: 0.0174 - roi_forecast_loss: 0.0136 - roi_forecast_mae: 0.0573 - val_audience_exp_accuracy: 0.4992 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0090 - val_avg_perf_score_mae: 0.0745 - val_bid_strategy_accuracy: 0.2553 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0035 - val_budget_dist_mae: 0.0434 - val_budget_realloc_loss: 0.9860 - val_budget_realloc_mae: 0.8602 - val_budget_rec_accuracy: 0.5450 - val_budget_rec_loss: 0.6448 - val_campaign_score_loss: 0.0055 - val_campaign_score_mae: 0.0566 - val_loss: 3.7496 - val_performance_alerts_accuracy: 0.9963 - val_performance_alerts_loss: 0.0139 - val_roi_forecast_loss: 0.0017 - val_roi_forecast_mae: 0.0245 - learning_rate: 5.0000e-04
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5071 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0152 - avg_perf_score_mae: 0.0960 - bid_strategy_accuracy: 0.2579 - bid_strategy_loss: 1.3862 - budget_dist_loss: 0.0230 - budget_dist_mae: 0.1152 - budget_realloc_loss: 0.9998 - budget_realloc_mae: 0.8643 - budget_rec_accuracy: 0.5451 - budget_rec_loss: 0.6483 - campaign_score_loss: 0.0117 - campaign_score_mae: 0.0826 - loss: 3.8074 - performance_alerts_accuracy: 0.9951 - performance_alerts_loss: 0.0164 - roi_forecast_loss: 0.0137 - roi_forecast_mae: 0.0557 - val_audience_exp_accuracy: 0.4999 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0094 - val_avg_perf_score_mae: 0.0773 - val_bid_strategy_accuracy: 0.2538 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0039 - val_budget_dist_mae: 0.0457 - val_budget_realloc_loss: 0.9860 - val_budget_realloc_mae: 0.8602 - val_budget_rec_accuracy: 0.5484 - val_budget_rec_loss: 0.6460 - val_campaign_score_loss: 0.0059 - val_campaign_score_mae: 0.0588 - val_loss: 3.7569 - val_performance_alerts_accuracy: 0.9952 - val_performance_alerts_loss: 0.0149 - val_roi_forecast_loss: 0.0057 - val_roi_forecast_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5045 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0148 - avg_perf_score_mae: 0.0948 - bid_strategy_accuracy: 0.2581 - bid_strategy_loss: 1.3861 - budget_dist_loss: 0.0222 - budget_dist_mae: 0.1136 - budget_realloc_loss: 0.9998 - budget_realloc_mae: 0.8643 - budget_rec_accuracy: 0.5425 - budget_rec_loss: 0.6485 - campaign_score_loss: 0.0111 - campaign_score_mae: 0.0811 - loss: 3.8038 - performance_alerts_accuracy: 0.9950 - performance_alerts_loss: 0.0165 - roi_forecast_loss: 0.0120 - roi_forecast_mae: 0.0548 - val_audience_exp_accuracy: 0.4985 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0097 - val_avg_perf_score_mae: 0.0781 - val_bid_strategy_accuracy: 0.2577 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0039 - val_budget_dist_mae: 0.0461 - val_budget_realloc_loss: 0.9869 - val_budget_realloc_mae: 0.8608 - val_budget_rec_accuracy: 0.5463 - val_budget_rec_loss: 0.6452 - val_campaign_score_loss: 0.0063 - val_campaign_score_mae: 0.0608 - val_loss: 3.7584 - val_performance_alerts_accuracy: 0.9959 - val_performance_alerts_loss: 0.0142 - val_roi_forecast_loss: 0.0075 - val_roi_forecast_mae: 0.0365 - learning_rate: 5.0000e-04
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5059 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0147 - avg_perf_score_mae: 0.0948 - bid_strategy_accuracy: 0.2552 - bid_strategy_loss: 1.3862 - budget_dist_loss: 0.0220 - budget_dist_mae: 0.1129 - budget_realloc_loss: 0.9996 - budget_realloc_mae: 0.8646 - budget_rec_accuracy: 0.5418 - budget_rec_loss: 0.6487 - campaign_score_loss: 0.0111 - campaign_score_mae: 0.0811 - loss: 3.8047 - performance_alerts_accuracy: 0.9950 - performance_alerts_loss: 0.0165 - roi_forecast_loss: 0.0125 - roi_forecast_mae: 0.0553 - val_audience_exp_accuracy: 0.5005 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0105 - val_avg_perf_score_mae: 0.0799 - val_bid_strategy_accuracy: 0.2530 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0037 - val_budget_dist_mae: 0.0450 - val_budget_realloc_loss: 0.9862 - val_budget_realloc_mae: 0.8603 - val_budget_rec_accuracy: 0.5415 - val_budget_rec_loss: 0.6499 - val_campaign_score_loss: 0.0075 - val_campaign_score_mae: 0.0663 - val_loss: 3.7666 - val_performance_alerts_accuracy: 0.9937 - val_performance_alerts_loss: 0.0179 - val_roi_forecast_loss: 0.0059 - val_roi_forecast_mae: 0.0379 - learning_rate: 5.0000e-04
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - audience_exp_accuracy: 0.5069 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0141 - avg_perf_score_mae: 0.0930 - bid_strategy_accuracy: 0.2600 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0214 - budget_dist_mae: 0.1116 - budget_realloc_loss: 1.0000 - budget_realloc_mae: 0.8643 - budget_rec_accuracy: 0.5471 - budget_rec_loss: 0.6467 - campaign_score_loss: 0.0106 - campaign_score_mae: 0.0789 - loss: 3.7991 - performance_alerts_accuracy: 0.9957 - performance_alerts_loss: 0.0147 - roi_forecast_loss: 0.0129 - roi_forecast_mae: 0.0543 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0099 - val_avg_perf_score_mae: 0.0770 - val_bid_strategy_accuracy: 0.2537 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0033 - val_budget_dist_mae: 0.0424 - val_budget_realloc_loss: 0.9861 - val_budget_realloc_mae: 0.8601 - val_budget_rec_accuracy: 0.5471 - val_budget_rec_loss: 0.6439 - val_campaign_score_loss: 0.0060 - val_campaign_score_mae: 0.0568 - val_loss: 3.7554 - val_performance_alerts_accuracy: 0.9966 - val_performance_alerts_loss: 0.0129 - val_roi_forecast_loss: 0.0084 - val_roi_forecast_mae: 0.0351 - learning_rate: 2.5000e-04
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5073 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0137 - avg_perf_score_mae: 0.0920 - bid_strategy_accuracy: 0.2554 - bid_strategy_loss: 1.3861 - budget_dist_loss: 0.0214 - budget_dist_mae: 0.1115 - budget_realloc_loss: 0.9993 - budget_realloc_mae: 0.8640 - budget_rec_accuracy: 0.5451 - budget_rec_loss: 0.6463 - campaign_score_loss: 0.0103 - campaign_score_mae: 0.0780 - loss: 3.7962 - performance_alerts_accuracy: 0.9958 - performance_alerts_loss: 0.0144 - roi_forecast_loss: 0.0118 - roi_forecast_mae: 0.0530 - val_audience_exp_accuracy: 0.4999 - val_audience_exp_loss: 0.6937 - val_avg_perf_score_loss: 0.0093 - val_avg_perf_score_mae: 0.0747 - val_bid_strategy_accuracy: 0.2535 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0034 - val_budget_dist_mae: 0.0429 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8602 - val_budget_rec_accuracy: 0.5483 - val_budget_rec_loss: 0.6446 - val_campaign_score_loss: 0.0055 - val_campaign_score_mae: 0.0546 - val_loss: 3.7525 - val_performance_alerts_accuracy: 0.9955 - val_performance_alerts_loss: 0.0135 - val_roi_forecast_loss: 0.0051 - val_roi_forecast_mae: 0.0400 - learning_rate: 2.5000e-04
# Multi-task model training completed successfully!

# %%
#try3
# -------------------------------
# Multi-Task Neural Network Training Code (Weighted for Imbalanced Classification)
# -------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------------
# Assume df_model and processed features/targets exist:
# X_scaled (features), and targets:
# y_campaign_score, y_performance_alerts, y_budget_rec, y_roi_forecast,
# y_budget_dist_total (shape: n_samples x 3), y_avg_perf_score, 
# y_budget_realloc, y_audience_exp, y_bid_strategy
# -------------------------------

# 1. Train-test split for features
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# 2. Train-test split for each target
def split_target(y):
    return train_test_split(y, test_size=0.2, random_state=42)

y_campaign_score_train, y_campaign_score_test = split_target(y_campaign_score)
y_roi_forecast_train, y_roi_forecast_test = split_target(y_roi_forecast)
y_avg_perf_score_train, y_avg_perf_score_test = split_target(y_avg_perf_score)
y_budget_realloc_train, y_budget_realloc_test = split_target(y_budget_realloc)
y_budget_dist_train, y_budget_dist_test = split_target(y_budget_dist_total)  # shape: (n_samples,3)

y_performance_alerts_train, y_performance_alerts_test = split_target(y_performance_alerts)
y_budget_rec_train, y_budget_rec_test = split_target(y_budget_rec)
y_audience_exp_train, y_audience_exp_test = split_target(y_audience_exp)
y_bid_strategy_train, y_bid_strategy_test = split_target(y_bid_strategy)

# 3. Scale regression targets
scalers = {}

for name, y_train, y_test in [
    ('campaign_score', y_campaign_score_train, y_campaign_score_test),
    ('roi_forecast', y_roi_forecast_train, y_roi_forecast_test),
    ('avg_perf_score', y_avg_perf_score_train, y_avg_perf_score_test),
    ('budget_realloc', y_budget_realloc_train, y_budget_realloc_test)
]:
    scaler = StandardScaler()
    y_train_scaled = scaler.fit_transform(np.array(y_train).reshape(-1,1))
    y_test_scaled = scaler.transform(np.array(y_test).reshape(-1,1))
    if name == 'campaign_score':
        y_campaign_score_train, y_campaign_score_test = y_train_scaled, y_test_scaled
    elif name == 'roi_forecast':
        y_roi_forecast_train, y_roi_forecast_test = y_train_scaled, y_test_scaled
    elif name == 'avg_perf_score':
        y_avg_perf_score_train, y_avg_perf_score_test = y_train_scaled, y_test_scaled
    elif name == 'budget_realloc':
        y_budget_realloc_train, y_budget_realloc_test = y_train_scaled, y_test_scaled
    scalers[name] = scaler

# Scale multi-output regression: budget_dist (n_samples,3)
scaler_budget_dist = StandardScaler()
y_budget_dist_train = scaler_budget_dist.fit_transform(y_budget_dist_train)
y_budget_dist_test = scaler_budget_dist.transform(y_budget_dist_test)
scalers['budget_dist'] = scaler_budget_dist

# 4. Combine targets into dicts
y_train_prepared = {
    'campaign_score': y_campaign_score_train,
    'roi_forecast': y_roi_forecast_train,
    'avg_perf_score': y_avg_perf_score_train,
    'budget_dist': y_budget_dist_train,
    'budget_realloc': y_budget_realloc_train,
    'performance_alerts': y_performance_alerts_train,
    'budget_rec': y_budget_rec_train,
    'audience_exp': y_audience_exp_train,
    'bid_strategy': y_bid_strategy_train
}

y_test_prepared = {
    'campaign_score': y_campaign_score_test,
    'roi_forecast': y_roi_forecast_test,
    'avg_perf_score': y_avg_perf_score_test,
    'budget_dist': y_budget_dist_test,
    'budget_realloc': y_budget_realloc_test,
    'performance_alerts': y_performance_alerts_test,
    'budget_rec': y_budget_rec_test,
    'audience_exp': y_audience_exp_test,
    'bid_strategy': y_bid_strategy_test
}

# 5. Compute per-sample weights for imbalanced classification
def get_sample_weights(y_train, classes):
    weights = compute_class_weight('balanced', classes=classes, y=y_train)
    return np.array([weights[int(label)] for label in y_train])

sample_weights = {
    'audience_exp': get_sample_weights(y_audience_exp_train, np.unique(y_audience_exp_train)),
    'bid_strategy': get_sample_weights(y_bid_strategy_train, np.unique(y_bid_strategy_train))
}

# 6. Build multi-task neural network
input_layer = Input(shape=(X_train.shape[1],), name='input_features')

# Shared layers
x = Dense(256, activation='relu')(input_layer)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)

# Regression outputs
campaign_score_out = Dense(32, activation='relu')(x)
campaign_score_out = Dense(1, name='campaign_score')(campaign_score_out)

roi_forecast_out = Dense(16, activation='relu')(x)
roi_forecast_out = Dense(1, name='roi_forecast')(roi_forecast_out)

avg_perf_score_out = Dense(16, activation='relu')(x)
avg_perf_score_out = Dense(1, name='avg_perf_score')(avg_perf_score_out)

budget_realloc_out = Dense(16, activation='relu')(x)
budget_realloc_out = Dense(1, name='budget_realloc')(budget_realloc_out)

budget_dist_out = Dense(16, activation='relu')(x)
budget_dist_out = Dense(3, name='budget_dist')(budget_dist_out)  # matches y shape (n_samples,3)

# Classification outputs
performance_alerts_out = Dense(16, activation='relu')(x)
performance_alerts_out = Dense(1, activation='sigmoid', name='performance_alerts')(performance_alerts_out)

budget_rec_out = Dense(32, activation='relu')(x)
budget_rec_out = Dense(len(np.unique(y_budget_rec_train)), activation='softmax', name='budget_rec')(budget_rec_out)

audience_exp_out = Dense(16, activation='relu')(x)
audience_exp_out = Dense(1, activation='sigmoid', name='audience_exp')(audience_exp_out)

bid_strategy_out = Dense(32, activation='relu')(x)
bid_strategy_out = Dense(len(np.unique(y_bid_strategy_train)), activation='softmax', name='bid_strategy')(bid_strategy_out)

# Build model
model = Model(inputs=input_layer, outputs=[
    campaign_score_out, roi_forecast_out, avg_perf_score_out, budget_dist_out, budget_realloc_out,
    performance_alerts_out, budget_rec_out, audience_exp_out, bid_strategy_out
])

# 7. Compile model with adjusted loss weights
model.compile(
    optimizer='adam',
    loss={
        'campaign_score': 'mse',
        'roi_forecast': 'mse',
        'avg_perf_score': 'mse',
        'budget_dist': 'mse',
        'budget_realloc': 'mse',
        'performance_alerts': 'binary_crossentropy',
        'budget_rec': 'sparse_categorical_crossentropy',
        'audience_exp': 'binary_crossentropy',
        'bid_strategy': 'sparse_categorical_crossentropy'
    },
    metrics={
        'campaign_score': 'mae',
        'roi_forecast': 'mae',
        'avg_perf_score': 'mae',
        'budget_dist': 'mae',
        'budget_realloc': 'mae',
        'performance_alerts': 'accuracy',
        'budget_rec': 'accuracy',
        'audience_exp': 'accuracy',
        'bid_strategy': 'accuracy'
    },
    loss_weights={
        'campaign_score': 1.0,
        'roi_forecast': 1.0,
        'avg_perf_score': 1.0,
        'budget_dist': 1.0,
        'budget_realloc': 1.0,
        'performance_alerts': 1.0,
        'budget_rec': 1.0,
        'audience_exp': 3.0,      # increase weight for imbalanced binary task
        'bid_strategy': 3.0        # increase weight for imbalanced multi-class task
    }
)


# 8. Train model (no sample_weight)
history = model.fit(
    X_train, y_train_prepared,
    validation_data=(X_test, y_test_prepared),
    epochs=50,
    batch_size=512,
    callbacks=callbacks,
    verbose=1
)

# 8. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
]

# -------------------------------
# 9. Train model without sample_weight
# -------------------------------
history = model.fit(
    X_train, y_train_prepared,
    validation_data=(X_test, y_test_prepared),
    epochs=50,
    batch_size=512,
    callbacks=callbacks,
    verbose=1
)

print("Multi-task model training completed successfully!")


print("Weighted multi-task model training completed successfully!")
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - audience_exp_accuracy: 0.4991 - audience_exp_loss: 0.6972 - avg_perf_score_loss: 0.1380 - avg_perf_score_mae: 0.2653 - bid_strategy_accuracy: 0.2494 - bid_strategy_loss: 1.3931 - budget_dist_loss: 0.2085 - budget_dist_mae: 0.3170 - budget_realloc_loss: 1.0161 - budget_realloc_mae: 0.8715 - budget_rec_accuracy: 0.4743 - budget_rec_loss: 0.8301 - campaign_score_loss: 0.1466 - campaign_score_mae: 0.2678 - loss: 8.9611 - performance_alerts_accuracy: 0.9221 - performance_alerts_loss: 0.2365 - roi_forecast_loss: 0.1119 - roi_forecast_mae: 0.1604 - val_audience_exp_accuracy: 0.4915 - val_audience_exp_loss: 0.6940 - val_avg_perf_score_loss: 0.0285 - val_avg_perf_score_mae: 0.1346 - val_bid_strategy_accuracy: 0.2522 - val_bid_strategy_loss: 1.3886 - val_budget_dist_loss: 0.0091 - val_budget_dist_mae: 0.0720 - val_budget_realloc_loss: 0.9886 - val_budget_realloc_mae: 0.8620 - val_budget_rec_accuracy: 0.5155 - val_budget_rec_loss: 0.7257 - val_campaign_score_loss: 0.0258 - val_campaign_score_mae: 0.1262 - val_loss: 8.1445 - val_performance_alerts_accuracy: 0.9589 - val_performance_alerts_loss: 0.1046 - val_roi_forecast_loss: 0.0069 - val_roi_forecast_mae: 0.0626 - learning_rate: 0.0010
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5004 - audience_exp_loss: 0.6939 - avg_perf_score_loss: 0.0497 - avg_perf_score_mae: 0.1750 - bid_strategy_accuracy: 0.2526 - bid_strategy_loss: 1.3895 - budget_dist_loss: 0.0532 - budget_dist_mae: 0.1761 - budget_realloc_loss: 1.0023 - budget_realloc_mae: 0.8661 - budget_rec_accuracy: 0.5210 - budget_rec_loss: 0.7206 - campaign_score_loss: 0.0465 - campaign_score_mae: 0.1688 - loss: 8.2445 - performance_alerts_accuracy: 0.9622 - performance_alerts_loss: 0.0920 - roi_forecast_loss: 0.0291 - roi_forecast_mae: 0.0984 - val_audience_exp_accuracy: 0.4979 - val_audience_exp_loss: 0.6938 - val_avg_perf_score_loss: 0.0223 - val_avg_perf_score_mae: 0.1169 - val_bid_strategy_accuracy: 0.2535 - val_bid_strategy_loss: 1.3874 - val_budget_dist_loss: 0.0069 - val_budget_dist_mae: 0.0638 - val_budget_realloc_loss: 0.9869 - val_budget_realloc_mae: 0.8604 - val_budget_rec_accuracy: 0.5326 - val_budget_rec_loss: 0.6840 - val_campaign_score_loss: 0.0193 - val_campaign_score_mae: 0.1059 - val_loss: 8.0361 - val_performance_alerts_accuracy: 0.9815 - val_performance_alerts_loss: 0.0565 - val_roi_forecast_loss: 0.0110 - val_roi_forecast_mae: 0.0661 - learning_rate: 0.0010
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4991 - audience_exp_loss: 0.6935 - avg_perf_score_loss: 0.0421 - avg_perf_score_mae: 0.1600 - bid_strategy_accuracy: 0.2525 - bid_strategy_loss: 1.3879 - budget_dist_loss: 0.0447 - budget_dist_mae: 0.1611 - budget_realloc_loss: 1.0012 - budget_realloc_mae: 0.8646 - budget_rec_accuracy: 0.5322 - budget_rec_loss: 0.6896 - campaign_score_loss: 0.0387 - campaign_score_mae: 0.1534 - loss: 8.1445 - performance_alerts_accuracy: 0.9775 - performance_alerts_loss: 0.0588 - roi_forecast_loss: 0.0248 - roi_forecast_mae: 0.0878 - val_audience_exp_accuracy: 0.4988 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0199 - val_avg_perf_score_mae: 0.1105 - val_bid_strategy_accuracy: 0.2511 - val_bid_strategy_loss: 1.3871 - val_budget_dist_loss: 0.0073 - val_budget_dist_mae: 0.0626 - val_budget_realloc_loss: 0.9860 - val_budget_realloc_mae: 0.8595 - val_budget_rec_accuracy: 0.5391 - val_budget_rec_loss: 0.6674 - val_campaign_score_loss: 0.0161 - val_campaign_score_mae: 0.0982 - val_loss: 8.0015 - val_performance_alerts_accuracy: 0.9886 - val_performance_alerts_loss: 0.0379 - val_roi_forecast_loss: 0.0184 - val_roi_forecast_mae: 0.0660 - learning_rate: 0.0010
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5037 - audience_exp_loss: 0.6932 - avg_perf_score_loss: 0.0371 - avg_perf_score_mae: 0.1505 - bid_strategy_accuracy: 0.2512 - bid_strategy_loss: 1.3876 - budget_dist_loss: 0.0409 - budget_dist_mae: 0.1526 - budget_realloc_loss: 1.0004 - budget_realloc_mae: 0.8642 - budget_rec_accuracy: 0.5379 - budget_rec_loss: 0.6750 - campaign_score_loss: 0.0337 - campaign_score_mae: 0.1431 - loss: 8.0968 - performance_alerts_accuracy: 0.9847 - performance_alerts_loss: 0.0434 - roi_forecast_loss: 0.0235 - roi_forecast_mae: 0.0821 - val_audience_exp_accuracy: 0.4967 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0181 - val_avg_perf_score_mae: 0.1064 - val_bid_strategy_accuracy: 0.2525 - val_bid_strategy_loss: 1.3869 - val_budget_dist_loss: 0.0067 - val_budget_dist_mae: 0.0618 - val_budget_realloc_loss: 0.9860 - val_budget_realloc_mae: 0.8595 - val_budget_rec_accuracy: 0.5444 - val_budget_rec_loss: 0.6588 - val_campaign_score_loss: 0.0146 - val_campaign_score_mae: 0.0951 - val_loss: 7.9944 - val_performance_alerts_accuracy: 0.9930 - val_performance_alerts_loss: 0.0285 - val_roi_forecast_loss: 0.0349 - val_roi_forecast_mae: 0.0884 - learning_rate: 0.0010
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5032 - audience_exp_loss: 0.6932 - avg_perf_score_loss: 0.0324 - avg_perf_score_mae: 0.1410 - bid_strategy_accuracy: 0.2509 - bid_strategy_loss: 1.3873 - budget_dist_loss: 0.0378 - budget_dist_mae: 0.1467 - budget_realloc_loss: 1.0005 - budget_realloc_mae: 0.8640 - budget_rec_accuracy: 0.5366 - budget_rec_loss: 0.6680 - campaign_score_loss: 0.0292 - campaign_score_mae: 0.1331 - loss: 8.0662 - performance_alerts_accuracy: 0.9881 - performance_alerts_loss: 0.0359 - roi_forecast_loss: 0.0210 - roi_forecast_mae: 0.0761 - val_audience_exp_accuracy: 0.4956 - val_audience_exp_loss: 0.6933 - val_avg_perf_score_loss: 0.0164 - val_avg_perf_score_mae: 0.1027 - val_bid_strategy_accuracy: 0.2518 - val_bid_strategy_loss: 1.3873 - val_budget_dist_loss: 0.0058 - val_budget_dist_mae: 0.0567 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8595 - val_budget_rec_accuracy: 0.5410 - val_budget_rec_loss: 0.6562 - val_campaign_score_loss: 0.0132 - val_campaign_score_mae: 0.0919 - val_loss: 7.9553 - val_performance_alerts_accuracy: 0.9926 - val_performance_alerts_loss: 0.0247 - val_roi_forecast_loss: 0.0057 - val_roi_forecast_mae: 0.0499 - learning_rate: 0.0010
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5017 - audience_exp_loss: 0.6932 - avg_perf_score_loss: 0.0291 - avg_perf_score_mae: 0.1334 - bid_strategy_accuracy: 0.2521 - bid_strategy_loss: 1.3873 - budget_dist_loss: 0.0347 - budget_dist_mae: 0.1409 - budget_realloc_loss: 1.0000 - budget_realloc_mae: 0.8640 - budget_rec_accuracy: 0.5385 - budget_rec_loss: 0.6625 - campaign_score_loss: 0.0258 - campaign_score_mae: 0.1251 - loss: 8.0420 - performance_alerts_accuracy: 0.9901 - performance_alerts_loss: 0.0307 - roi_forecast_loss: 0.0175 - roi_forecast_mae: 0.0706 - val_audience_exp_accuracy: 0.4967 - val_audience_exp_loss: 0.6933 - val_avg_perf_score_loss: 0.0158 - val_avg_perf_score_mae: 0.1002 - val_bid_strategy_accuracy: 0.2501 - val_bid_strategy_loss: 1.3870 - val_budget_dist_loss: 0.0059 - val_budget_dist_mae: 0.0541 - val_budget_realloc_loss: 0.9862 - val_budget_realloc_mae: 0.8597 - val_budget_rec_accuracy: 0.5418 - val_budget_rec_loss: 0.6523 - val_campaign_score_loss: 0.0118 - val_campaign_score_mae: 0.0869 - val_loss: 7.9483 - val_performance_alerts_accuracy: 0.9945 - val_performance_alerts_loss: 0.0218 - val_roi_forecast_loss: 0.0077 - val_roi_forecast_mae: 0.0472 - learning_rate: 0.0010
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5039 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0258 - avg_perf_score_mae: 0.1252 - bid_strategy_accuracy: 0.2534 - bid_strategy_loss: 1.3869 - budget_dist_loss: 0.0321 - budget_dist_mae: 0.1359 - budget_realloc_loss: 0.9999 - budget_realloc_mae: 0.8637 - budget_rec_accuracy: 0.5383 - budget_rec_loss: 0.6596 - campaign_score_loss: 0.0224 - campaign_score_mae: 0.1158 - loss: 8.0250 - performance_alerts_accuracy: 0.9908 - performance_alerts_loss: 0.0271 - roi_forecast_loss: 0.0174 - roi_forecast_mae: 0.0674 - val_audience_exp_accuracy: 0.4954 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0115 - val_avg_perf_score_mae: 0.0852 - val_bid_strategy_accuracy: 0.2519 - val_bid_strategy_loss: 1.3871 - val_budget_dist_loss: 0.0051 - val_budget_dist_mae: 0.0508 - val_budget_realloc_loss: 0.9861 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5411 - val_budget_rec_loss: 0.6508 - val_campaign_score_loss: 0.0080 - val_campaign_score_mae: 0.0686 - val_loss: 7.9393 - val_performance_alerts_accuracy: 0.9951 - val_performance_alerts_loss: 0.0198 - val_roi_forecast_loss: 0.0106 - val_roi_forecast_mae: 0.0453 - learning_rate: 0.0010
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - audience_exp_accuracy: 0.5053 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0229 - avg_perf_score_mae: 0.1181 - bid_strategy_accuracy: 0.2556 - bid_strategy_loss: 1.3868 - budget_dist_loss: 0.0305 - budget_dist_mae: 0.1325 - budget_realloc_loss: 1.0002 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5391 - budget_rec_loss: 0.6563 - campaign_score_loss: 0.0196 - campaign_score_mae: 0.1082 - loss: 8.0125 - performance_alerts_accuracy: 0.9924 - performance_alerts_loss: 0.0239 - roi_forecast_loss: 0.0194 - roi_forecast_mae: 0.0686 - val_audience_exp_accuracy: 0.4965 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0098 - val_avg_perf_score_mae: 0.0785 - val_bid_strategy_accuracy: 0.2515 - val_bid_strategy_loss: 1.3867 - val_budget_dist_loss: 0.0051 - val_budget_dist_mae: 0.0536 - val_budget_realloc_loss: 0.9861 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5422 - val_budget_rec_loss: 0.6515 - val_campaign_score_loss: 0.0061 - val_campaign_score_mae: 0.0608 - val_loss: 7.9261 - val_performance_alerts_accuracy: 0.9937 - val_performance_alerts_loss: 0.0196 - val_roi_forecast_loss: 0.0024 - val_roi_forecast_mae: 0.0320 - learning_rate: 0.0010
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5038 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0214 - avg_perf_score_mae: 0.1137 - bid_strategy_accuracy: 0.2543 - bid_strategy_loss: 1.3865 - budget_dist_loss: 0.0291 - budget_dist_mae: 0.1292 - budget_realloc_loss: 0.9998 - budget_realloc_mae: 0.8636 - budget_rec_accuracy: 0.5370 - budget_rec_loss: 0.6560 - campaign_score_loss: 0.0181 - campaign_score_mae: 0.1034 - loss: 8.0031 - performance_alerts_accuracy: 0.9923 - performance_alerts_loss: 0.0230 - roi_forecast_loss: 0.0164 - roi_forecast_mae: 0.0646 - val_audience_exp_accuracy: 0.4963 - val_audience_exp_loss: 0.6933 - val_avg_perf_score_loss: 0.0083 - val_avg_perf_score_mae: 0.0726 - val_bid_strategy_accuracy: 0.2524 - val_bid_strategy_loss: 1.3876 - val_budget_dist_loss: 0.0047 - val_budget_dist_mae: 0.0503 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8594 - val_budget_rec_accuracy: 0.5438 - val_budget_rec_loss: 0.6521 - val_campaign_score_loss: 0.0056 - val_campaign_score_mae: 0.0580 - val_loss: 7.9271 - val_performance_alerts_accuracy: 0.9933 - val_performance_alerts_loss: 0.0206 - val_roi_forecast_loss: 0.0017 - val_roi_forecast_mae: 0.0264 - learning_rate: 0.0010
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5060 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0199 - avg_perf_score_mae: 0.1097 - bid_strategy_accuracy: 0.2549 - bid_strategy_loss: 1.3865 - budget_dist_loss: 0.0275 - budget_dist_mae: 0.1255 - budget_realloc_loss: 0.9993 - budget_realloc_mae: 0.8634 - budget_rec_accuracy: 0.5421 - budget_rec_loss: 0.6544 - campaign_score_loss: 0.0165 - campaign_score_mae: 0.0986 - loss: 7.9947 - performance_alerts_accuracy: 0.9925 - performance_alerts_loss: 0.0221 - roi_forecast_loss: 0.0151 - roi_forecast_mae: 0.0614 - val_audience_exp_accuracy: 0.4970 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0108 - val_avg_perf_score_mae: 0.0826 - val_bid_strategy_accuracy: 0.2535 - val_bid_strategy_loss: 1.3868 - val_budget_dist_loss: 0.0050 - val_budget_dist_mae: 0.0527 - val_budget_realloc_loss: 0.9861 - val_budget_realloc_mae: 0.8595 - val_budget_rec_accuracy: 0.5404 - val_budget_rec_loss: 0.6507 - val_campaign_score_loss: 0.0066 - val_campaign_score_mae: 0.0631 - val_loss: 7.9296 - val_performance_alerts_accuracy: 0.9937 - val_performance_alerts_loss: 0.0193 - val_roi_forecast_loss: 0.0052 - val_roi_forecast_mae: 0.0384 - learning_rate: 0.0010
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5040 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0193 - avg_perf_score_mae: 0.1078 - bid_strategy_accuracy: 0.2550 - bid_strategy_loss: 1.3866 - budget_dist_loss: 0.0266 - budget_dist_mae: 0.1236 - budget_realloc_loss: 0.9996 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5384 - budget_rec_loss: 0.6544 - campaign_score_loss: 0.0158 - campaign_score_mae: 0.0964 - loss: 7.9925 - performance_alerts_accuracy: 0.9929 - performance_alerts_loss: 0.0220 - roi_forecast_loss: 0.0153 - roi_forecast_mae: 0.0608 - val_audience_exp_accuracy: 0.4922 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0104 - val_avg_perf_score_mae: 0.0799 - val_bid_strategy_accuracy: 0.2535 - val_bid_strategy_loss: 1.3869 - val_budget_dist_loss: 0.0053 - val_budget_dist_mae: 0.0544 - val_budget_realloc_loss: 0.9863 - val_budget_realloc_mae: 0.8599 - val_budget_rec_accuracy: 0.5463 - val_budget_rec_loss: 0.6494 - val_campaign_score_loss: 0.0071 - val_campaign_score_mae: 0.0630 - val_loss: 7.9278 - val_performance_alerts_accuracy: 0.9943 - val_performance_alerts_loss: 0.0182 - val_roi_forecast_loss: 0.0054 - val_roi_forecast_mae: 0.0376 - learning_rate: 0.0010
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5052 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0170 - avg_perf_score_mae: 0.1018 - bid_strategy_accuracy: 0.2545 - bid_strategy_loss: 1.3865 - budget_dist_loss: 0.0248 - budget_dist_mae: 0.1197 - budget_realloc_loss: 0.9997 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5425 - budget_rec_loss: 0.6509 - campaign_score_loss: 0.0137 - campaign_score_mae: 0.0898 - loss: 7.9768 - performance_alerts_accuracy: 0.9942 - performance_alerts_loss: 0.0188 - roi_forecast_loss: 0.0130 - roi_forecast_mae: 0.0566 - val_audience_exp_accuracy: 0.4923 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0090 - val_avg_perf_score_mae: 0.0751 - val_bid_strategy_accuracy: 0.2497 - val_bid_strategy_loss: 1.3865 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0446 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5473 - val_budget_rec_loss: 0.6465 - val_campaign_score_loss: 0.0057 - val_campaign_score_mae: 0.0560 - val_loss: 7.9171 - val_performance_alerts_accuracy: 0.9956 - val_performance_alerts_loss: 0.0154 - val_roi_forecast_loss: 0.0058 - val_roi_forecast_mae: 0.0416 - learning_rate: 5.0000e-04
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5056 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0167 - avg_perf_score_mae: 0.1009 - bid_strategy_accuracy: 0.2556 - bid_strategy_loss: 1.3863 - budget_dist_loss: 0.0241 - budget_dist_mae: 0.1178 - budget_realloc_loss: 1.0001 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5443 - budget_rec_loss: 0.6501 - campaign_score_loss: 0.0133 - campaign_score_mae: 0.0888 - loss: 7.9722 - performance_alerts_accuracy: 0.9944 - performance_alerts_loss: 0.0180 - roi_forecast_loss: 0.0120 - roi_forecast_mae: 0.0556 - val_audience_exp_accuracy: 0.4918 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0078 - val_avg_perf_score_mae: 0.0702 - val_bid_strategy_accuracy: 0.2542 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0038 - val_budget_dist_mae: 0.0463 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5444 - val_budget_rec_loss: 0.6451 - val_campaign_score_loss: 0.0041 - val_campaign_score_mae: 0.0473 - val_loss: 7.9143 - val_performance_alerts_accuracy: 0.9965 - val_performance_alerts_loss: 0.0140 - val_roi_forecast_loss: 0.0089 - val_roi_forecast_mae: 0.0385 - learning_rate: 5.0000e-04
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.5058 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0164 - avg_perf_score_mae: 0.0993 - bid_strategy_accuracy: 0.2560 - bid_strategy_loss: 1.3863 - budget_dist_loss: 0.0237 - budget_dist_mae: 0.1167 - budget_realloc_loss: 1.0004 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5414 - budget_rec_loss: 0.6493 - campaign_score_loss: 0.0131 - campaign_score_mae: 0.0875 - loss: 7.9705 - performance_alerts_accuracy: 0.9948 - performance_alerts_loss: 0.0171 - roi_forecast_loss: 0.0128 - roi_forecast_mae: 0.0566 - val_audience_exp_accuracy: 0.4943 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0093 - val_avg_perf_score_mae: 0.0769 - val_bid_strategy_accuracy: 0.2578 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0042 - val_budget_dist_mae: 0.0483 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8594 - val_budget_rec_accuracy: 0.5441 - val_budget_rec_loss: 0.6495 - val_campaign_score_loss: 0.0064 - val_campaign_score_mae: 0.0607 - val_loss: 7.9256 - val_performance_alerts_accuracy: 0.9936 - val_performance_alerts_loss: 0.0181 - val_roi_forecast_loss: 0.0072 - val_roi_forecast_mae: 0.0408 - learning_rate: 5.0000e-04
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5044 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0164 - avg_perf_score_mae: 0.0994 - bid_strategy_accuracy: 0.2558 - bid_strategy_loss: 1.3862 - budget_dist_loss: 0.0230 - budget_dist_mae: 0.1153 - budget_realloc_loss: 0.9993 - budget_realloc_mae: 0.8634 - budget_rec_accuracy: 0.5440 - budget_rec_loss: 0.6497 - campaign_score_loss: 0.0130 - campaign_score_mae: 0.0872 - loss: 7.9710 - performance_alerts_accuracy: 0.9948 - performance_alerts_loss: 0.0174 - roi_forecast_loss: 0.0144 - roi_forecast_mae: 0.0568 - val_audience_exp_accuracy: 0.4913 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0082 - val_avg_perf_score_mae: 0.0713 - val_bid_strategy_accuracy: 0.2549 - val_bid_strategy_loss: 1.3862 - val_budget_dist_loss: 0.0041 - val_budget_dist_mae: 0.0469 - val_budget_realloc_loss: 0.9860 - val_budget_realloc_mae: 0.8594 - val_budget_rec_accuracy: 0.5439 - val_budget_rec_loss: 0.6468 - val_campaign_score_loss: 0.0043 - val_campaign_score_mae: 0.0479 - val_loss: 7.9158 - val_performance_alerts_accuracy: 0.9952 - val_performance_alerts_loss: 0.0154 - val_roi_forecast_loss: 0.0067 - val_roi_forecast_mae: 0.0436 - learning_rate: 5.0000e-04
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5054 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0162 - avg_perf_score_mae: 0.0991 - bid_strategy_accuracy: 0.2569 - bid_strategy_loss: 1.3862 - budget_dist_loss: 0.0229 - budget_dist_mae: 0.1147 - budget_realloc_loss: 1.0000 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5427 - budget_rec_loss: 0.6504 - campaign_score_loss: 0.0130 - campaign_score_mae: 0.0875 - loss: 7.9733 - performance_alerts_accuracy: 0.9940 - performance_alerts_loss: 0.0183 - roi_forecast_loss: 0.0147 - roi_forecast_mae: 0.0570 - val_audience_exp_accuracy: 0.4929 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0100 - val_avg_perf_score_mae: 0.0790 - val_bid_strategy_accuracy: 0.2542 - val_bid_strategy_loss: 1.3865 - val_budget_dist_loss: 0.0045 - val_budget_dist_mae: 0.0503 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8601 - val_budget_rec_accuracy: 0.5452 - val_budget_rec_loss: 0.6460 - val_campaign_score_loss: 0.0068 - val_campaign_score_mae: 0.0643 - val_loss: 7.9249 - val_performance_alerts_accuracy: 0.9954 - val_performance_alerts_loss: 0.0149 - val_roi_forecast_loss: 0.0119 - val_roi_forecast_mae: 0.0450 - learning_rate: 5.0000e-04
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - audience_exp_accuracy: 0.5076 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0156 - avg_perf_score_mae: 0.0973 - bid_strategy_accuracy: 0.2587 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0224 - budget_dist_mae: 0.1128 - budget_realloc_loss: 0.9992 - budget_realloc_mae: 0.8635 - budget_rec_accuracy: 0.5458 - budget_rec_loss: 0.6483 - campaign_score_loss: 0.0123 - campaign_score_mae: 0.0846 - loss: 7.9633 - performance_alerts_accuracy: 0.9951 - performance_alerts_loss: 0.0164 - roi_forecast_loss: 0.0114 - roi_forecast_mae: 0.0536 - val_audience_exp_accuracy: 0.4911 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0079 - val_avg_perf_score_mae: 0.0683 - val_bid_strategy_accuracy: 0.2525 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0038 - val_budget_dist_mae: 0.0455 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5488 - val_budget_rec_loss: 0.6455 - val_campaign_score_loss: 0.0044 - val_campaign_score_mae: 0.0455 - val_loss: 7.9139 - val_performance_alerts_accuracy: 0.9957 - val_performance_alerts_loss: 0.0144 - val_roi_forecast_loss: 0.0077 - val_roi_forecast_mae: 0.0383 - learning_rate: 2.5000e-04
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - audience_exp_accuracy: 0.5041 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0151 - avg_perf_score_mae: 0.0956 - bid_strategy_accuracy: 0.2573 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0220 - budget_dist_mae: 0.1122 - budget_realloc_loss: 1.0001 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5454 - budget_rec_loss: 0.6472 - campaign_score_loss: 0.0118 - campaign_score_mae: 0.0830 - loss: 7.9600 - performance_alerts_accuracy: 0.9956 - performance_alerts_loss: 0.0155 - roi_forecast_loss: 0.0115 - roi_forecast_mae: 0.0536 - val_audience_exp_accuracy: 0.4897 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0072 - val_avg_perf_score_mae: 0.0670 - val_bid_strategy_accuracy: 0.2531 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0041 - val_budget_dist_mae: 0.0466 - val_budget_realloc_loss: 0.9857 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5472 - val_budget_rec_loss: 0.6443 - val_campaign_score_loss: 0.0038 - val_campaign_score_mae: 0.0439 - val_loss: 7.9116 - val_performance_alerts_accuracy: 0.9966 - val_performance_alerts_loss: 0.0132 - val_roi_forecast_loss: 0.0089 - val_roi_forecast_mae: 0.0403 - learning_rate: 2.5000e-04
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5059 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0150 - avg_perf_score_mae: 0.0956 - bid_strategy_accuracy: 0.2570 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0215 - budget_dist_mae: 0.1115 - budget_realloc_loss: 0.9997 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5456 - budget_rec_loss: 0.6471 - campaign_score_loss: 0.0116 - campaign_score_mae: 0.0825 - loss: 7.9583 - performance_alerts_accuracy: 0.9956 - performance_alerts_loss: 0.0151 - roi_forecast_loss: 0.0110 - roi_forecast_mae: 0.0531 - val_audience_exp_accuracy: 0.4931 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0077 - val_avg_perf_score_mae: 0.0693 - val_bid_strategy_accuracy: 0.2550 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0444 - val_budget_realloc_loss: 0.9857 - val_budget_realloc_mae: 0.8594 - val_budget_rec_accuracy: 0.5471 - val_budget_rec_loss: 0.6449 - val_campaign_score_loss: 0.0045 - val_campaign_score_mae: 0.0486 - val_loss: 7.9145 - val_performance_alerts_accuracy: 0.9959 - val_performance_alerts_loss: 0.0137 - val_roi_forecast_loss: 0.0098 - val_roi_forecast_mae: 0.0411 - learning_rate: 2.5000e-04
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - audience_exp_accuracy: 0.5053 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0150 - avg_perf_score_mae: 0.0953 - bid_strategy_accuracy: 0.2595 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0213 - budget_dist_mae: 0.1110 - budget_realloc_loss: 0.9997 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5470 - budget_rec_loss: 0.6469 - campaign_score_loss: 0.0116 - campaign_score_mae: 0.0820 - loss: 7.9583 - performance_alerts_accuracy: 0.9956 - performance_alerts_loss: 0.0149 - roi_forecast_loss: 0.0118 - roi_forecast_mae: 0.0530 - val_audience_exp_accuracy: 0.4909 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0081 - val_avg_perf_score_mae: 0.0709 - val_bid_strategy_accuracy: 0.2559 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0443 - val_budget_realloc_loss: 0.9857 - val_budget_realloc_mae: 0.8594 - val_budget_rec_accuracy: 0.5501 - val_budget_rec_loss: 0.6466 - val_campaign_score_loss: 0.0044 - val_campaign_score_mae: 0.0490 - val_loss: 7.9163 - val_performance_alerts_accuracy: 0.9945 - val_performance_alerts_loss: 0.0153 - val_roi_forecast_loss: 0.0078 - val_roi_forecast_mae: 0.0341 - learning_rate: 2.5000e-04
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5046 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0149 - avg_perf_score_mae: 0.0951 - bid_strategy_accuracy: 0.2582 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0210 - budget_dist_mae: 0.1103 - budget_realloc_loss: 0.9994 - budget_realloc_mae: 0.8634 - budget_rec_accuracy: 0.5458 - budget_rec_loss: 0.6472 - campaign_score_loss: 0.0115 - campaign_score_mae: 0.0822 - loss: 7.9579 - performance_alerts_accuracy: 0.9955 - performance_alerts_loss: 0.0153 - roi_forecast_loss: 0.0112 - roi_forecast_mae: 0.0525 - val_audience_exp_accuracy: 0.4920 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0089 - val_avg_perf_score_mae: 0.0747 - val_bid_strategy_accuracy: 0.2535 - val_bid_strategy_loss: 1.3865 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0440 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5458 - val_budget_rec_loss: 0.6455 - val_campaign_score_loss: 0.0054 - val_campaign_score_mae: 0.0552 - val_loss: 7.9130 - val_performance_alerts_accuracy: 0.9952 - val_performance_alerts_loss: 0.0142 - val_roi_forecast_loss: 0.0048 - val_roi_forecast_mae: 0.0325 - learning_rate: 2.5000e-04
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5042 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0144 - avg_perf_score_mae: 0.0940 - bid_strategy_accuracy: 0.2573 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0209 - budget_dist_mae: 0.1097 - budget_realloc_loss: 0.9996 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5479 - budget_rec_loss: 0.6462 - campaign_score_loss: 0.0110 - campaign_score_mae: 0.0807 - loss: 7.9551 - performance_alerts_accuracy: 0.9959 - performance_alerts_loss: 0.0144 - roi_forecast_loss: 0.0116 - roi_forecast_mae: 0.0519 - val_audience_exp_accuracy: 0.4921 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0078 - val_avg_perf_score_mae: 0.0689 - val_bid_strategy_accuracy: 0.2551 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0444 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5478 - val_budget_rec_loss: 0.6437 - val_campaign_score_loss: 0.0042 - val_campaign_score_mae: 0.0458 - val_loss: 7.9145 - val_performance_alerts_accuracy: 0.9969 - val_performance_alerts_loss: 0.0125 - val_roi_forecast_loss: 0.0127 - val_roi_forecast_mae: 0.0448 - learning_rate: 1.2500e-04
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5044 - audience_exp_loss: 0.6931 - avg_perf_score_loss: 0.0145 - avg_perf_score_mae: 0.0935 - bid_strategy_accuracy: 0.2589 - bid_strategy_loss: 1.3861 - budget_dist_loss: 0.0205 - budget_dist_mae: 0.1093 - budget_realloc_loss: 1.0001 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5466 - budget_rec_loss: 0.6460 - campaign_score_loss: 0.0111 - campaign_score_mae: 0.0803 - loss: 7.9539 - performance_alerts_accuracy: 0.9961 - performance_alerts_loss: 0.0140 - roi_forecast_loss: 0.0108 - roi_forecast_mae: 0.0513 - val_audience_exp_accuracy: 0.4914 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0080 - val_avg_perf_score_mae: 0.0701 - val_bid_strategy_accuracy: 0.2570 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0035 - val_budget_dist_mae: 0.0437 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5494 - val_budget_rec_loss: 0.6433 - val_campaign_score_loss: 0.0044 - val_campaign_score_mae: 0.0477 - val_loss: 7.9134 - val_performance_alerts_accuracy: 0.9970 - val_performance_alerts_loss: 0.0122 - val_roi_forecast_loss: 0.0122 - val_roi_forecast_mae: 0.0449 - learning_rate: 1.2500e-04
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5065 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0150 - avg_perf_score_mae: 0.0956 - bid_strategy_accuracy: 0.2596 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0215 - budget_dist_mae: 0.1116 - budget_realloc_loss: 0.9994 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5480 - budget_rec_loss: 0.6463 - campaign_score_loss: 0.0116 - campaign_score_mae: 0.0824 - loss: 7.9565 - performance_alerts_accuracy: 0.9959 - performance_alerts_loss: 0.0145 - roi_forecast_loss: 0.0108 - roi_forecast_mae: 0.0526 - val_audience_exp_accuracy: 0.4922 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0075 - val_avg_perf_score_mae: 0.0680 - val_bid_strategy_accuracy: 0.2553 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0041 - val_budget_dist_mae: 0.0468 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5473 - val_budget_rec_loss: 0.6439 - val_campaign_score_loss: 0.0038 - val_campaign_score_mae: 0.0443 - val_loss: 7.9134 - val_performance_alerts_accuracy: 0.9970 - val_performance_alerts_loss: 0.0127 - val_roi_forecast_loss: 0.0113 - val_roi_forecast_mae: 0.0422 - learning_rate: 1.2500e-04
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - audience_exp_accuracy: 0.5061 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0147 - avg_perf_score_mae: 0.0948 - bid_strategy_accuracy: 0.2590 - bid_strategy_loss: 1.3858 - budget_dist_loss: 0.0211 - budget_dist_mae: 0.1108 - budget_realloc_loss: 0.9997 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5434 - budget_rec_loss: 0.6467 - campaign_score_loss: 0.0114 - campaign_score_mae: 0.0818 - loss: 7.9565 - performance_alerts_accuracy: 0.9956 - performance_alerts_loss: 0.0147 - roi_forecast_loss: 0.0112 - roi_forecast_mae: 0.0522 - val_audience_exp_accuracy: 0.4924 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0081 - val_avg_perf_score_mae: 0.0696 - val_bid_strategy_accuracy: 0.2544 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0039 - val_budget_dist_mae: 0.0452 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5443 - val_budget_rec_loss: 0.6443 - val_campaign_score_loss: 0.0049 - val_campaign_score_mae: 0.0486 - val_loss: 7.9118 - val_performance_alerts_accuracy: 0.9962 - val_performance_alerts_loss: 0.0132 - val_roi_forecast_loss: 0.0072 - val_roi_forecast_mae: 0.0376 - learning_rate: 1.2500e-04
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - audience_exp_accuracy: 0.5070 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0147 - avg_perf_score_mae: 0.0944 - bid_strategy_accuracy: 0.2579 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0214 - budget_dist_mae: 0.1109 - budget_realloc_loss: 1.0000 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5448 - budget_rec_loss: 0.6463 - campaign_score_loss: 0.0113 - campaign_score_mae: 0.0815 - loss: 7.9557 - performance_alerts_accuracy: 0.9959 - performance_alerts_loss: 0.0142 - roi_forecast_loss: 0.0112 - roi_forecast_mae: 0.0521 - val_audience_exp_accuracy: 0.4910 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0081 - val_avg_perf_score_mae: 0.0702 - val_bid_strategy_accuracy: 0.2553 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0445 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5468 - val_budget_rec_loss: 0.6435 - val_campaign_score_loss: 0.0050 - val_campaign_score_mae: 0.0499 - val_loss: 7.9107 - val_performance_alerts_accuracy: 0.9969 - val_performance_alerts_loss: 0.0124 - val_roi_forecast_loss: 0.0080 - val_roi_forecast_mae: 0.0369 - learning_rate: 1.2500e-04
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5056 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0146 - avg_perf_score_mae: 0.0941 - bid_strategy_accuracy: 0.2600 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0210 - budget_dist_mae: 0.1102 - budget_realloc_loss: 1.0002 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5472 - budget_rec_loss: 0.6462 - campaign_score_loss: 0.0112 - campaign_score_mae: 0.0812 - loss: 7.9535 - performance_alerts_accuracy: 0.9961 - performance_alerts_loss: 0.0141 - roi_forecast_loss: 0.0098 - roi_forecast_mae: 0.0513 - val_audience_exp_accuracy: 0.4912 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0081 - val_avg_perf_score_mae: 0.0701 - val_bid_strategy_accuracy: 0.2546 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0038 - val_budget_dist_mae: 0.0442 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5455 - val_budget_rec_loss: 0.6437 - val_campaign_score_loss: 0.0046 - val_campaign_score_mae: 0.0478 - val_loss: 7.9146 - val_performance_alerts_accuracy: 0.9973 - val_performance_alerts_loss: 0.0125 - val_roi_forecast_loss: 0.0117 - val_roi_forecast_mae: 0.0377 - learning_rate: 1.2500e-04
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5047 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0144 - avg_perf_score_mae: 0.0939 - bid_strategy_accuracy: 0.2610 - bid_strategy_loss: 1.3860 - budget_dist_loss: 0.0210 - budget_dist_mae: 0.1102 - budget_realloc_loss: 1.0001 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5474 - budget_rec_loss: 0.6463 - campaign_score_loss: 0.0111 - campaign_score_mae: 0.0806 - loss: 7.9544 - performance_alerts_accuracy: 0.9960 - performance_alerts_loss: 0.0143 - roi_forecast_loss: 0.0104 - roi_forecast_mae: 0.0512 - val_audience_exp_accuracy: 0.4926 - val_audience_exp_loss: 0.6934 - val_avg_perf_score_loss: 0.0082 - val_avg_perf_score_mae: 0.0716 - val_bid_strategy_accuracy: 0.2572 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0041 - val_budget_dist_mae: 0.0461 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5483 - val_budget_rec_loss: 0.6437 - val_campaign_score_loss: 0.0048 - val_campaign_score_mae: 0.0515 - val_loss: 7.9098 - val_performance_alerts_accuracy: 0.9969 - val_performance_alerts_loss: 0.0126 - val_roi_forecast_loss: 0.0061 - val_roi_forecast_mae: 0.0354 - learning_rate: 1.2500e-04
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5059 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0144 - avg_perf_score_mae: 0.0936 - bid_strategy_accuracy: 0.2588 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0208 - budget_dist_mae: 0.1097 - budget_realloc_loss: 0.9995 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5483 - budget_rec_loss: 0.6459 - campaign_score_loss: 0.0109 - campaign_score_mae: 0.0803 - loss: 7.9532 - performance_alerts_accuracy: 0.9961 - performance_alerts_loss: 0.0141 - roi_forecast_loss: 0.0106 - roi_forecast_mae: 0.0515 - val_audience_exp_accuracy: 0.4922 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0071 - val_avg_perf_score_mae: 0.0666 - val_bid_strategy_accuracy: 0.2548 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0036 - val_budget_dist_mae: 0.0443 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5468 - val_budget_rec_loss: 0.6439 - val_campaign_score_loss: 0.0036 - val_campaign_score_mae: 0.0431 - val_loss: 7.9086 - val_performance_alerts_accuracy: 0.9965 - val_performance_alerts_loss: 0.0128 - val_roi_forecast_loss: 0.0074 - val_roi_forecast_mae: 0.0358 - learning_rate: 1.2500e-04
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5052 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0144 - avg_perf_score_mae: 0.0937 - bid_strategy_accuracy: 0.2583 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0207 - budget_dist_mae: 0.1092 - budget_realloc_loss: 1.0003 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5470 - budget_rec_loss: 0.6463 - campaign_score_loss: 0.0110 - campaign_score_mae: 0.0804 - loss: 7.9535 - performance_alerts_accuracy: 0.9959 - performance_alerts_loss: 0.0143 - roi_forecast_loss: 0.0104 - roi_forecast_mae: 0.0512 - val_audience_exp_accuracy: 0.4927 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0083 - val_avg_perf_score_mae: 0.0713 - val_bid_strategy_accuracy: 0.2561 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0035 - val_budget_dist_mae: 0.0437 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5483 - val_budget_rec_loss: 0.6439 - val_campaign_score_loss: 0.0050 - val_campaign_score_mae: 0.0506 - val_loss: 7.9124 - val_performance_alerts_accuracy: 0.9964 - val_performance_alerts_loss: 0.0127 - val_roi_forecast_loss: 0.0087 - val_roi_forecast_mae: 0.0401 - learning_rate: 1.2500e-04
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5033 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0143 - avg_perf_score_mae: 0.0935 - bid_strategy_accuracy: 0.2616 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0204 - budget_dist_mae: 0.1089 - budget_realloc_loss: 0.9997 - budget_realloc_mae: 0.8633 - budget_rec_accuracy: 0.5478 - budget_rec_loss: 0.6458 - campaign_score_loss: 0.0109 - campaign_score_mae: 0.0800 - loss: 7.9517 - performance_alerts_accuracy: 0.9961 - performance_alerts_loss: 0.0138 - roi_forecast_loss: 0.0100 - roi_forecast_mae: 0.0508 - val_audience_exp_accuracy: 0.4902 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0082 - val_avg_perf_score_mae: 0.0707 - val_bid_strategy_accuracy: 0.2541 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0037 - val_budget_dist_mae: 0.0446 - val_budget_realloc_loss: 0.9858 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5491 - val_budget_rec_loss: 0.6434 - val_campaign_score_loss: 0.0048 - val_campaign_score_mae: 0.0500 - val_loss: 7.9147 - val_performance_alerts_accuracy: 0.9969 - val_performance_alerts_loss: 0.0123 - val_roi_forecast_loss: 0.0122 - val_roi_forecast_mae: 0.0396 - learning_rate: 1.2500e-04
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5056 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0142 - avg_perf_score_mae: 0.0930 - bid_strategy_accuracy: 0.2587 - bid_strategy_loss: 1.3858 - budget_dist_loss: 0.0205 - budget_dist_mae: 0.1085 - budget_realloc_loss: 0.9999 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5473 - budget_rec_loss: 0.6458 - campaign_score_loss: 0.0108 - campaign_score_mae: 0.0797 - loss: 7.9511 - performance_alerts_accuracy: 0.9960 - performance_alerts_loss: 0.0139 - roi_forecast_loss: 0.0100 - roi_forecast_mae: 0.0507 - val_audience_exp_accuracy: 0.4909 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0081 - val_avg_perf_score_mae: 0.0713 - val_bid_strategy_accuracy: 0.2541 - val_bid_strategy_loss: 1.3864 - val_budget_dist_loss: 0.0040 - val_budget_dist_mae: 0.0459 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5491 - val_budget_rec_loss: 0.6434 - val_campaign_score_loss: 0.0050 - val_campaign_score_mae: 0.0522 - val_loss: 7.9121 - val_performance_alerts_accuracy: 0.9966 - val_performance_alerts_loss: 0.0123 - val_roi_forecast_loss: 0.0090 - val_roi_forecast_mae: 0.0376 - learning_rate: 1.2500e-04
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5040 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0141 - avg_perf_score_mae: 0.0926 - bid_strategy_accuracy: 0.2602 - bid_strategy_loss: 1.3858 - budget_dist_loss: 0.0202 - budget_dist_mae: 0.1082 - budget_realloc_loss: 1.0000 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5484 - budget_rec_loss: 0.6452 - campaign_score_loss: 0.0107 - campaign_score_mae: 0.0790 - loss: 7.9506 - performance_alerts_accuracy: 0.9962 - performance_alerts_loss: 0.0134 - roi_forecast_loss: 0.0107 - roi_forecast_mae: 0.0501 - val_audience_exp_accuracy: 0.4908 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0077 - val_avg_perf_score_mae: 0.0690 - val_bid_strategy_accuracy: 0.2553 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0037 - val_budget_dist_mae: 0.0447 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8593 - val_budget_rec_accuracy: 0.5448 - val_budget_rec_loss: 0.6438 - val_campaign_score_loss: 0.0042 - val_campaign_score_mae: 0.0467 - val_loss: 7.9144 - val_performance_alerts_accuracy: 0.9962 - val_performance_alerts_loss: 0.0126 - val_roi_forecast_loss: 0.0121 - val_roi_forecast_mae: 0.0395 - learning_rate: 6.2500e-05
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5068 - audience_exp_loss: 0.6930 - avg_perf_score_loss: 0.0142 - avg_perf_score_mae: 0.0929 - bid_strategy_accuracy: 0.2593 - bid_strategy_loss: 1.3859 - budget_dist_loss: 0.0201 - budget_dist_mae: 0.1077 - budget_realloc_loss: 0.9995 - budget_realloc_mae: 0.8632 - budget_rec_accuracy: 0.5464 - budget_rec_loss: 0.6454 - campaign_score_loss: 0.0107 - campaign_score_mae: 0.0792 - loss: 7.9504 - performance_alerts_accuracy: 0.9960 - performance_alerts_loss: 0.0134 - roi_forecast_loss: 0.0102 - roi_forecast_mae: 0.0506 - val_audience_exp_accuracy: 0.4916 - val_audience_exp_loss: 0.6935 - val_avg_perf_score_loss: 0.0076 - val_avg_perf_score_mae: 0.0689 - val_bid_strategy_accuracy: 0.2575 - val_bid_strategy_loss: 1.3863 - val_budget_dist_loss: 0.0037 - val_budget_dist_mae: 0.0445 - val_budget_realloc_loss: 0.9859 - val_budget_realloc_mae: 0.8592 - val_budget_rec_accuracy: 0.5480 - val_budget_rec_loss: 0.6435 - val_campaign_score_loss: 0.0043 - val_campaign_score_mae: 0.0469 - val_loss: 7.9091 - val_performance_alerts_accuracy: 0.9968 - val_performance_alerts_loss: 0.0124 - val_roi_forecast_loss: 0.0075 - val_roi_forecast_mae: 0.0355 - learning_rate: 6.2500e-05
# Multi-task model training completed successfully!
# Weighted multi-task model training completed successfully!

# %%
# -------------------------------
# Multi-Task Neural Network Training Code (Improved for Imbalanced Classification)
# -------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall

# -------------------------------
# 1. Train-test split for features
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# -------------------------------
# 2. Train-test split for each target
def split_target(y):
    return train_test_split(y, test_size=0.2, random_state=42)

y_campaign_score_train, y_campaign_score_test = split_target(y_campaign_score)
y_roi_forecast_train, y_roi_forecast_test = split_target(y_roi_forecast)
y_avg_perf_score_train, y_avg_perf_score_test = split_target(y_avg_perf_score)
y_budget_realloc_train, y_budget_realloc_test = split_target(y_budget_realloc)
y_budget_dist_train, y_budget_dist_test = split_target(y_budget_dist_total)

y_performance_alerts_train, y_performance_alerts_test = split_target(y_performance_alerts)
y_budget_rec_train, y_budget_rec_test = split_target(y_budget_rec)
y_audience_exp_train, y_audience_exp_test = split_target(y_audience_exp)
y_bid_strategy_train, y_bid_strategy_test = split_target(y_bid_strategy)

# -------------------------------
# 3. Scale regression targets
scalers = {}
for name, y_train, y_test in [
    ('campaign_score', y_campaign_score_train, y_campaign_score_test),
    ('roi_forecast', y_roi_forecast_train, y_roi_forecast_test),
    ('avg_perf_score', y_avg_perf_score_train, y_avg_perf_score_test),
    ('budget_realloc', y_budget_realloc_train, y_budget_realloc_test)
]:
    scaler = StandardScaler()
    y_train_scaled = scaler.fit_transform(np.array(y_train).reshape(-1,1))
    y_test_scaled = scaler.transform(np.array(y_test).reshape(-1,1))
    if name == 'campaign_score':
        y_campaign_score_train, y_campaign_score_test = y_train_scaled, y_test_scaled
    elif name == 'roi_forecast':
        y_roi_forecast_train, y_roi_forecast_test = y_train_scaled, y_test_scaled
    elif name == 'avg_perf_score':
        y_avg_perf_score_train, y_avg_perf_score_test = y_train_scaled, y_test_scaled
    elif name == 'budget_realloc':
        y_budget_realloc_train, y_budget_realloc_test = y_train_scaled, y_test_scaled
    scalers[name] = scaler

# Scale multi-output regression: budget_dist (n_samples,3)
scaler_budget_dist = StandardScaler()
y_budget_dist_train = scaler_budget_dist.fit_transform(y_budget_dist_train)
y_budget_dist_test = scaler_budget_dist.transform(y_budget_dist_test)
scalers['budget_dist'] = scaler_budget_dist

# -------------------------------
# 4. Compute sample weights for imbalanced classification
def get_sample_weights(y_train, classes):
    weights = compute_class_weight('balanced', classes=classes, y=y_train)
    return np.array([weights[int(label)] for label in y_train])

sample_weights = {
    'audience_exp': get_sample_weights(y_audience_exp_train, np.unique(y_audience_exp_train)),
    'bid_strategy': get_sample_weights(y_bid_strategy_train, np.unique(y_bid_strategy_train))
}

# -------------------------------
# 5. Build multi-task neural network
input_layer = Input(shape=(X_train.shape[1],), name='input_features')

# Shared layers
x = Dense(256, activation='relu')(input_layer)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)

# Regression outputs
campaign_score_out = Dense(32, activation='relu')(x)
campaign_score_out = Dense(1, name='campaign_score')(campaign_score_out)

roi_forecast_out = Dense(16, activation='relu')(x)
roi_forecast_out = Dense(1, name='roi_forecast')(roi_forecast_out)

avg_perf_score_out = Dense(16, activation='relu')(x)
avg_perf_score_out = Dense(1, name='avg_perf_score')(avg_perf_score_out)

budget_realloc_out = Dense(16, activation='relu')(x)
budget_realloc_out = Dense(1, name='budget_realloc')(budget_realloc_out)

budget_dist_out = Dense(16, activation='relu')(x)
budget_dist_out = Dense(3, name='budget_dist')(budget_dist_out)

# Classification outputs
performance_alerts_out = Dense(16, activation='relu')(x)
performance_alerts_out = Dense(1, activation='sigmoid', name='performance_alerts')(performance_alerts_out)

budget_rec_out = Dense(32, activation='relu')(x)
budget_rec_out = Dense(len(np.unique(y_budget_rec_train)), activation='softmax', name='budget_rec')(budget_rec_out)

audience_exp_out = Dense(16, activation='relu')(x)
audience_exp_out = Dense(1, activation='sigmoid', name='audience_exp')(audience_exp_out)

bid_strategy_out = Dense(32, activation='relu')(x)
bid_strategy_out = Dense(len(np.unique(y_bid_strategy_train)), activation='softmax', name='bid_strategy')(bid_strategy_out)

# Build model
model = Model(inputs=input_layer, outputs=[
    campaign_score_out, roi_forecast_out, avg_perf_score_out, budget_dist_out, budget_realloc_out,
    performance_alerts_out, budget_rec_out, audience_exp_out, bid_strategy_out
])

# -------------------------------
# 6. Compile model with loss weights and per-class metrics
model.compile(
    optimizer='adam',
    loss={
        'campaign_score': 'mse',
        'roi_forecast': 'mse',
        'avg_perf_score': 'mse',
        'budget_dist': 'mse',
        'budget_realloc': 'mse',
        'performance_alerts': 'binary_crossentropy',
        'budget_rec': 'sparse_categorical_crossentropy',
        'audience_exp': 'binary_crossentropy',
        'bid_strategy': 'sparse_categorical_crossentropy'
    },
    metrics={
        'campaign_score': 'mae',
        'roi_forecast': 'mae',
        'avg_perf_score': 'mae',
        'budget_dist': 'mae',
        'budget_realloc': 'mae',
        'performance_alerts': ['accuracy', Precision(), Recall()],
        'budget_rec': ['accuracy'],
        'audience_exp': ['accuracy', Precision(), Recall()],
        'bid_strategy': ['accuracy']
    },
    loss_weights={
        'campaign_score': 1.0,
        'roi_forecast': 1.0,
        'avg_perf_score': 1.0,
        'budget_dist': 1.0,
        'budget_realloc': 1.0,
        'performance_alerts': 1.0,
        'budget_rec': 1.0,
        'audience_exp': 3.0,
        'bid_strategy': 3.0
    }
)

# -------------------------------
# 7. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
]

# -------------------------------
# 8. Prepare y and sample_weights as lists for multi-output training
y_train_list = [
    y_campaign_score_train,
    y_roi_forecast_train,
    y_avg_perf_score_train,
    y_budget_dist_train,
    y_budget_realloc_train,
    y_performance_alerts_train,
    y_budget_rec_train,
    y_audience_exp_train,
    y_bid_strategy_train
]

y_test_list = [
    y_campaign_score_test,
    y_roi_forecast_test,
    y_avg_perf_score_test,
    y_budget_dist_test,
    y_budget_realloc_test,
    y_performance_alerts_test,
    y_budget_rec_test,
    y_audience_exp_test,
    y_bid_strategy_test
]

sample_weights_list = [
    None,  # campaign_score
    None,  # roi_forecast
    None,  # avg_perf_score
    None,  # budget_dist
    None,  # budget_realloc
    None,  # performance_alerts
    None,  # budget_rec
    sample_weights['audience_exp'],  # audience_exp
    sample_weights['bid_strategy']   # bid_strategy
]

# -------------------------------
# 9. Train model with per-output sample weights, increased epochs
history = model.fit(
    X_train, y_train_list,
    validation_data=(X_test, y_test_list),
    sample_weight=sample_weights_list,
    epochs=100,
    batch_size=512,
    callbacks=callbacks,
    verbose=1
)

print("Improved weighted multi-task model training completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 206
#     192 sample_weights_list = [
#     193     None,  # campaign_score
#     194     None,  # roi_forecast
#    (...)    201     sample_weights['bid_strategy']   # bid_strategy
#     202 ]
#     204 # -------------------------------
#     205 # 9. Train model with per-output sample weights, increased epochs
# --> 206 history = model.fit(
#     207     X_train, y_train_list,
#     208     validation_data=(X_test, y_test_list),
#     209     sample_weight=sample_weights_list,
#     210     epochs=100,
#     211     batch_size=512,
#     212     callbacks=callbacks,
#     213     verbose=1
#     214 )
#     216 print("Improved weighted multi-task model training completed successfully!")
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\data_adapters\data_adapter_utils.py:104, in <genexpr>(.0)
#     103 def check_data_cardinality(data):
# --> 104     num_samples = set(int(i.shape[0]) for i in tree.flatten(data))
#     105     if len(num_samples) > 1:
#     106         msg = (
#     107             "Data cardinality is ambiguous. "
#     108             "Make sure all arrays contain the same number of samples."
#     109         )
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 244
#     230 sample_weights_list = [
#     231     None,  # campaign_score
#     232     None,  # roi_forecast
#    (...)    239     sample_weights['bid_strategy']    # bid_strategy
#     240 ]
#     242 # -------------------------------
#     243 # 10. Train model
# --> 244 history = model.fit(
#     245     X_train, y_train_list,
#     246     validation_data=(X_test, y_test_list),
#     247     sample_weight=sample_weights_list,
#     248     epochs=100,
#     249     batch_size=512,
#     250     callbacks=callbacks,
#     251     verbose=1
#     252 )
#     254 print("Improved weighted multi-task model training completed successfully!")
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\jyoti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\trainers\data_adapters\data_adapter_utils.py:104, in <genexpr>(.0)
#     103 def check_data_cardinality(data):
# --> 104     num_samples = set(int(i.shape[0]) for i in tree.flatten(data))
#     105     if len(num_samples) > 1:
#     106         msg = (
#     107             "Data cardinality is ambiguous. "
#     108             "Make sure all arrays contain the same number of samples."
#     109         )
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# Multi-Task Neural Network Training Code (Stable Sample Weight Handling)
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall

# -------------------------------
# Assume X_scaled and all targets are already defined
# X_scaled = ...
# y_campaign_score, y_roi_forecast, y_avg_perf_score, y_budget_realloc, y_budget_dist_total
# y_performance_alerts, y_budget_rec, y_audience_exp, y_bid_strategy

# -------------------------------
# 1. Train-test split for features
X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42)

# -------------------------------
# 2. Train-test split for each target
def split_target(y):
    return train_test_split(y, test_size=0.2, random_state=42)

(
    y_campaign_score_train, y_campaign_score_test,
    y_roi_forecast_train, y_roi_forecast_test,
    y_avg_perf_score_train, y_avg_perf_score_test,
    y_budget_realloc_train, y_budget_realloc_test,
    y_budget_dist_train, y_budget_dist_test,
    y_performance_alerts_train, y_performance_alerts_test,
    y_budget_rec_train, y_budget_rec_test,
    y_audience_exp_train, y_audience_exp_test,
    y_bid_strategy_train, y_bid_strategy_test
) = (
    *split_target(y_campaign_score),
    *split_target(y_roi_forecast),
    *split_target(y_avg_perf_score),
    *split_target(y_budget_realloc),
    *split_target(y_budget_dist_total),
    *split_target(y_performance_alerts),
    *split_target(y_budget_rec),
    *split_target(y_audience_exp),
    *split_target(y_bid_strategy)
)

# -------------------------------
# 2b. Flatten classification targets
for var in ['y_performance_alerts', 'y_budget_rec', 'y_audience_exp', 'y_bid_strategy']:
    locals()[f'{var}_train'] = np.ravel(locals()[f'{var}_train'])
    locals()[f'{var}_test'] = np.ravel(locals()[f'{var}_test'])

# -------------------------------
# 3. Scale regression targets
scalers = {}
for name, y_train, y_test in [
    ('campaign_score', y_campaign_score_train, y_campaign_score_test),
    ('roi_forecast', y_roi_forecast_train, y_roi_forecast_test),
    ('avg_perf_score', y_avg_perf_score_train, y_avg_perf_score_test),
    ('budget_realloc', y_budget_realloc_train, y_budget_realloc_test)
]:
    scaler = StandardScaler()
    y_train_scaled = scaler.fit_transform(np.array(y_train).reshape(-1,1))
    y_test_scaled = scaler.transform(np.array(y_test).reshape(-1,1))
    locals()[f'{name}_train'], locals()[f'{name}_test'] = y_train_scaled, y_test_scaled
    scalers[name] = scaler

# Multi-output regression: budget_dist (n_samples,3)
scaler_budget_dist = StandardScaler()
y_budget_dist_train = scaler_budget_dist.fit_transform(y_budget_dist_train)
y_budget_dist_test = scaler_budget_dist.transform(y_budget_dist_test)
scalers['budget_dist'] = scaler_budget_dist

# -------------------------------
# 4. Prepare targets list (order must match model outputs)
y_train_list = [
    y_campaign_score_train,
    y_roi_forecast_train,
    y_avg_perf_score_train,
    y_budget_dist_train,
    y_budget_realloc_train,
    y_performance_alerts_train,
    y_budget_rec_train,
    y_audience_exp_train,
    y_bid_strategy_train
]

y_test_list = [
    y_campaign_score_test,
    y_roi_forecast_test,
    y_avg_perf_score_test,
    y_budget_dist_test,
    y_budget_realloc_test,
    y_performance_alerts_test,
    y_budget_rec_test,
    y_audience_exp_test,
    y_bid_strategy_test
]

# -------------------------------
# 5. Class weights for classification outputs
audience_exp_class_weights = {0: 1.004, 1: 0.996}
bid_strategy_class_weights = {0: 1.001, 1: 0.996, 2: 0.998, 3: 1.005}

def apply_class_weights(y_train, class_weights):
    return np.array([class_weights[int(label)] for label in y_train])

# -------------------------------
# 6. Sample weights list aligned to outputs
sample_weights_list = [
    np.ones(len(y_campaign_score_train)),  # regression
    np.ones(len(y_roi_forecast_train)),    # regression
    np.ones(len(y_avg_perf_score_train)),  # regression
    np.ones(len(y_budget_dist_train)),     # regression
    np.ones(len(y_budget_realloc_train)),  # regression
    np.ones(len(y_performance_alerts_train)),  # binary
    np.ones(len(y_budget_rec_train)),      # multi-class
    apply_class_weights(y_audience_exp_train, audience_exp_class_weights),  # weighted binary
    apply_class_weights(y_bid_strategy_train, bid_strategy_class_weights)   # weighted multi-class
]

# -------------------------------
# 7. Build multi-task neural network
input_layer = Input(shape=(X_train.shape[1],), name='input_features')
x = Dense(256, activation='relu')(input_layer)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(64, activation='relu')(x)

# Regression outputs
campaign_score_out = Dense(32, activation='relu')(x)
campaign_score_out = Dense(1, name='campaign_score')(campaign_score_out)

roi_forecast_out = Dense(16, activation='relu')(x)
roi_forecast_out = Dense(1, name='roi_forecast')(roi_forecast_out)

avg_perf_score_out = Dense(16, activation='relu')(x)
avg_perf_score_out = Dense(1, name='avg_perf_score')(avg_perf_score_out)

budget_realloc_out = Dense(16, activation='relu')(x)
budget_realloc_out = Dense(1, name='budget_realloc')(budget_realloc_out)

budget_dist_out = Dense(16, activation='relu')(x)
budget_dist_out = Dense(3, name='budget_dist')(budget_dist_out)

# Classification outputs
performance_alerts_out = Dense(16, activation='relu')(x)
performance_alerts_out = Dense(1, activation='sigmoid', name='performance_alerts')(performance_alerts_out)

budget_rec_out = Dense(32, activation='relu')(x)
budget_rec_out = Dense(len(np.unique(y_budget_rec_train)), activation='softmax', name='budget_rec')(budget_rec_out)

audience_exp_out = Dense(16, activation='relu')(x)
audience_exp_out = Dense(1, activation='sigmoid', name='audience_exp')(audience_exp_out)

bid_strategy_out = Dense(32, activation='relu')(x)
bid_strategy_out = Dense(len(np.unique(y_bid_strategy_train)), activation='softmax', name='bid_strategy')(bid_strategy_out)

# Build model
model = Model(inputs=input_layer, outputs=[
    campaign_score_out, roi_forecast_out, avg_perf_score_out, budget_dist_out, budget_realloc_out,
    performance_alerts_out, budget_rec_out, audience_exp_out, bid_strategy_out
])

# -------------------------------
# 8. Compile model
model.compile(
    optimizer='adam',
    loss={
        'campaign_score': 'mse',
        'roi_forecast': 'mse',
        'avg_perf_score': 'mse',
        'budget_dist': 'mse',
        'budget_realloc': 'mse',
        'performance_alerts': 'binary_crossentropy',
        'budget_rec': 'sparse_categorical_crossentropy',
        'audience_exp': 'binary_crossentropy',
        'bid_strategy': 'sparse_categorical_crossentropy'
    },
    metrics={
        'campaign_score': 'mae',
        'roi_forecast': 'mae',
        'avg_perf_score': 'mae',
        'budget_dist': 'mae',
        'budget_realloc': 'mae',
        'performance_alerts': ['accuracy', Precision(), Recall()],
        'budget_rec': ['accuracy'],
        'audience_exp': ['accuracy', Precision(), Recall()],
        'bid_strategy': ['accuracy']
    },
    loss_weights={
        'campaign_score': 1.0,
        'roi_forecast': 1.0,
        'avg_perf_score': 1.0,
        'budget_dist': 1.0,
        'budget_realloc': 1.0,
        'performance_alerts': 1.0,
        'budget_rec': 1.0,
        'audience_exp': 3.0,
        'bid_strategy': 3.0
    }
)

# -------------------------------
# 9. Callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
]

# -------------------------------
# 10. Train model with sample weights
history = model.fit(
    X_train, y_train_list,
    validation_data=(X_test, y_test_list),
    sample_weight=sample_weights_list,
    epochs=100,
    batch_size=512,
    callbacks=callbacks,
    verbose=1
)

print("Weighted multi-task model training completed successfully!")
# Out:
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - audience_exp_accuracy: 0.5021 - audience_exp_loss: 0.7614 - audience_exp_precision_1: 0.5047 - audience_exp_recall_1: 0.4749 - avg_perf_score_loss: 5346.2280 - avg_perf_score_mae: 52.2788 - bid_strategy_accuracy: 0.2494 - bid_strategy_loss: 1.5028 - budget_dist_loss: 1.1431 - budget_dist_mae: 0.8882 - budget_realloc_loss: 60.4737 - budget_realloc_mae: 5.9589 - budget_rec_accuracy: 0.4479 - budget_rec_loss: 1.0071 - campaign_score_loss: 4494.6177 - campaign_score_mae: 46.4024 - loss: 11478.5322 - performance_alerts_accuracy: 0.8988 - performance_alerts_loss: 0.3034 - performance_alerts_precision: 0.0919 - performance_alerts_recall: 0.0163 - roi_forecast_loss: 1525.1689 - roi_forecast_mae: 16.9670 - val_audience_exp_accuracy: 0.5001 - val_audience_exp_loss: 0.7086 - val_audience_exp_precision_1: 0.5005 - val_audience_exp_recall_1: 0.9636 - val_avg_perf_score_loss: 519.1801 - val_avg_perf_score_mae: 18.0214 - val_bid_strategy_accuracy: 0.2513 - val_bid_strategy_loss: 1.4179 - val_budget_dist_loss: 1.0064 - val_budget_dist_mae: 0.8531 - val_budget_realloc_loss: 25.8024 - val_budget_realloc_mae: 4.1621 - val_budget_rec_accuracy: 0.4572 - val_budget_rec_loss: 0.8909 - val_campaign_score_loss: 511.0643 - val_campaign_score_mae: 17.8689 - val_loss: 2196.4243 - val_performance_alerts_accuracy: 0.9104 - val_performance_alerts_loss: 0.2110 - val_performance_alerts_precision: 0.0000e+00 - val_performance_alerts_recall: 0.0000e+00 - val_roi_forecast_loss: 1105.1677 - val_roi_forecast_mae: 12.8800 - learning_rate: 0.0010
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5009 - audience_exp_loss: 0.7539 - audience_exp_precision_1: 0.5033 - audience_exp_recall_1: 0.5036 - avg_perf_score_loss: 517.9015 - avg_perf_score_mae: 17.9782 - bid_strategy_accuracy: 0.2476 - bid_strategy_loss: 1.5000 - budget_dist_loss: 1.0077 - budget_dist_mae: 0.8520 - budget_realloc_loss: 24.2502 - budget_realloc_mae: 4.0065 - budget_rec_accuracy: 0.4643 - budget_rec_loss: 0.9207 - campaign_score_loss: 503.7386 - campaign_score_mae: 17.8000 - loss: 1424.1179 - performance_alerts_accuracy: 0.9155 - performance_alerts_loss: 0.1895 - performance_alerts_precision: 0.7520 - performance_alerts_recall: 0.0660 - roi_forecast_loss: 367.0139 - roi_forecast_mae: 7.8972 - val_audience_exp_accuracy: 0.5002 - val_audience_exp_loss: 0.7279 - val_audience_exp_precision_1: 0.5006 - val_audience_exp_recall_1: 0.9941 - val_avg_perf_score_loss: 270.3900 - val_avg_perf_score_mae: 13.1409 - val_bid_strategy_accuracy: 0.2494 - val_bid_strategy_loss: 1.4222 - val_budget_dist_loss: 1.0008 - val_budget_dist_mae: 0.8510 - val_budget_realloc_loss: 15.8200 - val_budget_realloc_mae: 3.2760 - val_budget_rec_accuracy: 0.4909 - val_budget_rec_loss: 0.7910 - val_campaign_score_loss: 254.0438 - val_campaign_score_mae: 12.7229 - val_loss: 588.9011 - val_performance_alerts_accuracy: 0.9297 - val_performance_alerts_loss: 0.1406 - val_performance_alerts_precision: 0.8243 - val_performance_alerts_recall: 0.2725 - val_roi_forecast_loss: 34.5683 - val_roi_forecast_mae: 3.8821 - learning_rate: 0.0010
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4985 - audience_exp_loss: 0.7336 - audience_exp_precision_1: 0.5008 - audience_exp_recall_1: 0.5021 - avg_perf_score_loss: 295.3019 - avg_perf_score_mae: 13.6625 - bid_strategy_accuracy: 0.2525 - bid_strategy_loss: 1.4615 - budget_dist_loss: 1.0002 - budget_dist_mae: 0.8499 - budget_realloc_loss: 16.9355 - budget_realloc_mae: 3.3646 - budget_rec_accuracy: 0.4947 - budget_rec_loss: 0.8203 - campaign_score_loss: 283.3262 - campaign_score_mae: 13.3628 - loss: 685.8967 - performance_alerts_accuracy: 0.9384 - performance_alerts_loss: 0.1364 - performance_alerts_precision: 0.7021 - performance_alerts_recall: 0.5265 - roi_forecast_loss: 81.2209 - roi_forecast_mae: 5.2259 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.6939 - val_audience_exp_precision_1: 0.4994 - val_audience_exp_recall_1: 0.6247 - val_avg_perf_score_loss: 114.9968 - val_avg_perf_score_mae: 8.5563 - val_bid_strategy_accuracy: 0.2484 - val_bid_strategy_loss: 1.4022 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8505 - val_budget_realloc_loss: 13.5863 - val_budget_realloc_mae: 3.0762 - val_budget_rec_accuracy: 0.5181 - val_budget_rec_loss: 0.7349 - val_campaign_score_loss: 99.8973 - val_campaign_score_mae: 7.8915 - val_loss: 255.8380 - val_performance_alerts_accuracy: 0.9660 - val_performance_alerts_loss: 0.0986 - val_performance_alerts_precision: 0.8351 - val_performance_alerts_recall: 0.7722 - val_roi_forecast_loss: 17.7233 - val_roi_forecast_mae: 3.0125 - learning_rate: 0.0010
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4994 - audience_exp_loss: 0.7188 - audience_exp_precision_1: 0.5018 - audience_exp_recall_1: 0.4918 - avg_perf_score_loss: 202.2803 - avg_perf_score_mae: 11.2523 - bid_strategy_accuracy: 0.2503 - bid_strategy_loss: 1.4452 - budget_dist_loss: 1.0002 - budget_dist_mae: 0.8496 - budget_realloc_loss: 15.7727 - budget_realloc_mae: 3.2666 - budget_rec_accuracy: 0.5054 - budget_rec_loss: 0.7810 - campaign_score_loss: 191.1752 - campaign_score_mae: 10.9431 - loss: 490.3044 - performance_alerts_accuracy: 0.9474 - performance_alerts_loss: 0.1178 - performance_alerts_precision: 0.7453 - performance_alerts_recall: 0.6159 - roi_forecast_loss: 72.0646 - roi_forecast_mae: 4.6179 - val_audience_exp_accuracy: 0.4992 - val_audience_exp_loss: 0.7063 - val_audience_exp_precision_1: 0.5200 - val_audience_exp_recall_1: 0.0039 - val_avg_perf_score_loss: 78.0407 - val_avg_perf_score_mae: 7.0607 - val_bid_strategy_accuracy: 0.2471 - val_bid_strategy_loss: 1.4140 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 12.6274 - val_budget_realloc_mae: 2.9858 - val_budget_rec_accuracy: 0.5193 - val_budget_rec_loss: 0.7337 - val_campaign_score_loss: 67.7826 - val_campaign_score_mae: 6.5916 - val_loss: 179.9078 - val_performance_alerts_accuracy: 0.9661 - val_performance_alerts_loss: 0.0922 - val_performance_alerts_precision: 0.8753 - val_performance_alerts_recall: 0.7247 - val_roi_forecast_loss: 12.5086 - val_roi_forecast_mae: 2.6456 - learning_rate: 0.0010
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4992 - audience_exp_loss: 0.7144 - audience_exp_precision_1: 0.5015 - audience_exp_recall_1: 0.4882 - avg_perf_score_loss: 172.0110 - avg_perf_score_mae: 10.3285 - bid_strategy_accuracy: 0.2517 - bid_strategy_loss: 1.4333 - budget_dist_loss: 0.9994 - budget_dist_mae: 0.8495 - budget_realloc_loss: 14.1412 - budget_realloc_mae: 3.1237 - budget_rec_accuracy: 0.5124 - budget_rec_loss: 0.7593 - campaign_score_loss: 161.2826 - campaign_score_mae: 9.9832 - loss: 414.3256 - performance_alerts_accuracy: 0.9539 - performance_alerts_loss: 0.1040 - performance_alerts_precision: 0.7755 - performance_alerts_recall: 0.6738 - roi_forecast_loss: 58.3185 - roi_forecast_mae: 4.1843 - val_audience_exp_accuracy: 0.4994 - val_audience_exp_loss: 0.6966 - val_audience_exp_precision_1: 0.5028 - val_audience_exp_recall_1: 0.0530 - val_avg_perf_score_loss: 64.8882 - val_avg_perf_score_mae: 6.3516 - val_bid_strategy_accuracy: 0.2517 - val_bid_strategy_loss: 1.3894 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 11.4706 - val_budget_realloc_mae: 2.8793 - val_budget_rec_accuracy: 0.5272 - val_budget_rec_loss: 0.7214 - val_campaign_score_loss: 53.8877 - val_campaign_score_mae: 5.6896 - val_loss: 151.0546 - val_performance_alerts_accuracy: 0.9668 - val_performance_alerts_loss: 0.0861 - val_performance_alerts_precision: 0.8894 - val_performance_alerts_recall: 0.7186 - val_roi_forecast_loss: 12.4025 - val_roi_forecast_mae: 2.1509 - learning_rate: 0.0010
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5005 - audience_exp_loss: 0.7112 - audience_exp_precision_1: 0.5030 - audience_exp_recall_1: 0.4908 - avg_perf_score_loss: 155.3553 - avg_perf_score_mae: 9.8028 - bid_strategy_accuracy: 0.2485 - bid_strategy_loss: 1.4202 - budget_dist_loss: 0.9998 - budget_dist_mae: 0.8495 - budget_realloc_loss: 13.5782 - budget_realloc_mae: 3.0662 - budget_rec_accuracy: 0.5114 - budget_rec_loss: 0.7540 - campaign_score_loss: 144.5290 - campaign_score_mae: 9.4430 - loss: 376.0472 - performance_alerts_accuracy: 0.9567 - performance_alerts_loss: 0.0987 - performance_alerts_precision: 0.7833 - performance_alerts_recall: 0.7051 - roi_forecast_loss: 54.0152 - roi_forecast_mae: 3.9145 - val_audience_exp_accuracy: 0.5006 - val_audience_exp_loss: 0.6944 - val_audience_exp_precision_1: 0.5016 - val_audience_exp_recall_1: 0.4712 - val_avg_perf_score_loss: 58.8686 - val_avg_perf_score_mae: 6.0963 - val_bid_strategy_accuracy: 0.2521 - val_bid_strategy_loss: 1.4063 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 11.0642 - val_budget_realloc_mae: 2.8427 - val_budget_rec_accuracy: 0.5222 - val_budget_rec_loss: 0.7407 - val_campaign_score_loss: 50.4094 - val_campaign_score_mae: 5.7171 - val_loss: 136.9391 - val_performance_alerts_accuracy: 0.9690 - val_performance_alerts_loss: 0.0829 - val_performance_alerts_precision: 0.8695 - val_performance_alerts_recall: 0.7700 - val_roi_forecast_loss: 8.0980 - val_roi_forecast_mae: 2.0913 - learning_rate: 0.0010
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4974 - audience_exp_loss: 0.7047 - audience_exp_precision_1: 0.4997 - audience_exp_recall_1: 0.4823 - avg_perf_score_loss: 145.6804 - avg_perf_score_mae: 9.4686 - bid_strategy_accuracy: 0.2501 - bid_strategy_loss: 1.4159 - budget_dist_loss: 1.0002 - budget_dist_mae: 0.8495 - budget_realloc_loss: 13.3074 - budget_realloc_mae: 3.0492 - budget_rec_accuracy: 0.5100 - budget_rec_loss: 0.7462 - campaign_score_loss: 135.2670 - campaign_score_mae: 9.1002 - loss: 352.7770 - performance_alerts_accuracy: 0.9581 - performance_alerts_loss: 0.0965 - performance_alerts_precision: 0.7939 - performance_alerts_recall: 0.7102 - roi_forecast_loss: 50.0831 - roi_forecast_mae: 3.6912 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.7031 - val_audience_exp_precision_1: 0.4998 - val_audience_exp_recall_1: 0.9580 - val_avg_perf_score_loss: 51.8214 - val_avg_perf_score_mae: 5.6216 - val_bid_strategy_accuracy: 0.2503 - val_bid_strategy_loss: 1.3913 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 11.0743 - val_budget_realloc_mae: 2.8418 - val_budget_rec_accuracy: 0.5206 - val_budget_rec_loss: 0.7248 - val_campaign_score_loss: 41.6395 - val_campaign_score_mae: 4.8849 - val_loss: 122.9135 - val_performance_alerts_accuracy: 0.9693 - val_performance_alerts_loss: 0.0798 - val_performance_alerts_precision: 0.8731 - val_performance_alerts_recall: 0.7683 - val_roi_forecast_loss: 9.9905 - val_roi_forecast_mae: 2.3417 - learning_rate: 0.0010
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4988 - audience_exp_loss: 0.7076 - audience_exp_precision_1: 0.5012 - audience_exp_recall_1: 0.4924 - avg_perf_score_loss: 137.7748 - avg_perf_score_mae: 9.1639 - bid_strategy_accuracy: 0.2515 - bid_strategy_loss: 1.4121 - budget_dist_loss: 0.9995 - budget_dist_mae: 0.8495 - budget_realloc_loss: 13.0456 - budget_realloc_mae: 3.0218 - budget_rec_accuracy: 0.5145 - budget_rec_loss: 0.7393 - campaign_score_loss: 126.3999 - campaign_score_mae: 8.7520 - loss: 329.2134 - performance_alerts_accuracy: 0.9589 - performance_alerts_loss: 0.0946 - performance_alerts_precision: 0.8048 - performance_alerts_recall: 0.7063 - roi_forecast_loss: 43.9901 - roi_forecast_mae: 3.4635 - val_audience_exp_accuracy: 0.4992 - val_audience_exp_loss: 0.6956 - val_audience_exp_precision_1: 0.5013 - val_audience_exp_recall_1: 0.0577 - val_avg_perf_score_loss: 49.4908 - val_avg_perf_score_mae: 5.5723 - val_bid_strategy_accuracy: 0.2480 - val_bid_strategy_loss: 1.3964 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.8627 - val_budget_realloc_mae: 2.8221 - val_budget_rec_accuracy: 0.5250 - val_budget_rec_loss: 0.7137 - val_campaign_score_loss: 39.6439 - val_campaign_score_mae: 4.9903 - val_loss: 117.6047 - val_performance_alerts_accuracy: 0.9690 - val_performance_alerts_loss: 0.0800 - val_performance_alerts_precision: 0.8736 - val_performance_alerts_recall: 0.7644 - val_roi_forecast_loss: 9.1580 - val_roi_forecast_mae: 2.0093 - learning_rate: 0.0010
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5000 - audience_exp_loss: 0.7065 - audience_exp_precision_1: 0.5024 - audience_exp_recall_1: 0.4962 - avg_perf_score_loss: 130.6489 - avg_perf_score_mae: 8.9079 - bid_strategy_accuracy: 0.2492 - bid_strategy_loss: 1.4073 - budget_dist_loss: 1.0001 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.9156 - budget_realloc_mae: 3.0101 - budget_rec_accuracy: 0.5140 - budget_rec_loss: 0.7370 - campaign_score_loss: 118.9963 - campaign_score_mae: 8.4737 - loss: 317.1022 - performance_alerts_accuracy: 0.9599 - performance_alerts_loss: 0.0936 - performance_alerts_precision: 0.8112 - performance_alerts_recall: 0.7117 - roi_forecast_loss: 46.4080 - roi_forecast_mae: 3.3355 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.6951 - val_audience_exp_precision_1: 0.4925 - val_audience_exp_recall_1: 0.0263 - val_avg_perf_score_loss: 43.9903 - val_avg_perf_score_mae: 5.2905 - val_bid_strategy_accuracy: 0.2482 - val_bid_strategy_loss: 1.3998 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.7367 - val_budget_realloc_mae: 2.8106 - val_budget_rec_accuracy: 0.5263 - val_budget_rec_loss: 0.7174 - val_campaign_score_loss: 36.0651 - val_campaign_score_mae: 4.8601 - val_loss: 107.5279 - val_performance_alerts_accuracy: 0.9679 - val_performance_alerts_loss: 0.0814 - val_performance_alerts_precision: 0.9161 - val_performance_alerts_recall: 0.7069 - val_roi_forecast_loss: 8.2712 - val_roi_forecast_mae: 1.9226 - learning_rate: 0.0010
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5014 - audience_exp_loss: 0.6994 - audience_exp_precision_1: 0.5037 - audience_exp_recall_1: 0.5079 - avg_perf_score_loss: 121.7769 - avg_perf_score_mae: 8.5996 - bid_strategy_accuracy: 0.2501 - bid_strategy_loss: 1.4071 - budget_dist_loss: 1.0003 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.6562 - budget_realloc_mae: 2.9887 - budget_rec_accuracy: 0.5156 - budget_rec_loss: 0.7345 - campaign_score_loss: 109.7672 - campaign_score_mae: 8.1420 - loss: 290.1510 - performance_alerts_accuracy: 0.9598 - performance_alerts_loss: 0.0935 - performance_alerts_precision: 0.8074 - performance_alerts_recall: 0.7164 - roi_forecast_loss: 37.7020 - roi_forecast_mae: 3.0571 - val_audience_exp_accuracy: 0.5006 - val_audience_exp_loss: 0.6938 - val_audience_exp_precision_1: 0.5010 - val_audience_exp_recall_1: 0.7473 - val_avg_perf_score_loss: 35.5817 - val_avg_perf_score_mae: 4.7304 - val_bid_strategy_accuracy: 0.2482 - val_bid_strategy_loss: 1.3971 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.7336 - val_budget_realloc_mae: 2.8100 - val_budget_rec_accuracy: 0.5260 - val_budget_rec_loss: 0.7084 - val_campaign_score_loss: 24.0137 - val_campaign_score_mae: 3.7437 - val_loss: 86.0309 - val_performance_alerts_accuracy: 0.9705 - val_performance_alerts_loss: 0.0777 - val_performance_alerts_precision: 0.8673 - val_performance_alerts_recall: 0.7917 - val_roi_forecast_loss: 7.3830 - val_roi_forecast_mae: 1.6907 - learning_rate: 0.0010
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4989 - audience_exp_loss: 0.7001 - audience_exp_precision_1: 0.5012 - audience_exp_recall_1: 0.5030 - avg_perf_score_loss: 113.4421 - avg_perf_score_mae: 8.3017 - bid_strategy_accuracy: 0.2527 - bid_strategy_loss: 1.4050 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.5095 - budget_realloc_mae: 2.9749 - budget_rec_accuracy: 0.5137 - budget_rec_loss: 0.7315 - campaign_score_loss: 101.6266 - campaign_score_mae: 7.8149 - loss: 272.8305 - performance_alerts_accuracy: 0.9612 - performance_alerts_loss: 0.0913 - performance_alerts_precision: 0.8209 - performance_alerts_recall: 0.7179 - roi_forecast_loss: 37.0226 - roi_forecast_mae: 2.9128 - val_audience_exp_accuracy: 0.4995 - val_audience_exp_loss: 0.7104 - val_audience_exp_precision_1: 0.6216 - val_audience_exp_recall_1: 0.0023 - val_avg_perf_score_loss: 34.7187 - val_avg_perf_score_mae: 4.6295 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.3920 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.7036 - val_budget_realloc_mae: 2.8058 - val_budget_rec_accuracy: 0.5268 - val_budget_rec_loss: 0.7071 - val_campaign_score_loss: 24.6629 - val_campaign_score_mae: 3.7305 - val_loss: 90.4299 - val_performance_alerts_accuracy: 0.9667 - val_performance_alerts_loss: 0.0808 - val_performance_alerts_precision: 0.9145 - val_performance_alerts_recall: 0.6924 - val_roi_forecast_loss: 11.6569 - val_roi_forecast_mae: 1.9178 - learning_rate: 0.0010
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4993 - audience_exp_loss: 0.7011 - audience_exp_precision_1: 0.5016 - audience_exp_recall_1: 0.5150 - avg_perf_score_loss: 108.8613 - avg_perf_score_mae: 8.0968 - bid_strategy_accuracy: 0.2485 - bid_strategy_loss: 1.4045 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.4374 - budget_realloc_mae: 2.9670 - budget_rec_accuracy: 0.5185 - budget_rec_loss: 0.7268 - campaign_score_loss: 96.4363 - campaign_score_mae: 7.5671 - loss: 257.7775 - performance_alerts_accuracy: 0.9620 - performance_alerts_loss: 0.0905 - performance_alerts_precision: 0.8220 - performance_alerts_recall: 0.7273 - roi_forecast_loss: 31.8810 - roi_forecast_mae: 2.7472 - val_audience_exp_accuracy: 0.5027 - val_audience_exp_loss: 0.6933 - val_audience_exp_precision_1: 0.5049 - val_audience_exp_recall_1: 0.3776 - val_avg_perf_score_loss: 29.5866 - val_avg_perf_score_mae: 4.2539 - val_bid_strategy_accuracy: 0.2509 - val_bid_strategy_loss: 1.3914 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.9133 - val_budget_realloc_mae: 2.8274 - val_budget_rec_accuracy: 0.5260 - val_budget_rec_loss: 0.7093 - val_campaign_score_loss: 21.7496 - val_campaign_score_mae: 3.3193 - val_loss: 78.1027 - val_performance_alerts_accuracy: 0.9691 - val_performance_alerts_loss: 0.0770 - val_performance_alerts_precision: 0.8918 - val_performance_alerts_recall: 0.7454 - val_roi_forecast_loss: 7.5304 - val_roi_forecast_mae: 1.5829 - learning_rate: 0.0010
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4982 - audience_exp_loss: 0.7019 - audience_exp_precision_1: 0.5006 - audience_exp_recall_1: 0.4821 - avg_perf_score_loss: 101.5918 - avg_perf_score_mae: 7.8186 - bid_strategy_accuracy: 0.2502 - bid_strategy_loss: 1.3988 - budget_dist_loss: 0.9997 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.3205 - budget_realloc_mae: 2.9551 - budget_rec_accuracy: 0.5159 - budget_rec_loss: 0.7263 - campaign_score_loss: 89.9794 - campaign_score_mae: 7.3031 - loss: 246.5310 - performance_alerts_accuracy: 0.9608 - performance_alerts_loss: 0.0906 - performance_alerts_precision: 0.8220 - performance_alerts_recall: 0.7110 - roi_forecast_loss: 34.2250 - roi_forecast_mae: 2.7687 - val_audience_exp_accuracy: 0.5004 - val_audience_exp_loss: 0.7208 - val_audience_exp_precision_1: 0.5007 - val_audience_exp_recall_1: 0.9879 - val_avg_perf_score_loss: 28.8582 - val_avg_perf_score_mae: 4.2353 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.4079 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5747 - val_budget_realloc_mae: 2.7958 - val_budget_rec_accuracy: 0.5278 - val_budget_rec_loss: 0.7029 - val_campaign_score_loss: 22.4376 - val_campaign_score_mae: 3.6913 - val_loss: 74.3403 - val_performance_alerts_accuracy: 0.9695 - val_performance_alerts_loss: 0.0754 - val_performance_alerts_precision: 0.8749 - val_performance_alerts_recall: 0.7694 - val_roi_forecast_loss: 3.7820 - val_roi_forecast_mae: 1.5724 - learning_rate: 0.0010
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.4990 - audience_exp_loss: 0.7024 - audience_exp_precision_1: 0.5013 - audience_exp_recall_1: 0.5024 - avg_perf_score_loss: 97.0657 - avg_perf_score_mae: 7.5707 - bid_strategy_accuracy: 0.2504 - bid_strategy_loss: 1.3985 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.2509 - budget_realloc_mae: 2.9499 - budget_rec_accuracy: 0.5209 - budget_rec_loss: 0.7222 - campaign_score_loss: 85.7473 - campaign_score_mae: 7.0422 - loss: 231.6309 - performance_alerts_accuracy: 0.9631 - performance_alerts_loss: 0.0879 - performance_alerts_precision: 0.8329 - performance_alerts_recall: 0.7294 - roi_forecast_loss: 29.8656 - roi_forecast_mae: 2.6062 - val_audience_exp_accuracy: 0.5003 - val_audience_exp_loss: 0.6959 - val_audience_exp_precision_1: 0.5007 - val_audience_exp_recall_1: 0.9041 - val_avg_perf_score_loss: 46.1351 - val_avg_perf_score_mae: 5.2091 - val_bid_strategy_accuracy: 0.2492 - val_bid_strategy_loss: 1.3924 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.8937 - val_budget_realloc_mae: 2.8248 - val_budget_rec_accuracy: 0.5224 - val_budget_rec_loss: 0.7226 - val_campaign_score_loss: 53.4647 - val_campaign_score_mae: 5.5965 - val_loss: 128.6720 - val_performance_alerts_accuracy: 0.9690 - val_performance_alerts_loss: 0.0754 - val_performance_alerts_precision: 0.8775 - val_performance_alerts_recall: 0.7599 - val_roi_forecast_loss: 9.5340 - val_roi_forecast_mae: 1.7639 - learning_rate: 0.0010
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5024 - audience_exp_loss: 0.6981 - audience_exp_precision_1: 0.5046 - audience_exp_recall_1: 0.5233 - avg_perf_score_loss: 95.4654 - avg_perf_score_mae: 7.4994 - bid_strategy_accuracy: 0.2491 - bid_strategy_loss: 1.3986 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 12.1776 - budget_realloc_mae: 2.9421 - budget_rec_accuracy: 0.5218 - budget_rec_loss: 0.7212 - campaign_score_loss: 84.2303 - campaign_score_mae: 6.9547 - loss: 230.4036 - performance_alerts_accuracy: 0.9628 - performance_alerts_loss: 0.0884 - performance_alerts_precision: 0.8284 - performance_alerts_recall: 0.7311 - roi_forecast_loss: 30.2399 - roi_forecast_mae: 2.6178 - val_audience_exp_accuracy: 0.4971 - val_audience_exp_loss: 0.6940 - val_audience_exp_precision_1: 0.4989 - val_audience_exp_recall_1: 0.8642 - val_avg_perf_score_loss: 21.2397 - val_avg_perf_score_mae: 3.6705 - val_bid_strategy_accuracy: 0.2509 - val_bid_strategy_loss: 1.4021 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5028 - val_budget_realloc_mae: 2.7894 - val_budget_rec_accuracy: 0.5263 - val_budget_rec_loss: 0.7047 - val_campaign_score_loss: 11.9016 - val_campaign_score_mae: 2.6842 - val_loss: 55.5227 - val_performance_alerts_accuracy: 0.9683 - val_performance_alerts_loss: 0.0747 - val_performance_alerts_precision: 0.8922 - val_performance_alerts_recall: 0.7348 - val_roi_forecast_loss: 3.4392 - val_roi_forecast_mae: 1.0313 - learning_rate: 0.0010
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - audience_exp_accuracy: 0.5004 - audience_exp_loss: 0.6986 - audience_exp_precision_1: 0.5028 - audience_exp_recall_1: 0.4996 - avg_perf_score_loss: 87.1091 - avg_perf_score_mae: 7.1871 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.3977 - budget_dist_loss: 0.9996 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.9981 - budget_realloc_mae: 2.9293 - budget_rec_accuracy: 0.5217 - budget_rec_loss: 0.7170 - campaign_score_loss: 75.2931 - campaign_score_mae: 6.6000 - loss: 211.8134 - performance_alerts_accuracy: 0.9653 - performance_alerts_loss: 0.0844 - performance_alerts_precision: 0.8382 - performance_alerts_recall: 0.7522 - roi_forecast_loss: 29.1485 - roi_forecast_mae: 2.5165 - val_audience_exp_accuracy: 0.4972 - val_audience_exp_loss: 0.6934 - val_audience_exp_precision_1: 0.4986 - val_audience_exp_recall_1: 0.6471 - val_avg_perf_score_loss: 20.6087 - val_avg_perf_score_mae: 3.6773 - val_bid_strategy_accuracy: 0.2497 - val_bid_strategy_loss: 1.3953 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5154 - val_budget_realloc_mae: 2.7899 - val_budget_rec_accuracy: 0.5255 - val_budget_rec_loss: 0.7061 - val_campaign_score_loss: 11.2372 - val_campaign_score_mae: 2.6392 - val_loss: 56.7584 - val_performance_alerts_accuracy: 0.9692 - val_performance_alerts_loss: 0.0735 - val_performance_alerts_precision: 0.9193 - val_performance_alerts_recall: 0.7186 - val_roi_forecast_loss: 6.0102 - val_roi_forecast_mae: 1.4102 - learning_rate: 0.0010
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - audience_exp_accuracy: 0.4985 - audience_exp_loss: 0.6997 - audience_exp_precision_1: 0.5008 - audience_exp_recall_1: 0.5201 - avg_perf_score_loss: 84.4035 - avg_perf_score_mae: 7.0722 - bid_strategy_accuracy: 0.2514 - bid_strategy_loss: 1.3976 - budget_dist_loss: 0.9998 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.8658 - budget_realloc_mae: 2.9164 - budget_rec_accuracy: 0.5254 - budget_rec_loss: 0.7156 - campaign_score_loss: 72.6742 - campaign_score_mae: 6.4872 - loss: 208.1977 - performance_alerts_accuracy: 0.9658 - performance_alerts_loss: 0.0831 - performance_alerts_precision: 0.8372 - performance_alerts_recall: 0.7606 - roi_forecast_loss: 31.0808 - roi_forecast_mae: 2.5200 - val_audience_exp_accuracy: 0.4993 - val_audience_exp_loss: 0.7059 - val_audience_exp_precision_1: 0.5676 - val_audience_exp_recall_1: 0.0021 - val_avg_perf_score_loss: 24.2088 - val_avg_perf_score_mae: 3.9399 - val_bid_strategy_accuracy: 0.2526 - val_bid_strategy_loss: 1.3913 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.6980 - val_budget_realloc_mae: 2.8080 - val_budget_rec_accuracy: 0.5282 - val_budget_rec_loss: 0.6989 - val_campaign_score_loss: 16.8899 - val_campaign_score_mae: 3.2690 - val_loss: 65.5745 - val_performance_alerts_accuracy: 0.9691 - val_performance_alerts_loss: 0.0730 - val_performance_alerts_precision: 0.8976 - val_performance_alerts_recall: 0.7393 - val_roi_forecast_loss: 5.3108 - val_roi_forecast_mae: 1.3514 - learning_rate: 0.0010
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4994 - audience_exp_loss: 0.6989 - audience_exp_precision_1: 0.5018 - audience_exp_recall_1: 0.4768 - avg_perf_score_loss: 85.2724 - avg_perf_score_mae: 7.0309 - bid_strategy_accuracy: 0.2482 - bid_strategy_loss: 1.3989 - budget_dist_loss: 0.9997 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.7701 - budget_realloc_mae: 2.9066 - budget_rec_accuracy: 0.5220 - budget_rec_loss: 0.7127 - campaign_score_loss: 74.1737 - campaign_score_mae: 6.4545 - loss: 205.6638 - performance_alerts_accuracy: 0.9669 - performance_alerts_loss: 0.0817 - performance_alerts_precision: 0.8432 - performance_alerts_recall: 0.7686 - roi_forecast_loss: 26.2882 - roi_forecast_mae: 2.4535 - val_audience_exp_accuracy: 0.4999 - val_audience_exp_loss: 0.6944 - val_audience_exp_precision_1: 0.5005 - val_audience_exp_recall_1: 0.9296 - val_avg_perf_score_loss: 35.4827 - val_avg_perf_score_mae: 4.4252 - val_bid_strategy_accuracy: 0.2520 - val_bid_strategy_loss: 1.3889 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 11.0074 - val_budget_realloc_mae: 2.8347 - val_budget_rec_accuracy: 0.5304 - val_budget_rec_loss: 0.7065 - val_campaign_score_loss: 36.4919 - val_campaign_score_mae: 4.2727 - val_loss: 95.0639 - val_performance_alerts_accuracy: 0.9740 - val_performance_alerts_loss: 0.0692 - val_performance_alerts_precision: 0.8533 - val_performance_alerts_recall: 0.8571 - val_roi_forecast_loss: 3.6450 - val_roi_forecast_mae: 1.0740 - learning_rate: 0.0010
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4997 - audience_exp_loss: 0.6995 - audience_exp_precision_1: 0.5020 - audience_exp_recall_1: 0.5072 - avg_perf_score_loss: 79.7937 - avg_perf_score_mae: 6.8613 - bid_strategy_accuracy: 0.2513 - bid_strategy_loss: 1.3976 - budget_dist_loss: 0.9995 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.6799 - budget_realloc_mae: 2.8980 - budget_rec_accuracy: 0.5291 - budget_rec_loss: 0.7082 - campaign_score_loss: 68.5013 - campaign_score_mae: 6.2535 - loss: 194.2246 - performance_alerts_accuracy: 0.9683 - performance_alerts_loss: 0.0782 - performance_alerts_precision: 0.8460 - performance_alerts_recall: 0.7845 - roi_forecast_loss: 26.1278 - roi_forecast_mae: 2.3590 - val_audience_exp_accuracy: 0.4978 - val_audience_exp_loss: 0.6963 - val_audience_exp_precision_1: 0.4778 - val_audience_exp_recall_1: 0.0268 - val_avg_perf_score_loss: 20.0690 - val_avg_perf_score_mae: 3.5923 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.3904 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5263 - val_budget_realloc_mae: 2.7912 - val_budget_rec_accuracy: 0.5357 - val_budget_rec_loss: 0.6939 - val_campaign_score_loss: 11.2167 - val_campaign_score_mae: 2.5490 - val_loss: 53.7364 - val_performance_alerts_accuracy: 0.9746 - val_performance_alerts_loss: 0.0672 - val_performance_alerts_precision: 0.9349 - val_performance_alerts_recall: 0.7700 - val_roi_forecast_loss: 3.5899 - val_roi_forecast_mae: 1.3329 - learning_rate: 0.0010
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4996 - audience_exp_loss: 0.6978 - audience_exp_precision_1: 0.5019 - audience_exp_recall_1: 0.5172 - avg_perf_score_loss: 77.0329 - avg_perf_score_mae: 6.7312 - bid_strategy_accuracy: 0.2501 - bid_strategy_loss: 1.3968 - budget_dist_loss: 0.9998 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.4490 - budget_realloc_mae: 2.8792 - budget_rec_accuracy: 0.5258 - budget_rec_loss: 0.7054 - campaign_score_loss: 65.3441 - campaign_score_mae: 6.0976 - loss: 192.9899 - performance_alerts_accuracy: 0.9707 - performance_alerts_loss: 0.0745 - performance_alerts_precision: 0.8571 - performance_alerts_recall: 0.8023 - roi_forecast_loss: 31.0452 - roi_forecast_mae: 2.4517 - val_audience_exp_accuracy: 0.4993 - val_audience_exp_loss: 0.6938 - val_audience_exp_precision_1: 0.5041 - val_audience_exp_recall_1: 0.0310 - val_avg_perf_score_loss: 26.5332 - val_avg_perf_score_mae: 4.1518 - val_bid_strategy_accuracy: 0.2483 - val_bid_strategy_loss: 1.3907 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5540 - val_budget_realloc_mae: 2.7938 - val_budget_rec_accuracy: 0.5292 - val_budget_rec_loss: 0.6893 - val_campaign_score_loss: 20.3080 - val_campaign_score_mae: 3.6624 - val_loss: 71.8082 - val_performance_alerts_accuracy: 0.9736 - val_performance_alerts_loss: 0.0635 - val_performance_alerts_precision: 0.8906 - val_performance_alerts_recall: 0.8046 - val_roi_forecast_loss: 5.8527 - val_roi_forecast_mae: 1.2755 - learning_rate: 0.0010
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4981 - audience_exp_loss: 0.6983 - audience_exp_precision_1: 0.5005 - audience_exp_recall_1: 0.4801 - avg_perf_score_loss: 74.2904 - avg_perf_score_mae: 6.6053 - bid_strategy_accuracy: 0.2516 - bid_strategy_loss: 1.3960 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.3852 - budget_realloc_mae: 2.8698 - budget_rec_accuracy: 0.5257 - budget_rec_loss: 0.7019 - campaign_score_loss: 63.1423 - campaign_score_mae: 5.9808 - loss: 182.2322 - performance_alerts_accuracy: 0.9716 - performance_alerts_loss: 0.0717 - performance_alerts_precision: 0.8517 - performance_alerts_recall: 0.8219 - roi_forecast_loss: 25.2177 - roi_forecast_mae: 2.2357 - val_audience_exp_accuracy: 0.4980 - val_audience_exp_loss: 0.6990 - val_audience_exp_precision_1: 0.4994 - val_audience_exp_recall_1: 0.9385 - val_avg_perf_score_loss: 18.6025 - val_avg_perf_score_mae: 3.4187 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.3912 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5600 - val_budget_realloc_mae: 2.7941 - val_budget_rec_accuracy: 0.5321 - val_budget_rec_loss: 0.6884 - val_campaign_score_loss: 10.4359 - val_campaign_score_mae: 2.3028 - val_loss: 48.9755 - val_performance_alerts_accuracy: 0.9739 - val_performance_alerts_loss: 0.0616 - val_performance_alerts_precision: 0.8973 - val_performance_alerts_recall: 0.8001 - val_roi_forecast_loss: 0.9966 - val_roi_forecast_mae: 0.7080 - learning_rate: 0.0010
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5002 - audience_exp_loss: 0.7000 - audience_exp_precision_1: 0.5027 - audience_exp_recall_1: 0.4895 - avg_perf_score_loss: 73.6150 - avg_perf_score_mae: 6.5633 - bid_strategy_accuracy: 0.2498 - bid_strategy_loss: 1.3950 - budget_dist_loss: 1.0003 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.3302 - budget_realloc_mae: 2.8687 - budget_rec_accuracy: 0.5268 - budget_rec_loss: 0.6997 - campaign_score_loss: 62.3419 - campaign_score_mae: 5.9233 - loss: 185.1951 - performance_alerts_accuracy: 0.9732 - performance_alerts_loss: 0.0687 - performance_alerts_precision: 0.8573 - performance_alerts_recall: 0.8360 - roi_forecast_loss: 29.7569 - roi_forecast_mae: 2.3248 - val_audience_exp_accuracy: 0.5009 - val_audience_exp_loss: 0.7002 - val_audience_exp_precision_1: 0.5009 - val_audience_exp_recall_1: 1.0000 - val_avg_perf_score_loss: 17.8506 - val_avg_perf_score_mae: 3.4364 - val_bid_strategy_accuracy: 0.2502 - val_bid_strategy_loss: 1.3931 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.2930 - val_budget_realloc_mae: 2.7710 - val_budget_rec_accuracy: 0.5313 - val_budget_rec_loss: 0.6884 - val_campaign_score_loss: 9.5676 - val_campaign_score_mae: 2.4256 - val_loss: 49.1407 - val_performance_alerts_accuracy: 0.9751 - val_performance_alerts_loss: 0.0624 - val_performance_alerts_precision: 0.9505 - val_performance_alerts_recall: 0.7616 - val_roi_forecast_loss: 3.1431 - val_roi_forecast_mae: 0.8355 - learning_rate: 0.0010
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5007 - audience_exp_loss: 0.6962 - audience_exp_precision_1: 0.5030 - audience_exp_recall_1: 0.5220 - avg_perf_score_loss: 69.0173 - avg_perf_score_mae: 6.3760 - bid_strategy_accuracy: 0.2504 - bid_strategy_loss: 1.3954 - budget_dist_loss: 1.0003 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.1361 - budget_realloc_mae: 2.8488 - budget_rec_accuracy: 0.5247 - budget_rec_loss: 0.6987 - campaign_score_loss: 57.6035 - campaign_score_mae: 5.7010 - loss: 172.2654 - performance_alerts_accuracy: 0.9744 - performance_alerts_loss: 0.0671 - performance_alerts_precision: 0.8627 - performance_alerts_recall: 0.8445 - roi_forecast_loss: 26.6062 - roi_forecast_mae: 2.2284 - val_audience_exp_accuracy: 0.4979 - val_audience_exp_loss: 0.6965 - val_audience_exp_precision_1: 0.4994 - val_audience_exp_recall_1: 0.9525 - val_avg_perf_score_loss: 22.2640 - val_avg_perf_score_mae: 3.8377 - val_bid_strategy_accuracy: 0.2481 - val_bid_strategy_loss: 1.3981 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.5680 - val_budget_realloc_mae: 2.7971 - val_budget_rec_accuracy: 0.5319 - val_budget_rec_loss: 0.6842 - val_campaign_score_loss: 15.8159 - val_campaign_score_mae: 3.3409 - val_loss: 59.6472 - val_performance_alerts_accuracy: 0.9782 - val_performance_alerts_loss: 0.0564 - val_performance_alerts_precision: 0.9129 - val_performance_alerts_recall: 0.8364 - val_roi_forecast_loss: 2.7373 - val_roi_forecast_mae: 0.9974 - learning_rate: 0.0010
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5008 - audience_exp_loss: 0.7005 - audience_exp_precision_1: 0.5031 - audience_exp_recall_1: 0.5137 - avg_perf_score_loss: 66.9447 - avg_perf_score_mae: 6.2704 - bid_strategy_accuracy: 0.2480 - bid_strategy_loss: 1.3954 - budget_dist_loss: 1.0000 - budget_dist_mae: 0.8495 - budget_realloc_loss: 11.0384 - budget_realloc_mae: 2.8410 - budget_rec_accuracy: 0.5287 - budget_rec_loss: 0.6946 - campaign_score_loss: 55.6346 - campaign_score_mae: 5.5915 - loss: 166.0686 - performance_alerts_accuracy: 0.9754 - performance_alerts_loss: 0.0641 - performance_alerts_precision: 0.8667 - performance_alerts_recall: 0.8528 - roi_forecast_loss: 24.3576 - roi_forecast_mae: 2.2060 - val_audience_exp_accuracy: 0.5006 - val_audience_exp_loss: 0.6944 - val_audience_exp_precision_1: 0.5008 - val_audience_exp_recall_1: 0.9119 - val_avg_perf_score_loss: 38.0028 - val_avg_perf_score_mae: 4.6501 - val_bid_strategy_accuracy: 0.2506 - val_bid_strategy_loss: 1.3938 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.5452 - val_budget_realloc_mae: 2.7951 - val_budget_rec_accuracy: 0.5354 - val_budget_rec_loss: 0.6799 - val_campaign_score_loss: 34.8987 - val_campaign_score_mae: 4.3865 - val_loss: 93.3795 - val_performance_alerts_accuracy: 0.9859 - val_performance_alerts_loss: 0.0518 - val_performance_alerts_precision: 0.9319 - val_performance_alerts_recall: 0.9090 - val_roi_forecast_loss: 1.1658 - val_roi_forecast_mae: 0.6624 - learning_rate: 0.0010
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4995 - audience_exp_loss: 0.6972 - audience_exp_precision_1: 0.5019 - audience_exp_recall_1: 0.4981 - avg_perf_score_loss: 67.1785 - avg_perf_score_mae: 6.2368 - bid_strategy_accuracy: 0.2511 - bid_strategy_loss: 1.3938 - budget_dist_loss: 1.0000 - budget_dist_mae: 0.8496 - budget_realloc_loss: 10.9623 - budget_realloc_mae: 2.8363 - budget_rec_accuracy: 0.5292 - budget_rec_loss: 0.6944 - campaign_score_loss: 56.7277 - campaign_score_mae: 5.5851 - loss: 169.1998 - performance_alerts_accuracy: 0.9764 - performance_alerts_loss: 0.0633 - performance_alerts_precision: 0.8708 - performance_alerts_recall: 0.8603 - roi_forecast_loss: 26.2685 - roi_forecast_mae: 2.2521 - val_audience_exp_accuracy: 0.5019 - val_audience_exp_loss: 0.6983 - val_audience_exp_precision_1: 0.5016 - val_audience_exp_recall_1: 0.8770 - val_avg_perf_score_loss: 22.6955 - val_avg_perf_score_mae: 3.8569 - val_bid_strategy_accuracy: 0.2498 - val_bid_strategy_loss: 1.3905 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.2038 - val_budget_realloc_mae: 2.7639 - val_budget_rec_accuracy: 0.5363 - val_budget_rec_loss: 0.6778 - val_campaign_score_loss: 14.6251 - val_campaign_score_mae: 3.0726 - val_loss: 57.8955 - val_performance_alerts_accuracy: 0.9851 - val_performance_alerts_loss: 0.0517 - val_performance_alerts_precision: 0.9219 - val_performance_alerts_recall: 0.9101 - val_roi_forecast_loss: 1.9289 - val_roi_forecast_mae: 0.7970 - learning_rate: 0.0010
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5035 - audience_exp_loss: 0.6977 - audience_exp_precision_1: 0.5059 - audience_exp_recall_1: 0.4967 - avg_perf_score_loss: 62.8391 - avg_perf_score_mae: 6.0752 - bid_strategy_accuracy: 0.2490 - bid_strategy_loss: 1.3930 - budget_dist_loss: 0.9998 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.8693 - budget_realloc_mae: 2.8269 - budget_rec_accuracy: 0.5285 - budget_rec_loss: 0.6965 - campaign_score_loss: 51.7341 - campaign_score_mae: 5.4074 - loss: 158.4797 - performance_alerts_accuracy: 0.9764 - performance_alerts_loss: 0.0631 - performance_alerts_precision: 0.8683 - performance_alerts_recall: 0.8641 - roi_forecast_loss: 24.8695 - roi_forecast_mae: 2.1260 - val_audience_exp_accuracy: 0.5018 - val_audience_exp_loss: 0.6940 - val_audience_exp_precision_1: 0.5163 - val_audience_exp_recall_1: 0.0870 - val_avg_perf_score_loss: 20.9804 - val_avg_perf_score_mae: 3.6370 - val_bid_strategy_accuracy: 0.2481 - val_bid_strategy_loss: 1.3941 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.2678 - val_budget_realloc_mae: 2.7692 - val_budget_rec_accuracy: 0.5348 - val_budget_rec_loss: 0.6847 - val_campaign_score_loss: 14.3261 - val_campaign_score_mae: 2.8288 - val_loss: 55.6259 - val_performance_alerts_accuracy: 0.9825 - val_performance_alerts_loss: 0.0528 - val_performance_alerts_precision: 0.9338 - val_performance_alerts_recall: 0.8660 - val_roi_forecast_loss: 1.6742 - val_roi_forecast_mae: 0.7444 - learning_rate: 0.0010
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5006 - audience_exp_loss: 0.6949 - audience_exp_precision_1: 0.5030 - audience_exp_recall_1: 0.4827 - avg_perf_score_loss: 59.9389 - avg_perf_score_mae: 5.9525 - bid_strategy_accuracy: 0.2508 - bid_strategy_loss: 1.3901 - budget_dist_loss: 0.9994 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.7427 - budget_realloc_mae: 2.8147 - budget_rec_accuracy: 0.5297 - budget_rec_loss: 0.6914 - campaign_score_loss: 48.7480 - campaign_score_mae: 5.2258 - loss: 152.4308 - performance_alerts_accuracy: 0.9770 - performance_alerts_loss: 0.0612 - performance_alerts_precision: 0.8698 - performance_alerts_recall: 0.8701 - roi_forecast_loss: 24.8391 - roi_forecast_mae: 2.0808 - val_audience_exp_accuracy: 0.4973 - val_audience_exp_loss: 0.6973 - val_audience_exp_precision_1: 0.4990 - val_audience_exp_recall_1: 0.8797 - val_avg_perf_score_loss: 23.2407 - val_avg_perf_score_mae: 3.7636 - val_bid_strategy_accuracy: 0.2499 - val_bid_strategy_loss: 1.3894 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.1725 - val_budget_realloc_mae: 2.7604 - val_budget_rec_accuracy: 0.5368 - val_budget_rec_loss: 0.6770 - val_campaign_score_loss: 16.2244 - val_campaign_score_mae: 3.0564 - val_loss: 59.2760 - val_performance_alerts_accuracy: 0.9863 - val_performance_alerts_loss: 0.0495 - val_performance_alerts_precision: 0.9217 - val_performance_alerts_recall: 0.9263 - val_roi_forecast_loss: 1.2505 - val_roi_forecast_mae: 0.8327 - learning_rate: 5.0000e-04
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4986 - audience_exp_loss: 0.6955 - audience_exp_precision_1: 0.5009 - audience_exp_recall_1: 0.5251 - avg_perf_score_loss: 58.8762 - avg_perf_score_mae: 5.8578 - bid_strategy_accuracy: 0.2508 - bid_strategy_loss: 1.3899 - budget_dist_loss: 1.0004 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.7053 - budget_realloc_mae: 2.8088 - budget_rec_accuracy: 0.5290 - budget_rec_loss: 0.6921 - campaign_score_loss: 47.8578 - campaign_score_mae: 5.1547 - loss: 147.3248 - performance_alerts_accuracy: 0.9768 - performance_alerts_loss: 0.0617 - performance_alerts_precision: 0.8706 - performance_alerts_recall: 0.8663 - roi_forecast_loss: 22.2459 - roi_forecast_mae: 1.9876 - val_audience_exp_accuracy: 0.4992 - val_audience_exp_loss: 0.6970 - val_audience_exp_precision_1: 0.5056 - val_audience_exp_recall_1: 0.0136 - val_avg_perf_score_loss: 28.8906 - val_avg_perf_score_mae: 4.1841 - val_bid_strategy_accuracy: 0.2494 - val_bid_strategy_loss: 1.3882 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.1666 - val_budget_realloc_mae: 2.7598 - val_budget_rec_accuracy: 0.5375 - val_budget_rec_loss: 0.6789 - val_campaign_score_loss: 21.6296 - val_campaign_score_mae: 3.6518 - val_loss: 70.4708 - val_performance_alerts_accuracy: 0.9832 - val_performance_alerts_loss: 0.0513 - val_performance_alerts_precision: 0.9203 - val_performance_alerts_recall: 0.8894 - val_roi_forecast_loss: 1.3175 - val_roi_forecast_mae: 0.7562 - learning_rate: 5.0000e-04
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4989 - audience_exp_loss: 0.6952 - audience_exp_precision_1: 0.5013 - audience_exp_recall_1: 0.4868 - avg_perf_score_loss: 58.3542 - avg_perf_score_mae: 5.8425 - bid_strategy_accuracy: 0.2505 - bid_strategy_loss: 1.3902 - budget_dist_loss: 0.9998 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.6927 - budget_realloc_mae: 2.8104 - budget_rec_accuracy: 0.5289 - budget_rec_loss: 0.6920 - campaign_score_loss: 47.5718 - campaign_score_mae: 5.1347 - loss: 146.1495 - performance_alerts_accuracy: 0.9771 - performance_alerts_loss: 0.0608 - performance_alerts_precision: 0.8673 - performance_alerts_recall: 0.8742 - roi_forecast_loss: 21.6330 - roi_forecast_mae: 2.0081 - val_audience_exp_accuracy: 0.4954 - val_audience_exp_loss: 0.6935 - val_audience_exp_precision_1: 0.4977 - val_audience_exp_recall_1: 0.7929 - val_avg_perf_score_loss: 18.4292 - val_avg_perf_score_mae: 3.3944 - val_bid_strategy_accuracy: 0.2515 - val_bid_strategy_loss: 1.3905 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.2259 - val_budget_realloc_mae: 2.7656 - val_budget_rec_accuracy: 0.5373 - val_budget_rec_loss: 0.6753 - val_campaign_score_loss: 8.4822 - val_campaign_score_mae: 2.0948 - val_loss: 46.2556 - val_performance_alerts_accuracy: 0.9872 - val_performance_alerts_loss: 0.0486 - val_performance_alerts_precision: 0.9286 - val_performance_alerts_recall: 0.9291 - val_roi_forecast_loss: 0.8396 - val_roi_forecast_mae: 0.6257 - learning_rate: 5.0000e-04
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - audience_exp_accuracy: 0.4992 - audience_exp_loss: 0.6952 - audience_exp_precision_1: 0.5015 - audience_exp_recall_1: 0.5100 - avg_perf_score_loss: 59.0760 - avg_perf_score_mae: 5.8485 - bid_strategy_accuracy: 0.2505 - bid_strategy_loss: 1.3897 - budget_dist_loss: 1.0004 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.6345 - budget_realloc_mae: 2.8032 - budget_rec_accuracy: 0.5271 - budget_rec_loss: 0.6941 - campaign_score_loss: 48.1773 - campaign_score_mae: 5.1398 - loss: 150.7325 - performance_alerts_accuracy: 0.9761 - performance_alerts_loss: 0.0624 - performance_alerts_precision: 0.8652 - performance_alerts_recall: 0.8637 - roi_forecast_loss: 24.6222 - roi_forecast_mae: 2.0027 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.6991 - val_audience_exp_precision_1: 0.4783 - val_audience_exp_recall_1: 0.0011 - val_avg_perf_score_loss: 26.7218 - val_avg_perf_score_mae: 4.1376 - val_bid_strategy_accuracy: 0.2420 - val_bid_strategy_loss: 1.3882 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.1818 - val_budget_realloc_mae: 2.7616 - val_budget_rec_accuracy: 0.5368 - val_budget_rec_loss: 0.6782 - val_campaign_score_loss: 20.2995 - val_campaign_score_mae: 3.5542 - val_loss: 66.7167 - val_performance_alerts_accuracy: 0.9845 - val_performance_alerts_loss: 0.0505 - val_performance_alerts_precision: 0.9167 - val_performance_alerts_recall: 0.9095 - val_roi_forecast_loss: 1.1832 - val_roi_forecast_mae: 0.7295 - learning_rate: 5.0000e-04
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4987 - audience_exp_loss: 0.6955 - audience_exp_precision_1: 0.5011 - audience_exp_recall_1: 0.4959 - avg_perf_score_loss: 54.4177 - avg_perf_score_mae: 5.6756 - bid_strategy_accuracy: 0.2507 - bid_strategy_loss: 1.3899 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.6025 - budget_realloc_mae: 2.8007 - budget_rec_accuracy: 0.5264 - budget_rec_loss: 0.6944 - campaign_score_loss: 43.4089 - campaign_score_mae: 4.9347 - loss: 136.3481 - performance_alerts_accuracy: 0.9761 - performance_alerts_loss: 0.0624 - performance_alerts_precision: 0.8650 - performance_alerts_recall: 0.8644 - roi_forecast_loss: 19.9510 - roi_forecast_mae: 1.9547 - val_audience_exp_accuracy: 0.4999 - val_audience_exp_loss: 0.6932 - val_audience_exp_precision_1: 0.5006 - val_audience_exp_recall_1: 0.6370 - val_avg_perf_score_loss: 20.8464 - val_avg_perf_score_mae: 3.5785 - val_bid_strategy_accuracy: 0.2532 - val_bid_strategy_loss: 1.3877 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.0670 - val_budget_realloc_mae: 2.7505 - val_budget_rec_accuracy: 0.5329 - val_budget_rec_loss: 0.6820 - val_campaign_score_loss: 11.7634 - val_campaign_score_mae: 2.5194 - val_loss: 54.0347 - val_performance_alerts_accuracy: 0.9843 - val_performance_alerts_loss: 0.0501 - val_performance_alerts_precision: 0.9179 - val_performance_alerts_recall: 0.9051 - val_roi_forecast_loss: 3.0467 - val_roi_forecast_mae: 1.2587 - learning_rate: 5.0000e-04
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5010 - audience_exp_loss: 0.6951 - audience_exp_precision_1: 0.5032 - audience_exp_recall_1: 0.5141 - avg_perf_score_loss: 54.7592 - avg_perf_score_mae: 5.6725 - bid_strategy_accuracy: 0.2512 - bid_strategy_loss: 1.3902 - budget_dist_loss: 1.0000 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.5965 - budget_realloc_mae: 2.8027 - budget_rec_accuracy: 0.5301 - budget_rec_loss: 0.6945 - campaign_score_loss: 43.6413 - campaign_score_mae: 4.9260 - loss: 139.9994 - performance_alerts_accuracy: 0.9760 - performance_alerts_loss: 0.0626 - performance_alerts_precision: 0.8645 - performance_alerts_recall: 0.8633 - roi_forecast_loss: 22.9500 - roi_forecast_mae: 1.9278 - val_audience_exp_accuracy: 0.4991 - val_audience_exp_loss: 0.6961 - val_audience_exp_precision_1: 1.0000 - val_audience_exp_recall_1: 9.9810e-05 - val_avg_perf_score_loss: 32.7047 - val_avg_perf_score_mae: 4.6049 - val_bid_strategy_accuracy: 0.2500 - val_bid_strategy_loss: 1.3884 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.2230 - val_budget_realloc_mae: 2.7652 - val_budget_rec_accuracy: 0.5362 - val_budget_rec_loss: 0.6801 - val_campaign_score_loss: 27.8736 - val_campaign_score_mae: 4.1871 - val_loss: 80.8407 - val_performance_alerts_accuracy: 0.9847 - val_performance_alerts_loss: 0.0511 - val_performance_alerts_precision: 0.9183 - val_performance_alerts_recall: 0.9101 - val_roi_forecast_loss: 1.5543 - val_roi_forecast_mae: 0.8409 - learning_rate: 5.0000e-04
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5001 - audience_exp_loss: 0.6957 - audience_exp_precision_1: 0.5026 - audience_exp_recall_1: 0.4746 - avg_perf_score_loss: 53.5226 - avg_perf_score_mae: 5.6078 - bid_strategy_accuracy: 0.2492 - bid_strategy_loss: 1.3894 - budget_dist_loss: 1.0003 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.5919 - budget_realloc_mae: 2.8012 - budget_rec_accuracy: 0.5293 - budget_rec_loss: 0.6958 - campaign_score_loss: 42.6660 - campaign_score_mae: 4.8594 - loss: 139.4067 - performance_alerts_accuracy: 0.9757 - performance_alerts_loss: 0.0633 - performance_alerts_precision: 0.8623 - performance_alerts_recall: 0.8634 - roi_forecast_loss: 24.5654 - roi_forecast_mae: 1.9394 - val_audience_exp_accuracy: 0.5016 - val_audience_exp_loss: 0.6947 - val_audience_exp_precision_1: 0.5013 - val_audience_exp_recall_1: 0.9815 - val_avg_perf_score_loss: 22.7991 - val_avg_perf_score_mae: 3.5626 - val_bid_strategy_accuracy: 0.2539 - val_bid_strategy_loss: 1.3953 - val_budget_dist_loss: 1.0005 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.0879 - val_budget_realloc_mae: 2.7525 - val_budget_rec_accuracy: 0.5338 - val_budget_rec_loss: 0.6817 - val_campaign_score_loss: 15.7507 - val_campaign_score_mae: 2.6092 - val_loss: 57.9682 - val_performance_alerts_accuracy: 0.9844 - val_performance_alerts_loss: 0.0509 - val_performance_alerts_precision: 0.9061 - val_performance_alerts_recall: 0.9218 - val_roi_forecast_loss: 0.8806 - val_roi_forecast_mae: 0.7426 - learning_rate: 5.0000e-04
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5014 - audience_exp_loss: 0.6961 - audience_exp_precision_1: 0.5036 - audience_exp_recall_1: 0.5224 - avg_perf_score_loss: 52.3537 - avg_perf_score_mae: 5.5691 - bid_strategy_accuracy: 0.2502 - bid_strategy_loss: 1.3896 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8496 - budget_realloc_loss: 10.5299 - budget_realloc_mae: 2.7947 - budget_rec_accuracy: 0.5278 - budget_rec_loss: 0.6942 - campaign_score_loss: 41.6890 - campaign_score_mae: 4.8242 - loss: 134.5252 - performance_alerts_accuracy: 0.9760 - performance_alerts_loss: 0.0625 - performance_alerts_precision: 0.8626 - performance_alerts_recall: 0.8660 - roi_forecast_loss: 21.9066 - roi_forecast_mae: 1.9148 - val_audience_exp_accuracy: 0.4990 - val_audience_exp_loss: 0.6941 - val_audience_exp_precision_1: 0.4991 - val_audience_exp_recall_1: 0.0272 - val_avg_perf_score_loss: 28.9488 - val_avg_perf_score_mae: 4.2029 - val_bid_strategy_accuracy: 0.2532 - val_bid_strategy_loss: 1.3891 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8504 - val_budget_realloc_loss: 10.0540 - val_budget_realloc_mae: 2.7497 - val_budget_rec_accuracy: 0.5347 - val_budget_rec_loss: 0.6813 - val_campaign_score_loss: 20.2425 - val_campaign_score_mae: 3.3659 - val_loss: 73.3964 - val_performance_alerts_accuracy: 0.9832 - val_performance_alerts_loss: 0.0517 - val_performance_alerts_precision: 0.9232 - val_performance_alerts_recall: 0.8861 - val_roi_forecast_loss: 5.7221 - val_roi_forecast_mae: 0.8303 - learning_rate: 5.0000e-04
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5018 - audience_exp_loss: 0.6946 - audience_exp_precision_1: 0.5042 - audience_exp_recall_1: 0.4926 - avg_perf_score_loss: 49.9652 - avg_perf_score_mae: 5.4243 - bid_strategy_accuracy: 0.2506 - bid_strategy_loss: 1.3890 - budget_dist_loss: 0.9999 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.4553 - budget_realloc_mae: 2.7872 - budget_rec_accuracy: 0.5297 - budget_rec_loss: 0.6944 - campaign_score_loss: 39.0196 - campaign_score_mae: 4.6412 - loss: 127.7831 - performance_alerts_accuracy: 0.9761 - performance_alerts_loss: 0.0633 - performance_alerts_precision: 0.8626 - performance_alerts_recall: 0.8687 - roi_forecast_loss: 20.5269 - roi_forecast_mae: 1.8761 - val_audience_exp_accuracy: 0.5011 - val_audience_exp_loss: 0.6933 - val_audience_exp_precision_1: 0.5024 - val_audience_exp_recall_1: 0.4360 - val_avg_perf_score_loss: 28.2038 - val_avg_perf_score_mae: 4.1724 - val_bid_strategy_accuracy: 0.2490 - val_bid_strategy_loss: 1.3886 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.0984 - val_budget_realloc_mae: 2.7547 - val_budget_rec_accuracy: 0.5331 - val_budget_rec_loss: 0.6793 - val_campaign_score_loss: 22.9071 - val_campaign_score_mae: 3.5782 - val_loss: 72.4724 - val_performance_alerts_accuracy: 0.9840 - val_performance_alerts_loss: 0.0505 - val_performance_alerts_precision: 0.9168 - val_performance_alerts_recall: 0.9040 - val_roi_forecast_loss: 2.9463 - val_roi_forecast_mae: 1.0996 - learning_rate: 2.5000e-04
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - audience_exp_accuracy: 0.5016 - audience_exp_loss: 0.6951 - audience_exp_precision_1: 0.5041 - audience_exp_recall_1: 0.4776 - avg_perf_score_loss: 49.7612 - avg_perf_score_mae: 5.4195 - bid_strategy_accuracy: 0.2507 - bid_strategy_loss: 1.3889 - budget_dist_loss: 1.0002 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.4816 - budget_realloc_mae: 2.7931 - budget_rec_accuracy: 0.5269 - budget_rec_loss: 0.6945 - campaign_score_loss: 38.5049 - campaign_score_mae: 4.6214 - loss: 127.1582 - performance_alerts_accuracy: 0.9759 - performance_alerts_loss: 0.0633 - performance_alerts_precision: 0.8660 - performance_alerts_recall: 0.8606 - roi_forecast_loss: 20.3452 - roi_forecast_mae: 1.8485 - val_audience_exp_accuracy: 0.5023 - val_audience_exp_loss: 0.6934 - val_audience_exp_precision_1: 0.5020 - val_audience_exp_recall_1: 0.8323 - val_avg_perf_score_loss: 39.2957 - val_avg_perf_score_mae: 4.9749 - val_bid_strategy_accuracy: 0.2499 - val_bid_strategy_loss: 1.3875 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.1661 - val_budget_realloc_mae: 2.7616 - val_budget_rec_accuracy: 0.5355 - val_budget_rec_loss: 0.6787 - val_campaign_score_loss: 35.6808 - val_campaign_score_mae: 4.6608 - val_loss: 96.5927 - val_performance_alerts_accuracy: 0.9838 - val_performance_alerts_loss: 0.0511 - val_performance_alerts_precision: 0.9100 - val_performance_alerts_recall: 0.9090 - val_roi_forecast_loss: 3.0213 - val_roi_forecast_mae: 1.0774 - learning_rate: 2.5000e-04
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5018 - audience_exp_loss: 0.6945 - audience_exp_precision_1: 0.5041 - audience_exp_recall_1: 0.5104 - avg_perf_score_loss: 49.0700 - avg_perf_score_mae: 5.3505 - bid_strategy_accuracy: 0.2522 - bid_strategy_loss: 1.3886 - budget_dist_loss: 1.0002 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.4700 - budget_realloc_mae: 2.7898 - budget_rec_accuracy: 0.5285 - budget_rec_loss: 0.6934 - campaign_score_loss: 37.8838 - campaign_score_mae: 4.5517 - loss: 125.3901 - performance_alerts_accuracy: 0.9761 - performance_alerts_loss: 0.0628 - performance_alerts_precision: 0.8649 - performance_alerts_recall: 0.8646 - roi_forecast_loss: 19.9061 - roi_forecast_mae: 1.8170 - val_audience_exp_accuracy: 0.5005 - val_audience_exp_loss: 0.6988 - val_audience_exp_precision_1: 0.5008 - val_audience_exp_recall_1: 0.9378 - val_avg_perf_score_loss: 33.8765 - val_avg_perf_score_mae: 4.5083 - val_bid_strategy_accuracy: 0.2479 - val_bid_strategy_loss: 1.3890 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.0917 - val_budget_realloc_mae: 2.7540 - val_budget_rec_accuracy: 0.5350 - val_budget_rec_loss: 0.6788 - val_campaign_score_loss: 27.7618 - val_campaign_score_mae: 3.9087 - val_loss: 81.3743 - val_performance_alerts_accuracy: 0.9847 - val_performance_alerts_loss: 0.0506 - val_performance_alerts_precision: 0.9141 - val_performance_alerts_recall: 0.9151 - val_roi_forecast_loss: 1.2735 - val_roi_forecast_mae: 0.6490 - learning_rate: 2.5000e-04
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.4989 - audience_exp_loss: 0.6949 - audience_exp_precision_1: 0.5013 - audience_exp_recall_1: 0.4981 - avg_perf_score_loss: 48.1841 - avg_perf_score_mae: 5.3054 - bid_strategy_accuracy: 0.2488 - bid_strategy_loss: 1.3894 - budget_dist_loss: 1.0001 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.4365 - budget_realloc_mae: 2.7846 - budget_rec_accuracy: 0.5281 - budget_rec_loss: 0.6945 - campaign_score_loss: 37.0529 - campaign_score_mae: 4.5084 - loss: 123.2797 - performance_alerts_accuracy: 0.9758 - performance_alerts_loss: 0.0627 - performance_alerts_precision: 0.8589 - performance_alerts_recall: 0.8695 - roi_forecast_loss: 19.7852 - roi_forecast_mae: 1.8199 - val_audience_exp_accuracy: 0.4987 - val_audience_exp_loss: 0.6994 - val_audience_exp_precision_1: 0.4748 - val_audience_exp_recall_1: 0.0066 - val_avg_perf_score_loss: 36.4772 - val_avg_perf_score_mae: 4.7876 - val_bid_strategy_accuracy: 0.2499 - val_bid_strategy_loss: 1.3871 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.0693 - val_budget_realloc_mae: 2.7515 - val_budget_rec_accuracy: 0.5347 - val_budget_rec_loss: 0.6792 - val_campaign_score_loss: 31.5646 - val_campaign_score_mae: 4.3740 - val_loss: 90.5252 - val_performance_alerts_accuracy: 0.9842 - val_performance_alerts_loss: 0.0509 - val_performance_alerts_precision: 0.8984 - val_performance_alerts_recall: 0.9285 - val_roi_forecast_loss: 3.9720 - val_roi_forecast_mae: 1.2580 - learning_rate: 2.5000e-04
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - audience_exp_accuracy: 0.5020 - audience_exp_loss: 0.6940 - audience_exp_precision_1: 0.5045 - audience_exp_recall_1: 0.4879 - avg_perf_score_loss: 46.5575 - avg_perf_score_mae: 5.2420 - bid_strategy_accuracy: 0.2518 - bid_strategy_loss: 1.3884 - budget_dist_loss: 1.0010 - budget_dist_mae: 0.8495 - budget_realloc_loss: 10.4182 - budget_realloc_mae: 2.7842 - budget_rec_accuracy: 0.5279 - budget_rec_loss: 0.6940 - campaign_score_loss: 35.6422 - campaign_score_mae: 4.4398 - loss: 119.9529 - performance_alerts_accuracy: 0.9755 - performance_alerts_loss: 0.0629 - performance_alerts_precision: 0.8591 - performance_alerts_recall: 0.8644 - roi_forecast_loss: 19.6751 - roi_forecast_mae: 1.8065 - val_audience_exp_accuracy: 0.4983 - val_audience_exp_loss: 0.6936 - val_audience_exp_precision_1: 0.4973 - val_audience_exp_recall_1: 0.1372 - val_avg_perf_score_loss: 39.8137 - val_avg_perf_score_mae: 4.9943 - val_bid_strategy_accuracy: 0.2474 - val_bid_strategy_loss: 1.3884 - val_budget_dist_loss: 1.0004 - val_budget_dist_mae: 0.8503 - val_budget_realloc_loss: 10.1165 - val_budget_realloc_mae: 2.7565 - val_budget_rec_accuracy: 0.5350 - val_budget_rec_loss: 0.6794 - val_campaign_score_loss: 34.7343 - val_campaign_score_mae: 4.4787 - val_loss: 98.4230 - val_performance_alerts_accuracy: 0.9845 - val_performance_alerts_loss: 0.0512 - val_performance_alerts_precision: 0.9130 - val_performance_alerts_recall: 0.9140 - val_roi_forecast_loss: 5.3328 - val_roi_forecast_mae: 1.1519 - learning_rate: 2.5000e-04
# Weighted multi-task model training completed successfully!

# %%
from sklearn.utils import class_weight
import numpy as np

targets = {
    "audience_exp": y_audience_exp,
    "bid_strategy": y_bid_strategy
}

class_weights_dict = {}

for name, y in targets.items():
    weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
    class_weights_dict[name] = dict(zip(np.unique(y), weights))
    print(f"{name} class weights: {class_weights_dict[name]}")
# Out:
# audience_exp class weights: {np.int64(0): np.float64(1.004157210852931), np.int64(1): np.float64(0.9958770689346107)}
# bid_strategy class weights: {np.int64(0): np.float64(1.0008407061932023), np.int64(1): np.float64(0.9964129135113591), np.int64(2): np.float64(0.9980836793356755), np.int64(3): np.float64(1.0047020053852027)}

# %%
model.save("multi_task_model2.keras")

# %%
import numpy as np
from tensorflow import keras

# 1️⃣ Load the saved model
model = keras.models.load_model("multi_task_model.keras", compile=False)

# 2️⃣ Prepare a sample input
# Replace with the correct shape and dtype your model expects
sample_input = np.random.rand(1, input_feature_dim)  # e.g., (1, 20)

# 3️⃣ Get model predictions
predictions = model.predict(sample_input)

# 4️⃣ Print the outputs
# If it’s a multi-task model, predictions is usually a list of outputs
for i, output in enumerate(predictions):
    print(f"Output {i}: {output}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       5 model = keras.models.load_model("multi_task_model.keras", compile=False)
#       7 # 2️⃣ Prepare a sample input
#       8 # Replace with the correct shape and dtype your model expects
# ----> 9 sample_input = np.random.rand(1, input_feature_dim)  # e.g., (1, 20)
#      11 # 3️⃣ Get model predictions
#      12 predictions = model.predict(sample_input)
#
# NameError: name 'input_feature_dim' is not defined

# %%
# Load the model
from tensorflow import keras
model = keras.models.load_model("multi_task_model2.keras", compile=False)

# Check input shape
print(model.input_shape)
# Out:
# (None, 10)

# %%
import joblib

# Save StandardScaler
joblib.dump(scaler, "feature_scaler.save")

# Save LabelEncoders
joblib.dump(platform_encoder, "platform_encoder.save")
joblib.dump(budget_rec_encoder, "budget_rec_encoder.save")
joblib.dump(audience_exp_encoder, "audience_exp_encoder.save")
joblib.dump(bid_strategy_encoder, "bid_strategy_encoder.save")
# Out:
# ['bid_strategy_encoder.save']

# %%
from tensorflow.keras.models import load_model

# Load Keras model
model = load_model("multi_task_model.keras")

# Load encoders and scaler
scaler = joblib.load("feature_scaler.save")
platform_encoder = joblib.load("platform_encoder.save")
budget_rec_encoder = joblib.load("budget_rec_encoder.save")
audience_exp_encoder = joblib.load("audience_exp_encoder.save")
bid_strategy_encoder = joblib.load("bid_strategy_encoder.save")
# Out:
# c:\Users\jyoti\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 44 variables whereas the saved optimizer has 86 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import pandas as pd
import numpy as np
import re

def preprocess_row(row):
    # Encode platform
    row['platform_encoded'] = platform_encoder.transform([row['platform']])[0]

    # Process recommended_budget_distribution e.g., "22% Alpha, 38% Beta, 40% Gamma"
    parts = row['recommended_budget_distribution'].split(',')
    budget_alpha = float(parts[0].strip().split('%')[0])
    budget_beta  = float(parts[1].strip().split('%')[0])
    budget_gamma = float(parts[2].strip().split('%')[0])

    # Create input array
    X_input = np.array([[
        row['platform_encoded'], row['impressions'], row['clicks'], row['spend'],
        row['conversions'], row['CTR'], row['ROAS'],
        budget_alpha, budget_beta, budget_gamma
    ]])

    # Scale features
    X_scaled_input = scaler.transform(X_input)
    return X_scaled_input

# %%
def predict_row(row):
    X_scaled_input = preprocess_row(row)
    preds = model.predict(X_scaled_input)

    # preds is a list of 9 outputs, matching your model
    results = {
        'campaign_score': float(preds[0][0][0]),
        'roi_forecast': float(preds[1][0][0]),
        'avg_perf_score': float(preds[2][0][0]),
        'budget_dist': [float(x) for x in preds[3][0]],
        'budget_realloc': float(preds[4][0][0]),
        'performance_alerts': int(preds[5][0][0] > 0.5),
        'budget_rec': int(np.argmax(preds[6][0])),
        'audience_exp': int(preds[7][0][0] > 0.5),
        'bid_strategy': int(np.argmax(preds[8][0]))
    }

    # Optional: decode categorical outputs back to original labels
    results['budget_rec'] = budget_rec_encoder.inverse_transform([results['budget_rec']])[0]
    results['audience_exp'] = audience_exp_encoder.inverse_transform([results['audience_exp']])[0]
    results['bid_strategy'] = bid_strategy_encoder.inverse_transform([results['bid_strategy']])[0]

    return results

# %%
print(scaler.n_features_in_)
# Out:
# 1

# %%
from sklearn.preprocessing import StandardScaler
import joblib

# X = features for training (10 columns)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X has shape (n_samples, 10)

# Save the scaler for later use
joblib.dump(scaler, "feature_scaler.save")
# Out:
# ['feature_scaler.save']

# %%
import joblib

scaler = joblib.load("feature_scaler.save")
print(scaler.n_features_in_)  # Should print 10
# Out:
# 10

# %%
def preprocess_row(row):
    # Encode platform
    row['platform_encoded'] = platform_encoder.transform([row['platform']])[0]

    # Parse budget distribution
    budget_parts = row['recommended_budget_distribution'].split(',')
    budget_alpha = float(budget_parts[0].strip().split('%')[0])
    budget_beta  = float(budget_parts[1].strip().split('%')[0])
    budget_gamma = float(budget_parts[2].strip().split('%')[0])

    # Prepare feature array (10 features)
    X_input = np.array([[row['platform_encoded'], row['impressions'], row['clicks'], row['spend'],
                         row['conversions'], row['CTR'], row['ROAS'], budget_alpha, budget_beta, budget_gamma]])
    
    # Scale features using correct scaler
    X_scaled_input = scaler.transform(X_input)
    return X_scaled_input

# %%
X_scaled_input = preprocess_row(sample_row)
preds = model.predict(X_scaled_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step

# %%
# Print raw predictions
print(preds)

# If preds is a list (multi-task model)
for i, p in enumerate(preds):
    print(f"Output {i+1}: {p}")
# Out:
# [array([[20.289515]], dtype=float32), array([[0.26728535]], dtype=float32), array([[19.938618]], dtype=float32), array([[-0.02508513,  0.0700812 , -0.00126377]], dtype=float32), array([[9.190035]], dtype=float32), array([[0.67218745]], dtype=float32), array([[0.69836885, 0.14677173, 0.15485948]], dtype=float32), array([[0.4760242]], dtype=float32), array([[0.24284509, 0.25327653, 0.26749656, 0.23638184]], dtype=float32)]
# Output 1: [[20.289515]]
# Output 2: [[0.26728535]]
# Output 3: [[19.938618]]
# Output 4: [[-0.02508513  0.0700812  -0.00126377]]
# Output 5: [[9.190035]]
# Output 6: [[0.67218745]]
# Output 7: [[0.69836885 0.14677173 0.15485948]]
# Output 8: [[0.4760242]]
# Output 9: [[0.24284509 0.25327653 0.26749656 0.23638184]]

# %%
import numpy as np

def format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder):
    results = {}

    # 1. Campaign Score
    results["Campaign Score"] = float(preds[0][0][0])

    # 2. Performance Alerts (you may need mapping rules here)
    results["Performance Alerts"] = float(preds[1][0][0])  

    # 3. Budget Reallocation Opportunity
    results["Budget Reallocation (%)"] = float(preds[2][0][0])

    # 4. Bid Strategy Optimization (multi-class)
    bid_class = np.argmax(preds[3][0])
    results["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_class])[0]

    # 5. ROI Forecast
    results["ROI Forecast (ROAS)"] = float(preds[4][0][0])

    # 6. Average Performance Score
    results["Avg Performance Score"] = float(preds[5][0][0])

    # 7. Budget Distribution (3-way softmax probs)
    dist = preds[6][0]
    results["Budget Distribution"] = {
        "Alpha": round(dist[0] * 100, 2),
        "Beta": round(dist[1] * 100, 2),
        "Gamma": round(dist[2] * 100, 2),
    }

    # 8. Audience Expansion Opportunity (binary prob)
    results["Audience Expansion"] = audience_exp_encoder.inverse_transform(
        [int(preds[7][0][0] > 0.5)]
    )[0]

    # 9. Budget Recommendation (multi-class)
    rec_class = np.argmax(preds[8][0])
    results["Budget Recommendation"] = budget_rec_encoder.inverse_transform([rec_class])[0]

    return results

# %%
pretty_preds = format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder)
for k, v in pretty_preds.items():
    print(f"{k}: {v}")
# Out:
# Campaign Score: 20.289514541625977
# Performance Alerts: 0.2672853469848633
# Budget Reallocation (%): 19.938617706298828
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 9.190034866333008
# Avg Performance Score: 0.6721874475479126
# Budget Distribution: {'Alpha': np.float32(69.84), 'Beta': np.float32(14.68), 'Gamma': np.float32(15.49)}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget

# %%
def format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder):
    result = {}

    # Campaign Score (regression)
    result["Campaign Score"] = round(float(preds[0][0][0]), 2)

    # Performance Alerts (probability → label)
    result["Performance Alerts"] = "Triggered" if preds[1][0][0] > 0.5 else "Normal"

    # Budget Reallocation (%)
    result["Budget Reallocation (%)"] = round(float(preds[2][0][0]), 2)

    # Bid Strategy Optimization (classification)
    bid_idx = np.argmax(preds[3][0])
    result["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_idx])[0]

    # ROI Forecast (ROAS)
    result["ROI Forecast (ROAS)"] = round(float(preds[4][0][0]), 2)

    # Avg Performance Score
    result["Avg Performance Score"] = round(float(preds[5][0][0]), 2)

    # Budget Distribution (softmax probabilities → %)
    dist = preds[6][0]
    result["Budget Distribution"] = {
        "Alpha": round(float(dist[0]) * 100, 2),
        "Beta": round(float(dist[1]) * 100, 2),
        "Gamma": round(float(dist[2]) * 100, 2),
    }

    # Audience Expansion (classification)
    aud_idx = np.argmax(preds[7][0])
    result["Audience Expansion"] = audience_exp_encoder.inverse_transform([aud_idx])[0]

    # Budget Recommendation (classification)
    rec_idx = np.argmax(preds[8][0])
    result["Budget Recommendation"] = budget_rec_encoder.inverse_transform([rec_idx])[0]

    return result

# %%
pretty_preds = format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder)
for k, v in pretty_preds.items():
    print(f"{k}: {v}")
# Out:
# Campaign Score: 20.29
# Performance Alerts: Normal
# Budget Reallocation (%): 19.94
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 9.19
# Avg Performance Score: 0.67
# Budget Distribution: {'Alpha': 69.84, 'Beta': 14.68, 'Gamma': 15.49}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget

# %%
def format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder):
    result = {}

    def safe_val(x):
        import numpy as np
        if isinstance(x, (float, int, np.floating, np.integer)):
            return float(x)
        if hasattr(x, "ndim"):
            return float(x.ravel()[0])
        return x  # <-- return as-is if string

    result["Campaign Score"] = round(safe_val(preds['campaign_score']), 2)
    result["Performance Alerts"] = "Triggered" if safe_val(preds['performance_alerts']) > 0.5 else "Normal"
    result["Budget Reallocation (%)"] = round(safe_val(preds['budget_realloc']), 2)

    dist = preds['budget_dist']
    if hasattr(dist, "ndim"):
        dist = dist.ravel() * 100
        result["Budget Distribution"] = {
            "Alpha": round(float(dist[0]), 2),
            "Beta": round(float(dist[1]), 2),
            "Gamma": round(float(dist[2]), 2)
        }

    result["ROI Forecast (ROAS)"] = round(safe_val(preds['roi_forecast']), 2)
    result["Avg Performance Score"] = round(safe_val(preds['avg_perf_score']), 2)

    budget_rec_idx = np.argmax(preds['budget_rec'])
    result["Budget Recommendation"] = budget_rec_encoder.inverse_transform([budget_rec_idx])[0]

    # 🔹 Here we handle both prob or already-decoded string
    if isinstance(preds['audience_exp'], str):
        result["Audience Expansion"] = preds['audience_exp']
    else:
        result["Audience Expansion"] = "Yes" if safe_val(preds['audience_exp']) > 0.5 else "No"

    bid_idx = np.argmax(preds['bid_strategy'])
    result["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_idx])[0]

    return result

# %%
import numpy as np

def format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder):
    result = {}

    # Helper to safely convert numeric values
    def safe_val(x):
        if isinstance(x, (float, int, np.floating, np.integer)):
            return float(x)
        if hasattr(x, "ndim"):  # numpy array / tf.Tensor
            return float(x.ravel()[0])
        return x  # if already string, return as-is

    # Regression outputs
    result["Campaign Score"] = round(safe_val(preds['campaign_score']), 2)
    result["Performance Alerts"] = "Triggered" if safe_val(preds['performance_alerts']) > 0.5 else "Normal"
    result["Budget Reallocation (%)"] = round(safe_val(preds['budget_realloc']), 2)
    result["ROI Forecast (ROAS)"] = round(safe_val(preds['roi_forecast']), 2)
    result["Avg Performance Score"] = round(safe_val(preds['avg_perf_score']), 2)

    # Budget Distribution
    dist = preds['budget_dist']
    if hasattr(dist, "ndim"):
        dist = dist.ravel() * 100
    result["Budget Distribution"] = {
        "Alpha": round(float(dist[0]), 2),
        "Beta": round(float(dist[1]), 2),
        "Gamma": round(float(dist[2]), 2)
    }

    # Budget Recommendation (multi-class)
    budget_rec_idx = np.argmax(preds['budget_rec'])
    result["Budget Recommendation"] = budget_rec_encoder.inverse_transform([budget_rec_idx])[0]

    # Audience Expansion (binary, handles string or prob)
    if isinstance(preds['audience_exp'], str):
        result["Audience Expansion"] = preds['audience_exp']
    else:
        result["Audience Expansion"] = "Yes" if safe_val(preds['audience_exp']) > 0.5 else "No"

    # Bid Strategy Optimization (multi-class)
    bid_idx = np.argmax(preds['bid_strategy'])
    result["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_idx])[0]

    return result

# %%
sample_row = df.iloc[211].copy()        # pick any row
preds = predict_row(sample_row)        # returns raw or partially decoded outputs
pretty_preds = format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder)

for k, v in pretty_preds.items():
    print(f"{k}: {v}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Campaign Score: 193.77
# Performance Alerts: Normal
# Budget Reallocation (%): 10.23
# ROI Forecast (ROAS): 7.56
# Avg Performance Score: 196.9
# Budget Distribution: {'Alpha': 1.4, 'Beta': 6.9, 'Gamma': 1.45}
# Budget Recommendation: Maintain current budget
# Audience Expansion: No
# Bid Strategy Optimization: Maximize clicks

# %%
def predict_row(row):
    """
    Predict all 9 outputs for a single CSV row.
    Returns a dict keyed by output names, compatible with format_predictions().
    """
    # --- Encode platform ---
    row = row.copy()  # avoid SettingWithCopyWarning
    if 'platform_encoded' not in row:
        row['platform_encoded'] = platform_encoder.transform([row['platform']])[0]

    # --- Process recommended_budget_distribution ---
    if isinstance(row['recommended_budget_distribution'], str):
        parts = row['recommended_budget_distribution'].split(',')
        percentages = []
        for part in parts:
            try:
                percent = float(part.strip().split('%')[0])
            except:
                percent = 0.0
            percentages.append(percent)
        budget_alpha, budget_beta, budget_gamma = percentages
    else:
        budget_alpha = budget_beta = budget_gamma = 0.0

    # --- Prepare feature array ---
    X_input = np.array([[row['platform_encoded'], row['impressions'], row['clicks'], row['spend'],
                         row['conversions'], row['CTR'], row['ROAS'],
                         budget_alpha, budget_beta, budget_gamma]])
    
    # --- Scale features (using the scaler from training) ---
    X_scaled_input = scaler.transform(X_input)

    # --- Predict ---
    preds_list = model.predict(X_scaled_input)

    # --- Convert to dict keyed by output names ---
    output_names = ['campaign_score', 'roi_forecast', 'avg_perf_score', 'budget_dist',
                    'budget_realloc', 'performance_alerts', 'budget_rec',
                    'audience_exp', 'bid_strategy']

    preds_dict = {name: pred for name, pred in zip(output_names, preds_list)}
    return preds_dict

# %%
sample_row = df.iloc[8790].copy()            # pick any row
preds = predict_row(sample_row)            # returns dict keyed by output names
pretty_preds = format_predictions(preds, budget_rec_encoder, bid_strategy_encoder, audience_exp_encoder)

for k, v in pretty_preds.items():
    print(f"{k}: {v}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Campaign Score: 24.69
# Performance Alerts: Normal
# Budget Reallocation (%): 10.05
# ROI Forecast (ROAS): 0.12
# Avg Performance Score: 23.89
# Budget Distribution: {'Alpha': -1.51, 'Beta': 9.83, 'Gamma': -2.95}
# Budget Recommendation: Decrease budget or pause underperforming ads
# Audience Expansion: No
# Bid Strategy Optimization: Maximize conversions

# %%
def predict_and_display(row):
    """
    Input: row (pandas Series or dict) representing a single campaign
    Output: prints all 9 predictions in a human-readable format
    """
    # --- Ensure row is a copy to avoid warnings ---
    row = row.copy()

    # --- Encode platform ---
    if 'platform_encoded' not in row:
        row['platform_encoded'] = platform_encoder.transform([row['platform']])[0]

    # --- Process recommended_budget_distribution ---
    if isinstance(row['recommended_budget_distribution'], str):
        parts = row['recommended_budget_distribution'].split(',')
        percentages = []
        for part in parts:
            try:
                percent = float(part.strip().split('%')[0])
            except:
                percent = 0.0
            percentages.append(percent)
        budget_alpha, budget_beta, budget_gamma = percentages
    else:
        budget_alpha = budget_beta = budget_gamma = 0.0

    # --- Prepare features and scale ---
    X_input = np.array([[row['platform_encoded'], row['impressions'], row['clicks'], row['spend'],
                         row['conversions'], row['CTR'], row['ROAS'],
                         budget_alpha, budget_beta, budget_gamma]])
    X_scaled_input = scaler.transform(X_input)

    # --- Predict using model ---
    preds_list = model.predict(X_scaled_input)

    # --- Map predictions to output names ---
    output_names = ['campaign_score', 'roi_forecast', 'avg_perf_score', 'budget_dist',
                    'budget_realloc', 'performance_alerts', 'budget_rec',
                    'audience_exp', 'bid_strategy']
    preds_dict = {name: pred for name, pred in zip(output_names, preds_list)}

    # --- Format predictions for readability ---
    def safe_val(x):
        """Convert array/tensor to float safely."""
        if hasattr(x, "ndim"):
            return float(x.ravel()[0])
        try:
            return float(x)
        except:
            return x  # already decoded string

    result = {}

    # Campaign Score
    result["Campaign Score"] = round(safe_val(preds_dict['campaign_score']), 2)

    # Performance Alerts
    result["Performance Alerts"] = "Triggered" if safe_val(preds_dict['performance_alerts']) > 0.5 else "Normal"

    # Budget Reallocation
    result["Budget Reallocation (%)"] = round(safe_val(preds_dict['budget_realloc']), 2)

    # Bid Strategy Optimization
    bid_idx = np.argmax(preds_dict['bid_strategy'])
    result["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_idx])[0]

    # ROI Forecast
    result["ROI Forecast (ROAS)"] = round(safe_val(preds_dict['roi_forecast']), 2)

    # Avg Performance Score
    result["Avg Performance Score"] = round(safe_val(preds_dict['avg_perf_score']), 2)

    # Budget Distribution
    bd = preds_dict['budget_dist'].ravel()
    result["Budget Distribution"] = {
        'Alpha': round(float(bd[0]), 2),
        'Beta': round(float(bd[1]), 2),
        'Gamma': round(float(bd[2]), 2)
    }

    # Audience Expansion
    result["Audience Expansion"] = "Yes" if safe_val(preds_dict['audience_exp']) > 0.5 else "No"

    # Budget Recommendation
    budget_idx = np.argmax(preds_dict['budget_rec'])
    result["Budget Recommendation"] = budget_rec_encoder.inverse_transform([budget_idx])[0]

    # --- Print nicely ---
    print("=== Campaign Prediction ===")
    for k, v in result.items():
        print(f"{k}: {v}")

    return result

# %%
sample_row = df.iloc[87]


predictions = predict_and_display(sample_row)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# === Campaign Prediction ===
# Campaign Score: 222.32
# Performance Alerts: Normal
# Budget Reallocation (%): 10.63
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 36.55
# Avg Performance Score: 222.76
# Budget Distribution: {'Alpha': -0.16, 'Beta': 0.02, 'Gamma': 0.07}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget

# %%
def predict_and_display(row):
    """
    Input: row (pandas Series or dict) representing a single campaign
    Output: prints all 9 predictions in a human-readable format
    """
    # --- Ensure row is a copy to avoid warnings ---
    row = row.copy()

    # --- Encode platform ---
    if 'platform_encoded' not in row:
        row['platform_encoded'] = platform_encoder.transform([row['platform']])[0]

    # --- Process recommended_budget_distribution ---
    if isinstance(row['recommended_budget_distribution'], str):
        parts = row['recommended_budget_distribution'].split(',')
        percentages = []
        for part in parts:
            try:
                percent = float(part.strip().split('%')[0])
            except:
                percent = 0.0
            percentages.append(percent)
        budget_alpha, budget_beta, budget_gamma = percentages
    else:
        budget_alpha = budget_beta = budget_gamma = 0.0

    # --- Prepare features and scale ---
    X_input = np.array([[row['platform_encoded'], row['impressions'], row['clicks'], row['spend'],
                         row['conversions'], row['CTR'], row['ROAS'],
                         budget_alpha, budget_beta, budget_gamma]])
    X_scaled_input = scaler.transform(X_input)

    # --- Predict using model ---
    preds_list = model.predict(X_scaled_input)

    # --- Map predictions to output names ---
    output_names = ['campaign_score', 'roi_forecast', 'avg_perf_score', 'budget_dist',
                    'budget_realloc', 'performance_alerts', 'budget_rec',
                    'audience_exp', 'bid_strategy']
    preds_dict = {name: pred for name, pred in zip(output_names, preds_list)}

    # --- Helper for safely converting outputs ---
    def safe_val(x):
        """Convert array/tensor to float if possible, else return as-is"""
        if hasattr(x, "ndim"):
            return float(x.ravel()[0])
        try:
            return float(x)
        except:
            return x  # already decoded

    # --- Prepare results ---
    result = {}

    result["Campaign Score"] = round(safe_val(preds_dict['campaign_score']), 2)
    result["Performance Alerts"] = "Triggered" if safe_val(preds_dict['performance_alerts']) > 0.5 else "Normal"
    result["Budget Reallocation (%)"] = round(safe_val(preds_dict['budget_realloc']), 2)

    bid_idx = np.argmax(preds_dict['bid_strategy'])
    result["Bid Strategy Optimization"] = bid_strategy_encoder.inverse_transform([bid_idx])[0]

    result["ROI Forecast (ROAS)"] = round(safe_val(preds_dict['roi_forecast']), 2)
    result["Avg Performance Score"] = round(safe_val(preds_dict['avg_perf_score']), 2)

    # Budget Distribution (inverse scaled)
    bd_scaled = preds_dict['budget_dist']
    bd_actual = scaler_budget_dist.inverse_transform(bd_scaled)
    result["Budget Distribution"] = {
        'Alpha': round(float(bd_actual[0,0]), 2),
        'Beta': round(float(bd_actual[0,1]), 2),
        'Gamma': round(float(bd_actual[0,2]), 2)
    }

    result["Audience Expansion"] = "Yes" if safe_val(preds_dict['audience_exp']) > 0.5 else "No"

    budget_idx = np.argmax(preds_dict['budget_rec'])
    result["Budget Recommendation"] = budget_rec_encoder.inverse_transform([budget_idx])[0]

    # --- Print nicely ---
    print("=== Campaign Prediction ===")
    for k, v in result.items():
        print(f"{k}: {v}")

# %%
predict_and_display(df.iloc[221])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# === Campaign Prediction ===
# Campaign Score: 37.39
# Performance Alerts: Normal
# Budget Reallocation (%): 9.1
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 0.71
# Avg Performance Score: 38.04
# Budget Distribution: {'Alpha': 34.62, 'Beta': 34.3, 'Gamma': 31.4}
# Audience Expansion: No
# Budget Recommendation: Increase budget

# %%
for i in range(5): 
    print(f"\n--- Row {i} ---")
    predict_and_display(df.iloc[i])
# Out:
# --- Row 0 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# === Campaign Prediction ===
# Campaign Score: 20.29
# Performance Alerts: Triggered
# Budget Reallocation (%): 9.19
# Bid Strategy Optimization: Maximize conversions
# ROI Forecast (ROAS): 0.27
# Avg Performance Score: 19.94
# Budget Distribution: {'Alpha': 34.81, 'Beta': 35.59, 'Gamma': 29.98}
# Audience Expansion: No
# Budget Recommendation: Decrease budget or pause underperforming ads
#
# --- Row 1 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# === Campaign Prediction ===
# Campaign Score: 172.89
# Performance Alerts: Normal
# Budget Reallocation (%): 9.51
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 9.83
# Avg Performance Score: 174.52
# Budget Distribution: {'Alpha': 33.89, 'Beta': 34.42, 'Gamma': 31.58}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget
#
# --- Row 2 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# === Campaign Prediction ===
# Campaign Score: 156.07
# Performance Alerts: Normal
# Budget Reallocation (%): 10.56
# Bid Strategy Optimization: Maximize conversions
# ROI Forecast (ROAS): 46.59
# Avg Performance Score: 156.85
# Budget Distribution: {'Alpha': 34.28, 'Beta': 36.28, 'Gamma': 28.79}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget
#
# --- Row 3 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# === Campaign Prediction ===
# Campaign Score: 66.43
# Performance Alerts: Normal
# Budget Reallocation (%): 8.48
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 0.83
# Avg Performance Score: 67.61
# Budget Distribution: {'Alpha': 35.24, 'Beta': 35.12, 'Gamma': 30.62}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget
#
# --- Row 4 ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# === Campaign Prediction ===
# Campaign Score: 43.34
# Performance Alerts: Normal
# Budget Reallocation (%): 10.22
# Bid Strategy Optimization: Maximize clicks
# ROI Forecast (ROAS): 0.06
# Avg Performance Score: 43.31
# Budget Distribution: {'Alpha': 34.36, 'Beta': 34.89, 'Gamma': 30.83}
# Audience Expansion: No
# Budget Recommendation: Maintain current budget

# %%
import joblib

platform_encoder = joblib.load(r"C:\Users\jyoti\OneDrive\Desktop\ASF Hackathon\lasttry\platform_encoder.save")
print(platform_encoder.classes_)
# Out:
# ['Facebook Ads' 'Google Ads' 'Instagram Ads' 'LinkedIn Ads']
